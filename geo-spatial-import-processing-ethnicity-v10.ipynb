# %%
# Imports

import json
import geojson
import geopandas
import pandas as pd
import pathlib
import csv
import copy
import ast
import os
import time
from collections import OrderedDict

from geojson import Feature, Point, FeatureCollection

MAP_VERSION = 4
# STATS_TYPES = ['Count','Percent','nshft', 'pshft','growth', 'pshftna','growthna','Labels']
STATS_TYPES = ['Count','Percent','CountChange', 'PercentChange','SaturationChange', 'PercentChangeNatAdj','SaturationChangeNatAdj','Labels']

STATS_TYPE_LABELS = {
    'Count': "cnt",
    'CountChange': 'cch'
    'Percent': "pct",
    'PercentChange': "pch",
    'PercentChangeNatAdj': "pna",
    'SaturationChange': "sch",
    'SaturationChangeNatAdj': 'sna',
    'Labels': 'lbl'
}

# New to old mapping

# Count - count
# Percent - percent
# CountChange - nshft
# PercentChange - pshft
# SaturationChange - growth
# PercentChangeNatAdj - pshftna
# SaturationChangeNatAdj - growthna

# %%
ETHNICITIES = {
    "all": {
        "full": "All",
        "input_suffix": "All",
        "output_suffix": "al"
    },
    "asian": {
        "full": "Asian",
        "input_suffix": "Asi",
        "output_suffix": "as"
    },
    
    "black": {
        "full": "black",
        "input_suffix": "Bla",
        "output_suffix": "bl"
    },
    
    "hispanic": {
        "full": "Hispanic",
        "input_suffix": "His",
        "output_suffix": "hi"
    },
    
    "other": {
        "full": "Other",
        "input_suffix": "Oth",
        "output_suffix": "ot"
    },
    
    "white": {
        "full": "White",
        "input_suffix": "Whi",
        "output_suffix": "wh"
    },
    
    
}
ETHNICITY_KEYS = ETHNICITIES.keys()

def ethnicity_text(ethnicity,kind="input_suffix"):
    if kind == "input_suffix":
        return f'Eth{ETHNICITIES[ethnicity]["input_suffix"]}'
    elif kind == "output_suffix":
        return f'{ETHNICITIES[ethnicity]["output_suffix"]}'
    elif kind == "full":
        ETHNICITIES[ethnicity]["full"]
    else:
        ETHNICITIES[ethnicity]["full"]
        
print(ethnicity_text("all","output_suffix"))
print(ethnicity_text("white","input_suffix"))
print(ETHNICITY_KEYS)
# Out:
# al
# EthWhi
# dict_keys(['all', 'asian', 'black', 'hispanic', 'other', 'white'])

# %%
list(ETHNICITY_KEYS)[0]
STATS_TYPES[0]
# Out:
# 'Count'

# %%
fips_codes = {
 '01': {'abbr': 'AL', 'full_name': 'alabama'},
 '02': {'abbr': 'AK', 'full_name': 'alaska'},
 '04': {'abbr': 'AZ', 'full_name': 'arizona'},
 '05': {'abbr': 'AR', 'full_name': 'arkansas'},
 '06': {'abbr': 'CA', 'full_name': 'california'},
 '08': {'abbr': 'CO', 'full_name': 'colorado'},
 '09': {'abbr': 'CT', 'full_name': 'connecticut'},
 '10': {'abbr': 'DE', 'full_name': 'delaware'},
 '11': {'abbr': 'DC', 'full_name': 'district_of_columbia'},
 '12': {'abbr': 'FL', 'full_name': 'florida'},
 '13': {'abbr': 'GA', 'full_name': 'georgia'},
 '15': {'abbr': 'HI', 'full_name': 'hawaii'},
 '16': {'abbr': 'ID', 'full_name': 'idaho'},
 '17': {'abbr': 'IL', 'full_name': 'illinois'},
 '18': {'abbr': 'IN', 'full_name': 'indiana'},
 '19': {'abbr': 'IA', 'full_name': 'iowa'},
 '20': {'abbr': 'KS', 'full_name': 'kansas'},
 '21': {'abbr': 'KY', 'full_name': 'kentucky'},
 '22': {'abbr': 'LA', 'full_name': 'louisiana'},
 '23': {'abbr': 'ME', 'full_name': 'maine'},
 '24': {'abbr': 'MD', 'full_name': 'maryland'},
 '25': {'abbr': 'MA', 'full_name': 'massachusetts'},
 '26': {'abbr': 'MI', 'full_name': 'michigan'},
 '27': {'abbr': 'MN', 'full_name': 'minnesota'},
 '28': {'abbr': 'MS', 'full_name': 'mississippi'},
 '29': {'abbr': 'MO', 'full_name': 'missouri'},
 '30': {'abbr': 'MT', 'full_name': 'montana'},
 '31': {'abbr': 'NE', 'full_name': 'nebraska'},
 '32': {'abbr': 'NV', 'full_name': 'nevada'},
 '33': {'abbr': 'NH', 'full_name': 'new_hampshire'},
 '34': {'abbr': 'NJ', 'full_name': 'new_jersey'},
 '35': {'abbr': 'NM', 'full_name': 'new_mexico'},
 '36': {'abbr': 'NY', 'full_name': 'new_york'},
 '37': {'abbr': 'NC', 'full_name': 'north_carolina'},
 '38': {'abbr': 'ND', 'full_name': 'north_dakota'},
 '39': {'abbr': 'OH', 'full_name': 'ohio'},
 '40': {'abbr': 'OK', 'full_name': 'oklahoma'},
 '41': {'abbr': 'OR', 'full_name': 'oregon'},
 '42': {'abbr': 'PA', 'full_name': 'pennsylvania'},
 '44': {'abbr': 'RI', 'full_name': 'rhode_island'},
 '45': {'abbr': 'SC', 'full_name': 'south_carolina'},
 '46': {'abbr': 'SD', 'full_name': 'south_dakota'},
 '47': {'abbr': 'TN', 'full_name': 'tennessee'},
 '48': {'abbr': 'TX', 'full_name': 'texas'},
 '49': {'abbr': 'UT', 'full_name': 'utah'},
 '50': {'abbr': 'VT', 'full_name': 'vermont'},
 '51': {'abbr': 'VA', 'full_name': 'virginia'},
 '53': {'abbr': 'WA', 'full_name': 'washington'},
 '54': {'abbr': 'WV', 'full_name': 'west_virginia'},
 '55': {'abbr': 'WI', 'full_name': 'wisconsin'},
 '56': {'abbr': 'WY', 'full_name': 'wyoming'}}

# %%
STATE_FILES = [
    "tl_2010_01_bg10.json",
    "tl_2010_02_bg10.json",
    "tl_2010_04_bg10.json",
    "tl_2010_05_bg10.json",
    "tl_2010_06_bg10.json",
    "tl_2010_08_bg10.json",
    "tl_2010_09_bg10.json",
    "tl_2010_10_bg10.json",
    "tl_2010_11_bg10.json",
    "tl_2010_12_bg10.json",
    "tl_2010_13_bg10.json",
    "tl_2010_15_bg10.json",
    "tl_2010_16_bg10.json",
    "tl_2010_17_bg10.json",
    "tl_2010_18_bg10.json",
    "tl_2010_19_bg10.json",
    "tl_2010_20_bg10.json",
    "tl_2010_21_bg10.json",
    "tl_2010_22_bg10.json",
    "tl_2010_23_bg10.json",
    "tl_2010_24_bg10.json",
    "tl_2010_25_bg10.json",
    "tl_2010_26_bg10.json",
    "tl_2010_27_bg10.json",
    "tl_2010_28_bg10.json",
    "tl_2010_29_bg10.json",
    "tl_2010_30_bg10.json",
    "tl_2010_31_bg10.json",
    "tl_2010_32_bg10.json",
    "tl_2010_33_bg10.json",
    "tl_2010_34_bg10.json",
    "tl_2010_35_bg10.json",
    "tl_2010_36_bg10.json",
    "tl_2010_37_bg10.json",
    "tl_2010_38_bg10.json",
    "tl_2010_39_bg10.json",
    "tl_2010_40_bg10.json",
    "tl_2010_41_bg10.json",
    "tl_2010_42_bg10.json",
    "tl_2010_44_bg10.json",
    "tl_2010_45_bg10.json",
    "tl_2010_46_bg10.json",
    "tl_2010_47_bg10.json",
    "tl_2010_48_bg10.json",
    "tl_2010_49_bg10.json",
    "tl_2010_50_bg10.json",
    "tl_2010_51_bg10.json",
    "tl_2010_53_bg10.json",
    "tl_2010_54_bg10.json",
    "tl_2010_55_bg10.json",
    "tl_2010_56_bg10.json",
]

# %%
# Input Files
# 2 => "02"
def formatted_state_fips_code(fips_number):
    return f'{fips_number:02d}'

#  block_group_geojson_filename(state_fips_code=46, year=2010)
# tl_2010_46_bg10.json
def block_group_geojson_filename(state_fips_code=1, census_year=2010):
    year_string = str(census_year)
    fips_code_string = formatted_state_fips_code(state_fips_code)
    return f'tl_{year_string}_{fips_code_string}_bg10.json'

# wa_washington_zip_codes_geo.min.json
# def zip_code_geojson_filename(state_fips_code=1):
#     formatted_fips_code = formatted_state_fips_code(state_fips_code)
#     state_abbr = fips_codes[formatted_fips_code]["abbr"].lower()
#     state_full_name = fips_codes[formatted_fips_code]["full_name"]
#     return f'{state_abbr}_{state_full_name}_zip_codes_geo.min.json'


# def zip_geojson_files_for_market(market_data):
#     fips_codes = json.loads(market_data['StateFips'])
#     files = []
#     for fips_code in fips_codes:
#         files.append(zip_code_geojson_filename(fips_code))
#     return files

def bg_geojson_files_for_market(market_data, census_year):
    fips_codes = json.loads(market_data['StateFips'])
    files = []
    for fips_code in fips_codes:
        files.append(block_group_geojson_filename(state_fips_code=int(fips_code), census_year=census_year))
    return files

def read_geo_gson_file(file_path):
    with open(file_path) as f:
        gj = geojson.load(f)
        features = gj['features']
    print(f'Loaded {len(features)} features from {file_path}')
    return  features

def read_geojson_files(file_paths, base_path = "./"):
    features = []
    for file_path in file_paths:
        features += read_geo_gson_file(os.path.join(base_path, file_path))
    return features
    

# def read_market_zip_code_usage(market_file_prefix, base_path="./source_data" ):
#     data_type = "zip"
#     csv_file_path = mapping_data_file_path(market_file_prefix, base_path=base_path, data_type=data_type)
#     data_rows = []
#     with open(csv_file_path, encoding='utf-8-sig') as csvfile:
#         reader = csv.DictReader(csvfile)
#         for row in reader:
#             data_rows.append(row)
#     zip_codes = []
#     for data_row in data_rows:
#         zip_codes.append(data_row['Zip'].zfill(5))
#     print(f'Loaded {len(zip_codes)} zip_codes from {csv_file_path}')
#     return zip_codes
        
def read_market_block_group_usage(market_file_prefix, base_path="./source_data" ):
    data_type = "bg"
    csv_file_path = mapping_data_file_path(market_file_prefix, base_path=base_path, data_type=data_type)
    data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)
    block_groups = []
    for data_row in data_rows:
        block_groups.append(data_row['BG'].zfill(12))
    print(f'Loaded {len(block_groups)} block groups from {csv_file_path}')
    return block_groups
        
# market_file_prefix = 'DallasFortWorth'
# market_prefix= 'dfw'
# DallasFortWorth__Mapping_BG_Data.csv
# ./source_data/{market_file_prefix}__Mapping_BG_Data.csv - the actual zip code data
# 
# DallasFortWorth__Mapping_Zip_Data.csv
# ./source_data/{market_file_prefix}__Mapping_Zip_Data.csv - the actual block group data
# 
# DallasFortWorth__Mapping_Settings_Transposed File_BG.csv
# ./source_data/{market_file_prefix}__Mapping_Settings_Transposed_File_BG.csv - segment definitions for Block Groups
# DallasFortWorth__Mapping_Settings_Transposed File_Zip.csv
# ./source_data/{market_file_prefix}__Mapping_Settings_Transposed_File_Zip.csv - segment definitions for Zip Codes

def file_type_for_data_type(data_type = "bg"):
    if data_type == "zip": 
        return "Zip"
    if data_type == "bg":
        return "BG"

# DallasFortWorth__Mapping_BG_Data.csv
# ./source_data/{market_file_prefix}__Mapping_BG_Data.csv - the actual zip code data
# 
# DallasFortWorth__Mapping_Zip_Data.csv
# ./source_data/{market_file_prefix}__Mapping_Zip_Data.csv - the actual block group data
# 
def mapping_data_file_path_old(market_file_prefix,base_path="./source_data", data_type = "bg"):
    file_type = file_type_for_data_type(data_type = data_type)
    return f'{base_path}/{market_file_prefix}_Mapping_{file_type}_Data.csv'

def mapping_data_file_path(market_file_prefix, ethnicity, stats_type = "Count", base_path="./source_data"):
    ethnicity_suffix = ethnicity_file_suffix = ethnicity_text(ethnicity,"input_suffix")
    return f'{base_path}/{market_file_prefix}_{stats_type}_{ethnicity_suffix}.csv'

# DallasFortWorth__Mapping_Settings_Transposed File_BG.csv
# ./source_data/{market_file_prefix}__Mapping_Settings_Transposed_File_BG.csv - segment definitions for Block Groups
# DallasFortWorth__Mapping_Settings_Transposed File_Zip.csv
# ./source_data/{market_file_prefix}__Mapping_Settings_Transposed_File_Zip.csv - segment definitions for Zip Codes
def map_settings_data_file_path_old(market_file_prefix,ethnicity, base_path="./source_data", stats_type = "Count"):
    ethnicity_suffix = ethnicity_file_suffix = ethnicity_text(ethnicity,"input_suffix")
    return f'{base_path}/{market_file_prefix}_Mapping_Settings_Transposed_File_{stats_type}_{ethnicity_suffix}.csv'

def map_settings_data_file_path(market_file_prefix,ethnicity,  stats_type = "Count",base_path="./source_data",):
    ethnicity_suffix = ethnicity_file_suffix = ethnicity_text(ethnicity,"input_suffix")
    return f'{base_path}/{market_file_prefix}_Mapping_Settings_Transposed_File_{stats_type}_{ethnicity_suffix}.csv'


def published_map_data_path_old(market_prefix, ethnicity, data_type = "bg", published_data_base_path="./public"):
    ethnicity_suffix = ethnicity_text(ethnicity,"output_suffix")
    return f'{published_data_base_path}/{market_prefix}/data/{market_prefix}_{ethnicity_suffix}_{data_type}_data_v{MAP_VERSION}.json'

def published_map_data_path(market_prefix, ethnicity, stats_type = "Count", published_data_base_path="./public"):
    ethnicity_suffix = ethnicity_text(ethnicity,"output_suffix")
    stats_type_suffix = STATS_TYPE_LABELS[stats_type]
    return f'{published_data_base_path}/{market_prefix}/data/{market_prefix}_{ethnicity_suffix}_{stats_type_suffix}_data_v{MAP_VERSION}.json'


def published_map_settings_path(market_prefix, ethnicity, stats_type = "Count", published_data_base_path="./public"):
    ethnicity_suffix = ethnicity_text(ethnicity,"output_suffix")
    stats_type_suffix = STATS_TYPE_LABELS[stats_type]
    return f'{published_data_base_path}/{market_prefix}_{ethnicity_suffix}_{stats_type_suffix}_settings_data_v{MAP_VERSION}.json'

def published_map_labels_path_old(market_prefix, ethnicity, data_type = "bg", published_data_base_path="./public"):
    ethnicity_suffix = ethnicity_text(ethnicity,"output_suffix")
    return f'{published_data_base_path}/{market_prefix}_{ethnicity_suffix}_labels_v{MAP_VERSION}.json'

def published_map_labels_path(market_prefix, published_data_base_path="./public"):

    return f'{published_data_base_path}/{market_prefix}_labels_v{MAP_VERSION}.json'

def read_mapping_data(market_file_prefix,ethnicity, stats_type='Count', base_path='./source_data'):
    data_rows = []    
    csv_file_path = mapping_data_file_path(market_file_prefix, ethnicity, stats_type = stats_type, base_path=base_path)
    with open(csv_file_path) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)
    print(f'Loaded {len(data_rows)} data rows from {csv_file_path}')
    return data_rows

def create_zip_features(features, zip_data_rows):
    new_features_to_keep = []
    for data_row in zip_data_rows:
        zip_code = data_row['Zip'].zfill(5)
        # find the associated feature
        for feature in features:
            if feature['properties']["ZCTA5CE10"] == zip_code:
                new_feature = copy.deepcopy(feature)
                for key in data_row.keys():
                    if key != 'Zip':
                        if data_row[key]:
                            if data_row[key] != 'inf':
                                new_feature['properties'][key] =  ast.literal_eval(data_row[key].replace(',',''))
                new_features_to_keep.append(new_feature)
                break
    print(f'Processed {len(new_features_to_keep)} features to use')
    return new_features_to_keep

def create_bg_features(features, map_settings_data, bg_data_rows, stats_type):
    new_features_to_keep = []
    for data_row in bg_data_rows:
        block_group = str(data_row['BG']).zfill(12)
        # find the associated feature
        found = False
        if block_group in features:
            found = True
            feature = features[block_group]
            new_feature = copy.deepcopy(feature)
            properties = new_feature['properties']
            properties.pop("ALAND10",0)
            properties.pop("AWATER10",0)
            properties.pop("BLKGRPCE10",0)
            properties.pop("COUNTYFP10",0)
            properties.pop("FUNCSTAT10",0)
            properties.pop("MTFCC10",0)
            properties.pop("NAMELSAD10",0)
            properties.pop("STATEFP10",0)
            properties.pop("TRACTCE10",0)
            new_feature['properties'] = properties
            for key in list(data_row.keys())[0:]:
                if key not in  ['BG','LAT','LONG'] and stats_type in key: #and 'Count' in key:
                    if data_row[key] and data_row[key] != 'inf':
                        translated_key = map_settings_data[key]['mapbox_segment']
                        value = ast.literal_eval(data_row[key].replace(',',''))
                        value = int(value * 1000000) / 1000000
                        new_feature['properties'][translated_key] =  value
            new_features_to_keep.append(new_feature)
    #         if found == False:
    #             print(f'failed: {block_group}')
    print(f'Processed {len(new_features_to_keep)} features to use')
    return new_features_to_keep

def create_geojson(features):
    print(f'Created GeoJson with  {len(features)} features')
    return FeatureCollection(features)


def create_data_json(features):
    data = []
    for feature in features:
        #centroid = {
        #    "GEOID10": feature["properties"]["GEOID10"],
        #    "INTPTLAT10": feature["properties"]["INTPTLAT10"],
        #    "INTPTLON10": feature["properties"]["INTPTLON10"],
        #}
        datum = feature["properties"]
        data.append(datum)
    return data

def write_geojson(geojson_data, market_prefix,ethnicity, stats_type='Count',published_data_base_path = "./public"):
    geojson_string = geojson.dumps(geojson_data, sort_keys=True)
    ethnicity_suffix = ethnicity_file_suffix = ethnicity_text(ethnicity,"output_suffix")
    f = open(f'{published_data_base_path}/{market_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}.json', "w")
    f.write(geojson_string)
    f.close()
    print(f'Wrote geojson data to  {published_data_base_path}/{market_prefix}/data/{market_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}.json')
    
def write_data_json(json_data, market_prefix, ethnicity, stats_type='Count',published_data_base_path = "./public"):
    json_string = json.dumps(json_data, sort_keys=True)
    ethnicity_suffix = ethnicity_file_suffix = ethnicity_text(ethnicity,"output_suffix")
    f = open(f'{published_data_base_path}/{market_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_data_v{MAP_VERSION}.json', "w")
    f.write(json_string)
    f.close()
    print(f'Wrote centroid json data to  {published_data_base_path}/{market_prefix}/data/{market_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_data_v{MAP_VERSION}.json')

# TODO
def read_map_settings(market_file_prefix, ethnicity, stats_type = "Count", base_path="./source_data"):
    data_rows = []
    csv_file_path = map_settings_data_file_path(market_file_prefix,ethnicity, stats_type = stats_type, base_path=base_path )
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)
    print(f'Loaded {len(data_rows)} data rows from {csv_file_path}')   
    return data_rows

def write_settings_data(settings_data, market_file_prefix, ethnicity, stats_type = "Count", base_path="./public"):
    processed_settings_data = OrderedDict()
    segment_number = 0
    for row in settings_data:
        segment_number += 1
        if row["Display_Data_Type"] == "HH_Count":
            row["Display_Data_Type"] = "HH Count"
        mapbox_segment_key = f's{segment_number}'
        row['mapbox_segment'] = mapbox_segment_key
        processed_settings_data[row['UniqueSeriesString']] = row
    json_string = json.dumps(processed_settings_data, indent = 2, sort_keys=False)

    settings_data_file_path = published_map_settings_path(market_file_prefix, ethnicity, stats_type = stats_type, published_data_base_path=base_path)
    f = open(settings_data_file_path, "w")
    f.write(json_string)
    f.close()
    print(f'Wrote settings data rows to {settings_data_file_path}') 
    return processed_settings_data
    

def create_bg_labels(market_file_prefix, base_path="./source_data" ,  published_data_base_path="./public"):
    data_rows = []
    #     csv_file_path = './DFW_Mapping_data.csv'
    ethnicity = list(ETHNICITY_KEYS)[0]
    stats_type = STATS_TYPES[0]
    csv_file_path = mapping_data_file_path(market_file_prefix, ethnicity, stats_type, base_path=base_path)
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)

    features = []
    for data_row in data_rows:
        feature =  { 
            "type": "Feature", 
            "properties": {
                "id": data_row['BG']
            },
            "geometry": { 
                "type": "Point", 
                "coordinates": [ float(data_row['LONG']), float(data_row['LAT']) ]
            }
        }

        features.append(feature)
    geo_json = {
        "type": "FeatureCollection",
        "features": features
    }
    json_string = json.dumps(geo_json, indent = 2, sort_keys=True)
    output_file_path = published_map_labels_path(market_file_prefix, published_data_base_path=published_data_base_path)
    f = open(output_file_path, "w")
    f.write(json_string)
    f.close()
    print(f'Wrote geojson labels data to  {output_file_path}')

def create_geojson_settings(csv_file_path, published_data_base_path = "./public"):

    geospatial_settings = OrderedDict()
    csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings_v{MAP_VERSION}.csv'
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            row['CenterLat'] = float(row['CenterLat'])
            row['CenterLong'] = float(row['CenterLong'])
            geospatial_settings[row['MarketName']] = row
    geojson_string = json.dumps(geospatial_settings, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/geospatial_settings_v{MAP_VERSION}.json', "w")
    f.write(geojson_string)
    f.close()
    print(f'Wrote geospatials settings data to  {published_data_base_path}/geospatial_settings_v{MAP_VERSION}.json')
    
    
def create_tileset_data_recipe_file(market_file_prefix, ethnicity, stats_type, published_data_base_path):
    ethnicity_suffix = ethnicity_file_suffix = ethnicity_text(ethnicity,"output_suffix")

    recipe_file_contents = {
      'version': 1,
      'layers': {
        f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}': {
          'source': f'mapbox://tileset-source/stobieb/{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_src_v{MAP_VERSION}',
          'minzoom': 0,
          'maxzoom': 13,
          'tiles': {
            'layer_size': 2500
          }
        }
      }
    }

    recipe_file_path = os.path.join(published_data_base_path,f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_recipe_v{MAP_VERSION}.json' )
    with open(recipe_file_path, 'w') as recipe_file:
        recipe_file.write(json.dumps(recipe_file_contents, indent=4))
    

def create_tileset_labels_recipe_file(market_file_prefix, published_data_base_path):


    recipe_file_contents = {
      'version': 1,
      'layers': {
        f'{market_file_prefix}_labels_v{MAP_VERSION}': {
          'source': f'mapbox://tileset-source/stobieb/{market_file_prefix}_labels_src_v{MAP_VERSION}',
          'minzoom': 0,
          'maxzoom': 13,
            
        }
      }
    }

    recipe_file_path = os.path.join(published_data_base_path,f'{market_file_prefix}_labels_recipe_v{MAP_VERSION}.json' )
    with open(recipe_file_path, 'w') as recipe_file:
        recipe_file.write(json.dumps(recipe_file_contents, indent=4))
        
# def mstds_convert_file(market_file_prefix, published_data_base_path, filetype='data'):
#     recipe_file_path = os.path.join(published_data_base_path, market_file_prefix,'labels','mts-recipe.json' )
#     market_file_prefix, published_data_base_path

# %%
# Geojson file path
geojson_files_base_path = '/Users/alanmccann/Dropbox/bain/map_source_data'
def create_nation_bg_features_json(geojson_files_base_path='/Users/alanmccann/Dropbox/bain/map_source_data'):
    nationwide_features = {}
    for file in STATE_FILES:
        print(f'processing: {file}')
        geosjon_path = os.path.join(geojson_files_base_path,file)
        features = read_geo_gson_file(geosjon_path)
        for feature in features:
            key = feature['properties']["GEOID10"]
            nationwide_features[key] = feature
    json_string = json.dumps(nationwide_features, sort_keys=True)
    f = open(f'{geojson_files_base_path}/nationwide_bg.json', "w")
    f.write(json_string)
    f.close()
    print(f'Wrote geojson data to  {geojson_files_base_path}/nationwide_bg.json')

def read_nation_bg_features_json(geojson_files_base_path='/Users/alanmccann/Dropbox/bain/map_source_data'):
    geosjon_path = os.path.join(geojson_files_base_path,"nationwide_bg.json")
    # Opening JSON file
    f = open(geosjon_path)
    # returns JSON object as 
    # a dictionary
    features = json.load(f)
    # Closing file
    f.close()
    return features

def write_nation_bg_centroids_json(geojson_files_base_path='/Users/alanmccann/Dropbox/bain/map_source_data'):
    geosjon_path = os.path.join(geojson_files_base_path,"nationwide_bg.json")
    features = read_nation_bg_features_json(geojson_files_base_path)
    centroids = []
    for key in features.keys:
        feature = features[key]
        centroid = {
            "GEOID10": key,
            "INTPTLAT10": feature["properties"]["INTPTLAT10"],
            "INTPTLON10": feature["properties"]["INTPTLON10"],
        }
        centroids.append(centroid)
    json_string = json.dumps(centroids, sort_keys=True)
    f = open(f'{geojson_files_base_path}/nationwide_bg_centroids.json', "w")
    f.write(json_string)
    f.close()
    print(f'Wrote bg centroids data to  {geojson_files_base_path}/nationwide_bg_centroids.json')

# %%
# ETHNICITY TODO
def create_chart_json(published_data_base_path = "./public"):
    csv_file_path = f'{source_data_base_path}/Chart_Data_File.csv'
    chart_data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            chart_data_rows.append(row)
    data_json = {}
    for row in chart_data_rows:
        region = row['Region']
        # segment = row['Segment']
        year = row['Year']
        urban = row['Urban']
        suburban = row['SubUrban']
        exurban = row['ExUrban']
        print(region,year)
        print(urban, suburban, exurban)
        urban = '%.10f' % float(row['Urban'])
        suburban = '%.10f' % float(row['SubUrban'])
        exurban = '%.10f' % float(row['ExUrban'])
        display_region = row['DisplayRegion']
        if region not in data_json.keys():
            data_json[region] = {'displayRegion': display_region, 'data': {}}
        if year not in data_json[region]['data'].keys():
            data_json[region]['data'][year] = {}
        if 'Urban' not in data_json[region]['data'][year].keys():
            data_json[region]['data'][year]['Urban'] = {}
            data_json[region]['data'][year]['SubUrban'] = {}
            data_json[region]['data'][year]['ExUrban'] = {}
        data_json[region]['data'][year]['Urban'] = urban
        data_json[region]['data'][year]['SubUrban'] = suburban
        data_json[region]['data'][year]['ExUrban'] = exurban
    chart_data_string = json.dumps(data_json, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/market_summary_charts_v{MAP_VERSION}.json', "w")
    f.write(chart_data_string)
    f.close()
    print(f'Wrote market summary charts data to  {published_data_base_path}/market_summary_charts_v{MAP_VERSION}.json')

# %%
# ETHNICITY TODO
def create_comparison_chart_json(published_data_base_path = "./public"):
    csv_file_path = f'{source_data_base_path}/Chart_Data_File.csv'
    chart_data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            chart_data_rows.append(row)
    data_json = {}
    for row in chart_data_rows:
        region = row['Region']
        display_region = row['DisplayRegion']
        year = row['Year']
        age_segment=row['Display_Age_Segment']
        income_segment=row['Display_Income_Segment']
        key = f'{region}-{year}-{age_segment}-{income_segment}'
        urban = row['Urban']
        suburban = row['SubUrban']
        exurban = row['ExUrban']
        print(key)
        urban = '%.10f' % float(row['Urban'])
        suburban = '%.10f' % float(row['SubUrban'])
        exurban = '%.10f' % float(row['ExUrban'])
        display_region = row['DisplayRegion']
        isMetro = row['IsMetro']
        data_json[key] = {
            "year": year,
            "ageSegment": age_segment,
            "incomeSegment": income_segment,
            "urban": urban,
            "suburban": suburban,
            "exurban": exurban,
            "isMetro": isMetro,
        }
    chart_data_string = json.dumps(data_json, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/market_comparison_charts_v{MAP_VERSION}.json', "w")
    f.write(chart_data_string)
    f.close()
    print(f'Wrote market summary charts data to  {published_data_base_path}/market_comparison_charts_v{MAP_VERSION}.json')

# %%
# ETHNICITY TODO
def create_data_options_json(published_data_base_path = "./public"):
    csv_file_path = f'{source_data_base_path}/Chart_Data_File.csv'
    chart_data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            chart_data_rows.append(row)
    year_options_set = set()
    age_segment_options_set = set()
    income_segment_options_set = set()
    region_options_list = []
    for row in chart_data_rows:
        year_options_set.add(row["Year"])
        age_segment_options_set.add(row["Display_Age_Segment"])
        income_segment_options_set.add(row["Display_Income_Segment"])
        region = {
            "region": row["Region"],
            "displayRegion": row["DisplayRegion"],
            "isMetro": row["IsMetro"],
        }
        region_options_list.append(region)
    year_options_list = list(year_options_set)
    year_options_list.sort()
    age_segment_options_list = list(age_segment_options_set)
    age_segment_options_list.sort()
    income_segment_options_list = list(income_segment_options_set)
    income_segment_options_list.sort()
    region_options = pd.DataFrame(region_options_list).drop_duplicates().to_dict('r')
    dataOptions = {
        "yearOptions": year_options_list,
        'ageSegmentOptions': age_segment_options_list,
        'incomeSegmentOptions': income_segment_options_list,
        "regionOptions": region_options
    }
    data_options_string = json.dumps(dataOptions, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/data_options_v{MAP_VERSION}.json', "w")
    f.write(data_options_string)
    f.close()
    print(f'Wrote data options data to  {published_data_base_path}/data_options_v{MAP_VERSION}.json')

# %%
def process_main_geo_data(source_data_base_path, geojson_files_base_path, published_data_base_path, census_year):
    nationwide_bg_features = read_nation_bg_features_json(geojson_files_base_path)
    csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings_v{MAP_VERSION}.csv'
    market_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            market_rows.append(row)
    market_count = 0
    completed_markets = []
    for market_data in market_rows:
        #         if market_data['MarketName'] in ['Texas','DallasFortWorthTX']:
        #             #if True:
        #             #print(market_data['MarketName'])
        #if market_data['MarketName'] in ['Ohio','ClevelandOH']:
        # if market_data['MarketName'] in ['HomosassaSprngFL']:
        # if True:
        if market_data['MarketName'] in ['Texas','LosAngelesCA','California']:
            print("")
            print(f'Market Data: {market_count + 1}')
            market_file_prefix = market_data['MarketName'].lower()
            market_prefix = market_file_prefix
            mapbox_market_prefix = market_data['MapboxMarketName'].lower()
            create_tileset_labels_recipe_file(market_prefix, published_data_base_path)
            create_bg_labels(market_file_prefix, base_path=source_data_base_path , published_data_base_path=published_data_base_path)
            for ethnicity in ETHNICITIES.keys():
                for stats_type in STATS_TYPES[:2]:
                    create_tileset_data_recipe_file(market_prefix, ethnicity, stats_type, published_data_base_path)
                    map_settings_data = read_map_settings(market_data['MarketName'], ethnicity, stats_type , base_path=source_data_base_path)
                    map_settings = write_settings_data(map_settings_data, market_prefix, ethnicity, stats_type, base_path=published_data_base_path)
                    block_group_rows = read_mapping_data(market_file_prefix, ethnicity,stats_type, source_data_base_path)
                    features_to_use = create_bg_features(nationwide_bg_features, map_settings, block_group_rows, stats_type)
                    new_geojson = create_geojson(features_to_use)
                    write_geojson(new_geojson, market_prefix, ethnicity, stats_type,published_data_base_path=published_data_base_path)
                    if stats_type.lower() != 'labels':
                        new_data_json = create_data_json(features_to_use)
                        write_data_json(new_data_json, market_prefix.lower(), ethnicity, stats_type, published_data_base_path)
            market_count += 1
    # Finished states - create overall settings file    
    create_geojson_settings(csv_file_path, published_data_base_path = "./public")
    print(f'*** COMPLETED {market_count} markets')
    print(completed_markets)
                          
        
# source_data_base_path = "./source_data"
# source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/v5_9th_run Brian Stobie/"
# published_data_base_path = "./public"
# geojson_files_base_path = '/Users/alanmccann/Dropbox/bain/map_source_data'
# census_year = 2010

# %%
STATS_TYPES[:2]
# Out:
# ['Count', 'Percent']

# %%
# Set up input and output locations
# Geojson file path
geojson_files_base_path = '/Users/alanmccann/Dropbox/bain/map_source_data'
# Source csv data path
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie"
# Output data path - all of the files in this folder should be uploaded to the cms GeoSpatialTool/v1 folder
published_data_base_path = "./public"
published_data_base_path = f'/Users/alanmccann/Dropbox/bain/mtsds-data/v{MAP_VERSION}'
# Census year for geojson
census_year = 2010


# Process the data
process_main_geo_data(source_data_base_path, geojson_files_base_path, published_data_base_path, census_year)
# create_chart_json(published_data_base_path)
# create_comparison_chart_json(published_data_base_path)
# create_data_options_json(published_data_base_path)
# Out:
# Market Data: 1
# Wrote geojson labels data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_labels_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Count_EthAll.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_al_cnt_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Count_EthAll.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_al_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_al_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Percent_EthAll.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_al_pct_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Percent_EthAll.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_al_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_al_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Count_EthAsi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_as_cnt_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Count_EthAsi.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_as_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_as_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Percent_EthAsi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_as_pct_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Percent_EthAsi.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_as_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_as_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Count_EthBla.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_bl_cnt_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Count_EthBla.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_bl_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_bl_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Percent_EthBla.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_bl_pct_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Percent_EthBla.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_bl_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_bl_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Count_EthHis.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_hi_cnt_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Count_EthHis.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_hi_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_hi_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Percent_EthHis.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_hi_pct_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Percent_EthHis.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_hi_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_hi_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Count_EthOth.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_ot_cnt_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Count_EthOth.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_ot_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_ot_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Percent_EthOth.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_ot_pct_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Percent_EthOth.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_ot_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_ot_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Count_EthWhi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_wh_cnt_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Count_EthWhi.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_wh_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_wh_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/LosAngelesCA_Mapping_Settings_Transposed_File_Percent_EthWhi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca_wh_pct_settings_data_v4.json
# Loaded 8002 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/losangelesca_Percent_EthWhi.csv
# Processed 8002 features to use
# Created GeoJson with  8002 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_wh_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/losangelesca/data/losangelesca_wh_pct_data_v4.json
#
# Market Data: 2
# Wrote geojson labels data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_labels_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Count_EthAll.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_al_cnt_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Count_EthAll.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_al_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_al_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Percent_EthAll.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_al_pct_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Percent_EthAll.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_al_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_al_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Count_EthAsi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_as_cnt_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Count_EthAsi.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_as_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_as_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Percent_EthAsi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_as_pct_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Percent_EthAsi.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_as_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_as_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Count_EthBla.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_bl_cnt_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Count_EthBla.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_bl_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_bl_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Percent_EthBla.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_bl_pct_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Percent_EthBla.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_bl_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_bl_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Count_EthHis.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_hi_cnt_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Count_EthHis.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_hi_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_hi_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Percent_EthHis.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_hi_pct_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Percent_EthHis.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_hi_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_hi_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Count_EthOth.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_ot_cnt_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Count_EthOth.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_ot_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_ot_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Percent_EthOth.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_ot_pct_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Percent_EthOth.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_ot_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_ot_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Count_EthWhi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_wh_cnt_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Count_EthWhi.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_wh_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_wh_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/California_Mapping_Settings_Transposed_File_Percent_EthWhi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california_wh_pct_settings_data_v4.json
# Loaded 22263 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/california_Percent_EthWhi.csv
# Processed 22263 features to use
# Created GeoJson with  22263 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_wh_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/california/data/california_wh_pct_data_v4.json
#
# Market Data: 3
# Wrote geojson labels data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_labels_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Count_EthAll.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_al_cnt_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Count_EthAll.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_al_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_al_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Percent_EthAll.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_al_pct_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Percent_EthAll.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_al_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_al_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Count_EthAsi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_as_cnt_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Count_EthAsi.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_as_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_as_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Percent_EthAsi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_as_pct_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Percent_EthAsi.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_as_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_as_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Count_EthBla.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_bl_cnt_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Count_EthBla.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_bl_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_bl_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Percent_EthBla.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_bl_pct_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Percent_EthBla.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_bl_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_bl_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Count_EthHis.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_hi_cnt_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Count_EthHis.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_hi_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_hi_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Percent_EthHis.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_hi_pct_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Percent_EthHis.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_hi_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_hi_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Count_EthOth.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_ot_cnt_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Count_EthOth.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_ot_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_ot_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Percent_EthOth.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_ot_pct_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Percent_EthOth.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_ot_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_ot_pct_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Count_EthWhi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_wh_cnt_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Count_EthWhi.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_wh_cnt_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_wh_cnt_data_v4.json
# Loaded 64 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/Texas_Mapping_Settings_Transposed_File_Percent_EthWhi.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas_wh_pct_settings_data_v4.json
# Loaded 12672 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie/texas_Percent_EthWhi.csv
# Processed 12672 features to use
# Created GeoJson with  12672 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_wh_pct_v4.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/v4/texas/data/texas_wh_pct_data_v4.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/dh/fn0cs6ln6sq0722wd5lcgdcm0000gn/T/ipykernel_40766/2477431310.py in <module>
#      12
#      13 # Process the data
# ---> 14 process_main_geo_data(source_data_base_path, geojson_files_base_path, published_data_base_path, census_year)
#      15 # create_chart_json(published_data_base_path)
#      16 # create_comparison_chart_json(published_data_base_path)
#
# /var/folders/dh/fn0cs6ln6sq0722wd5lcgdcm0000gn/T/ipykernel_40766/316475533.py in process_main_geo_data(source_data_base_path, geojson_files_base_path, published_data_base_path, census_year)
#      38             market_count += 1
#      39     # Finished states - create overall settings file
# ---> 40     create_geojson_settings(csv_file_path, published_data_base_path = "./public")
#      41     print(f'*** COMPLETED {market_count} markets')
#      42     print(completed_markets)
#
# /var/folders/dh/fn0cs6ln6sq0722wd5lcgdcm0000gn/T/ipykernel_40766/1356050601.py in create_geojson_settings(csv_file_path, published_data_base_path)
#     317             geospatial_settings[row['MarketName']] = row
#     318     geojson_string = json.dumps(geospatial_settings, indent=4, sort_keys=True)
# --> 319     f = open(f'{published_data_base_path}/geospatial_settings_v{MAP_VERSION}.json', "w")
#     320     f.write(geojson_string)
#     321     f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: './public/geospatial_settings_v4.json'

# %%
def upload_to_mapbox(source_data_base_path,published_data_base_path):
    csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings_v{MAP_VERSION}.csv'
    market_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            market_rows.append(row)
    market_count = 0
    completed_markets = []
    for market_data in market_rows: #[0:10]:
        # if market_data['MarketName'] in ['Texas','DallasFortWorth']:
        if True:
            print("")
            print(f'Market Data: {market_count + 1}')
            market_file_prefix = market_data['MarketName'].lower()
            os.system(f'cd {published_data_base_path}; tilesets upload-source stobieb {market_file_prefix}_bg_data-src_v{MAP_VERSION} {market_file_prefix}_bg_data_v{MAP_VERSION}.json')
            os.system(f'cd {published_data_base_path};  tilesets create stobieb.{market_file_prefix}_bg_data_v{MAP_VERSION} --recipe {market_file_prefix}-bg-recipe_v{MAP_VERSION}.json --name "{market_file_prefix}_bg_data"')
            os.system(f'cd {published_data_base_path};  tilesets publish stobieb.{market_file_prefix}_bg_data_v{MAP_VERSION}')
            os.system(f'cd {published_data_base_path};  tilesets upload-source stobieb {market_file_prefix}_bg_labels-src {market_file_prefix}_bg_labels_v{MAP_VERSION}.json')
            os.system(f'cd {published_data_base_path};  tilesets create stobieb.{market_file_prefix}_bg_labels --recipe {market_file_prefix}-labels-recipe.json --name "{market_file_prefix}_bg_labels_v{MAP_VERSION}"')
            os.system(f'cd {published_data_base_path};  tilesets publish stobieb.{market_file_prefix}_bg_labels')

# %%
import os
import subprocess
import json
MAPBOX_ACCESS_TOKEN='sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'
my_env = {**os.environ, 'MAPBOX_ACCESS_TOKEN':'sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'}

import subprocess
# tilesets job stobieb.dallasfortworth_bg_data cl9kgdofo000209l52zyy3mdi
process = subprocess.Popen(['tilesets', 'job', 'stobieb.dallasfortworth_bg_data', 'cl9kgdofo000209l52zyy3mdi'],
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE,
                     env=my_env)
stdout, stderr = process.communicate()
output = stdout.decode('utf-8').split('\n')
error = stderr.decode('utf-8')
result = json.loads(output[0])

# %%
import os
import subprocess
import json
MAPBOX_ACCESS_TOKEN='sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'
my_env = {**os.environ, 'MAPBOX_ACCESS_TOKEN':'sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'}
published_data_base_path = f'/Users/alanmccann/Dropbox/bain/mtsds-data/v{MAP_VERSION}'
import subprocess

cwd = os.getcwd()
os.chdir(published_data_base_path)

market_file_prefix = 'austin'
stats_type = 'Count'

def upload_source(market_file_prefix, ethnicity, stats_type, working_directory):
    ethnicity_suffix = ethnicity_text(ethnicity, "output_suffix")
    cwd = os.getcwd()
    os.chdir(working_directory)
    upload_source_command = [
        'tilesets',
        'upload-source',
        'stobieb',
        f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_src_v{MAP_VERSION}',
        f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}.json',
        '--replace'
    ]
    print(' '.join(upload_source_command))
    process = subprocess.Popen(upload_source_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output)

def upload_label_source(market_file_prefix, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    upload_source_command = [
        'tilesets',
        'upload-source',
        'stobieb',
        f'{market_file_prefix}_labels_src_v{MAP_VERSION}',
        f'{market_file_prefix}_labels_v{MAP_VERSION}.json',
        #'--replace'
    ]
    print(' '.join(upload_source_command))
    process = subprocess.Popen(upload_source_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output)
    
# upload_source(market_file_prefix, stats_type, published_data_base_path)

# %%
def update_recipe(market_file_prefix, ethnicity, stats_type, working_directory):
    ethnicity_suffix = ethnicity_text(ethnicity, "output_suffix")
    cwd = os.getcwd()
    os.chdir(working_directory)
    update_recipe_command = [
        'tilesets',
        'update-recipe',
        f'stobieb.{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}',
        f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_recipe_v{MAP_VERSION}.json',
        
    ]

    print(' '.join(update_recipe_command))
    process = subprocess.Popen(update_recipe_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    
def update_label_recipe(market_file_prefix,  working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    update_recipe_command = [
        'tilesets',
        'update-recipe',
        f'stobieb.{market_file_prefix}_labels_v{MAP_VERSION}',
        f'{market_file_prefix}_labels_recipe_v{MAP_VERSION}.json',
        
    ]

    print(' '.join(update_recipe_command))
    process = subprocess.Popen(update_recipe_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    
def upload_tileset(market_file_prefix, ethnicity, stats_type, working_directory):
    ethnicity_suffix = ethnicity_text(ethnicity, "output_suffix")
    cwd = os.getcwd()
    os.chdir(working_directory)
    create_tileset_command = [
        'tilesets',
        'create',
        f'stobieb.{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}',
        '--recipe', 
        f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_recipe_v{MAP_VERSION}.json',
        '--name',
        f'{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}'
        
    ]

    print(' '.join(create_tileset_command))
    process = subprocess.Popen(create_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)

def upload_label_tileset(market_file_prefix, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    create_tileset_command = [
        'tilesets',
        'create',
        f'stobieb.{market_file_prefix}_labels_v{MAP_VERSION}',
        '--recipe', f'{market_file_prefix}_labels_recipe_v{MAP_VERSION}.json',
        '--name',
        f'{market_file_prefix}_labels_v{MAP_VERSION}'
        
    ]

    print(' '.join(create_tileset_command))
    process = subprocess.Popen(create_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)

# %%
import time
def publish_tileset(market_file_prefix, ethnicity, stats_type, working_directory):
    ethnicity_suffix = ethnicity_text(ethnicity, "output_suffix")
    cwd = os.getcwd()
    os.chdir(working_directory)
    publish_tileset_command = [
        'tilesets',
        'publish',
        f'stobieb.{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}'
    ]

    print(' '.join(publish_tileset_command))
    print(datetime.datetime.now())
    process = subprocess.Popen(publish_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    result = json.loads(output[0])
    print(result)
    get_job_status_command = [
        'tilesets',
        'job',
        f'stobieb.{market_file_prefix}_{ethnicity_suffix}_{STATS_TYPE_LABELS[stats_type]}_v{MAP_VERSION}',
        result['jobId']
    ]
    state = 'processing'
    while state == 'processing':
        process = subprocess.Popen(get_job_status_command,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE,
                     env=my_env)

        stdout, stderr = process.communicate()
        output = stdout.decode('utf-8').split('\n')
        try:
            result = json.loads(output[0])
        except:
            result = {}
        if 'stage' in result.keys():
            state = result['stage']
        if state != 'success':
            print(f'{state}: sleeping')
            time.sleep(15)
    print('finished')
    print(datetime.datetime.now())

def publish_label_tileset(market_file_prefix,  working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    publish_tileset_command = [
        'tilesets',
        'publish',
        f'stobieb.{market_file_prefix}_labels_v{MAP_VERSION}'
    ]

    print(' '.join(publish_tileset_command))
    print(datetime.datetime.now())
    process = subprocess.Popen(publish_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    result = json.loads(output[0])
    print(result)
    get_job_status_command = [
        'tilesets',
        'job',
        f'stobieb.{market_file_prefix}_labels_v{MAP_VERSION}',
        result['jobId']
    ]
    state = 'processing'
    while state == 'processing':
        process = subprocess.Popen(get_job_status_command,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE,
                     env=my_env)

        stdout, stderr = process.communicate()
        output = stdout.decode('utf-8').split('\n')
        try:
            result = json.loads(output[0])
        except:
            result = {}
        if 'stage' in result.keys():
            state = result['stage']
        if state != 'success':
            print(f'{state}: sleeping')
            time.sleep(15)
    print('finished')
    print(datetime.datetime.now())

# %%
import csv
import datetime
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_Dec2026_Run1 Brian Stobie"
published_data_base_path = f'/Users/alanmccann/Dropbox/bain/mtsds-data/v{MAP_VERSION}'
csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings_v{MAP_VERSION}.csv'
market_rows = []
with open(csv_file_path, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        market_rows.append(row)
market_count = 0
completed_markets = []
# STATS_TYPES = ['count','percent','nshft','labels','pshft','pshftna','growthna']
STATS_TYPES = ['growth']
STATS_TYPES = ['Count','Percent']
# MARKETS = ["ColoradoSpringCO","DallasFortWrthTX","EastStroudsbrgPA","HiltonHeadIlndSC","HomosassaSprngFL","DstrctOfColumbia"]
# MARKETS = ["ClevelandOH"]

# STATS_TYPES = ['pshftna','growthna']
# STATS_TYPES = ['nshft']
# Ohio market_rows[416:417]
# Cleveland market_rows[73:74]
count = 77
for market_data in market_rows:  #[416:417]:
    if market_data['MarketName'] in ['Texas','LosAngelesCA','California']:
        market_file_prefix = market_data['MapboxMarketName'].lower()
        for ethnicity in list(ETHNICITIES.keys()):
            if True: #market_data['MarketName'] in MARKETS: #,'DallasFortWorthTX']:
                count += 1
                print('count',count)
                print('creating tilesets for:', market_file_prefix, ethnicity)
                print(datetime.datetime.now())
                for stats_type in STATS_TYPES:
                    upload_source(market_file_prefix, ethnicity, stats_type, published_data_base_path)
                    upload_tileset(market_file_prefix, ethnicity,  stats_type, published_data_base_path)
                    update_recipe(market_file_prefix,ethnicity,  stats_type, published_data_base_path)
                    publish_tileset(market_file_prefix,ethnicity,  stats_type, published_data_base_path)
        upload_label_source(market_file_prefix, published_data_base_path)
        upload_label_tileset(market_file_prefix, published_data_base_path)
        update_label_recipe(market_file_prefix, published_data_base_path)
        publish_label_tileset(market_file_prefix,published_data_base_path)
# Out:
# count 78
# creating tilesets for: losangelesca all
# 2023-12-30 16:41:51.260649
# tilesets upload-source stobieb losangelesca_al_cnt_src_v4 losangelesca_al_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_al_cnt_src_v4", "files": 1, "source_size": 22957584, "file_size": 22957584}', '']
# tilesets create stobieb.losangelesca_al_cnt_v4 --recipe losangelesca_al_cnt_recipe_v4.json --name losangelesca_al_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_al_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_al_cnt_v4 losangelesca_al_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_al_cnt_v4
# 2023-12-30 16:42:08.865821
# ['{"message": "Processing stobieb.losangelesca_al_cnt_v4", "jobId": "clqsl8zzt000y08ky3wgb3l59"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_al_cnt_v4 or run tilesets job stobieb.losangelesca_al_cnt_v4 clqsl8zzt000y08ky3wgb3l59 to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_al_cnt_v4', 'jobId': 'clqsl8zzt000y08ky3wgb3l59'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 16:44:40.730672
# tilesets upload-source stobieb losangelesca_al_pct_src_v4 losangelesca_al_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_al_pct_src_v4", "files": 1, "source_size": 23124370, "file_size": 23124370}', '']
# tilesets create stobieb.losangelesca_al_pct_v4 --recipe losangelesca_al_pct_recipe_v4.json --name losangelesca_al_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_al_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_al_pct_v4 losangelesca_al_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_al_pct_v4
# 2023-12-30 16:44:59.104460
# ['{"message": "Processing stobieb.losangelesca_al_pct_v4", "jobId": "clqslcn6q003008jtg0910g04"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_al_pct_v4 or run tilesets job stobieb.losangelesca_al_pct_v4 clqslcn6q003008jtg0910g04 to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_al_pct_v4', 'jobId': 'clqslcn6q003008jtg0910g04'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 16:47:47.467367
# count 79
# creating tilesets for: losangelesca asian
# 2023-12-30 16:47:47.467540
# tilesets upload-source stobieb losangelesca_as_cnt_src_v4 losangelesca_as_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_as_cnt_src_v4", "files": 1, "source_size": 23073843, "file_size": 23073843}', '']
# tilesets create stobieb.losangelesca_as_cnt_v4 --recipe losangelesca_as_cnt_recipe_v4.json --name losangelesca_as_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_as_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_as_cnt_v4 losangelesca_as_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_as_cnt_v4
# 2023-12-30 16:48:03.770485
# ['{"message": "Processing stobieb.losangelesca_as_cnt_v4", "jobId": "clqslgm2u000c08jl2wtndhuf"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_as_cnt_v4 or run tilesets job stobieb.losangelesca_as_cnt_v4 clqslgm2u000c08jl2wtndhuf to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_as_cnt_v4', 'jobId': 'clqslgm2u000c08jl2wtndhuf'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 16:50:35.598647
# tilesets upload-source stobieb losangelesca_as_pct_src_v4 losangelesca_as_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_as_pct_src_v4", "files": 1, "source_size": 23050280, "file_size": 23050280}', '']
# tilesets create stobieb.losangelesca_as_pct_v4 --recipe losangelesca_as_pct_recipe_v4.json --name losangelesca_as_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_as_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_as_pct_v4 losangelesca_as_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_as_pct_v4
# 2023-12-30 16:51:03.201575
# ['{"message": "Processing stobieb.losangelesca_as_pct_v4", "jobId": "clqslkg8p004n08l5cttz485x"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_as_pct_v4 or run tilesets job stobieb.losangelesca_as_pct_v4 clqslkg8p004n08l5cttz485x to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_as_pct_v4', 'jobId': 'clqslkg8p004n08l5cttz485x'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 16:53:51.265304
# count 80
# creating tilesets for: losangelesca black
# 2023-12-30 16:53:51.265559
# tilesets upload-source stobieb losangelesca_bl_cnt_src_v4 losangelesca_bl_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_bl_cnt_src_v4", "files": 1, "source_size": 22832363, "file_size": 22832363}', '']
# tilesets create stobieb.losangelesca_bl_cnt_v4 --recipe losangelesca_bl_cnt_recipe_v4.json --name losangelesca_bl_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_bl_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_bl_cnt_v4 losangelesca_bl_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_bl_cnt_v4
# 2023-12-30 16:54:09.270466
# ['{"message": "Processing stobieb.losangelesca_bl_cnt_v4", "jobId": "clqslog2d002608l0elbo08wx"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_bl_cnt_v4 or run tilesets job stobieb.losangelesca_bl_cnt_v4 clqslog2d002608l0elbo08wx to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_bl_cnt_v4', 'jobId': 'clqslog2d002608l0elbo08wx'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 16:56:42.365113
# tilesets upload-source stobieb losangelesca_bl_pct_src_v4 losangelesca_bl_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_bl_pct_src_v4", "files": 1, "source_size": 22859381, "file_size": 22859381}', '']
# tilesets create stobieb.losangelesca_bl_pct_v4 --recipe losangelesca_bl_pct_recipe_v4.json --name losangelesca_bl_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_bl_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_bl_pct_v4 losangelesca_bl_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_bl_pct_v4
# 2023-12-30 16:56:59.584699
# ['{"message": "Processing stobieb.losangelesca_bl_pct_v4", "jobId": "clqsls3ad001w08jr3p2me04t"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_bl_pct_v4 or run tilesets job stobieb.losangelesca_bl_pct_v4 clqsls3ad001w08jr3p2me04t to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_bl_pct_v4', 'jobId': 'clqsls3ad001w08jr3p2me04t'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 16:59:46.847081
# count 81
# creating tilesets for: losangelesca hispanic
# 2023-12-30 16:59:46.847238
# tilesets upload-source stobieb losangelesca_hi_cnt_src_v4 losangelesca_hi_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_hi_cnt_src_v4", "files": 1, "source_size": 23340611, "file_size": 23340611}', '']
# tilesets create stobieb.losangelesca_hi_cnt_v4 --recipe losangelesca_hi_cnt_recipe_v4.json --name losangelesca_hi_cnt_v4
# ['{"message": "stobieb.losangelesca_hi_cnt_v4 already exists"}', '']
# tilesets update-recipe stobieb.losangelesca_hi_cnt_v4 losangelesca_hi_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_hi_cnt_v4
# 2023-12-30 17:00:03.468977
# ['{"message": "Processing stobieb.losangelesca_hi_cnt_v4", "jobId": "clqslw13z002508ky5pb40y5x"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_hi_cnt_v4 or run tilesets job stobieb.losangelesca_hi_cnt_v4 clqslw13z002508ky5pb40y5x to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_hi_cnt_v4', 'jobId': 'clqslw13z002508ky5pb40y5x'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:02:18.685489
# tilesets upload-source stobieb losangelesca_hi_pct_src_v4 losangelesca_hi_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_hi_pct_src_v4", "files": 1, "source_size": 23163647, "file_size": 23163647}', '']
# tilesets create stobieb.losangelesca_hi_pct_v4 --recipe losangelesca_hi_pct_recipe_v4.json --name losangelesca_hi_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_hi_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_hi_pct_v4 losangelesca_hi_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_hi_pct_v4
# 2023-12-30 17:02:35.311106
# ['{"message": "Processing stobieb.losangelesca_hi_pct_v4", "jobId": "clqslza6e002c08lkf6sfascw"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_hi_pct_v4 or run tilesets job stobieb.losangelesca_hi_pct_v4 clqslza6e002c08lkf6sfascw to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_hi_pct_v4', 'jobId': 'clqslza6e002c08lkf6sfascw'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:05:05.663713
# count 82
# creating tilesets for: losangelesca other
# 2023-12-30 17:05:05.663987
# tilesets upload-source stobieb losangelesca_ot_cnt_src_v4 losangelesca_ot_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_ot_cnt_src_v4", "files": 1, "source_size": 23058268, "file_size": 23058268}', '']
# tilesets create stobieb.losangelesca_ot_cnt_v4 --recipe losangelesca_ot_cnt_recipe_v4.json --name losangelesca_ot_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_ot_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_ot_cnt_v4 losangelesca_ot_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_ot_cnt_v4
# 2023-12-30 17:05:22.668842
# ['{"message": "Processing stobieb.losangelesca_ot_cnt_v4", "jobId": "clqsm2vgy002k08jr4qk29c0l"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_ot_cnt_v4 or run tilesets job stobieb.losangelesca_ot_cnt_v4 clqsm2vgy002k08jr4qk29c0l to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_ot_cnt_v4', 'jobId': 'clqsm2vgy002k08jr4qk29c0l'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:08:27.614794
# tilesets upload-source stobieb losangelesca_ot_pct_src_v4 losangelesca_ot_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_ot_pct_src_v4", "files": 1, "source_size": 23113714, "file_size": 23113714}', '']
# tilesets create stobieb.losangelesca_ot_pct_v4 --recipe losangelesca_ot_pct_recipe_v4.json --name losangelesca_ot_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_ot_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_ot_pct_v4 losangelesca_ot_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_ot_pct_v4
# 2023-12-30 17:08:44.020914
# ['{"message": "Processing stobieb.losangelesca_ot_pct_v4", "jobId": "clqsm76gu002k08kycw2aameg"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_ot_pct_v4 or run tilesets job stobieb.losangelesca_ot_pct_v4 clqsm76gu002k08kycw2aameg to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_ot_pct_v4', 'jobId': 'clqsm76gu002k08kycw2aameg'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:12:02.845185
# count 83
# creating tilesets for: losangelesca white
# 2023-12-30 17:12:02.845659
# tilesets upload-source stobieb losangelesca_wh_cnt_src_v4 losangelesca_wh_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_wh_cnt_src_v4", "files": 1, "source_size": 23274725, "file_size": 23274725}', '']
# tilesets create stobieb.losangelesca_wh_cnt_v4 --recipe losangelesca_wh_cnt_recipe_v4.json --name losangelesca_wh_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_wh_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_wh_cnt_v4 losangelesca_wh_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_wh_cnt_v4
# 2023-12-30 17:12:19.225919
# ['{"message": "Processing stobieb.losangelesca_wh_cnt_v4", "jobId": "clqsmbsnx000108k002nk96d5"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_wh_cnt_v4 or run tilesets job stobieb.losangelesca_wh_cnt_v4 clqsmbsnx000108k002nk96d5 to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_wh_cnt_v4', 'jobId': 'clqsmbsnx000108k002nk96d5'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:15:06.764706
# tilesets upload-source stobieb losangelesca_wh_pct_src_v4 losangelesca_wh_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_wh_pct_src_v4", "files": 1, "source_size": 23113951, "file_size": 23113951}', '']
# tilesets create stobieb.losangelesca_wh_pct_v4 --recipe losangelesca_wh_pct_recipe_v4.json --name losangelesca_wh_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_wh_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_wh_pct_v4 losangelesca_wh_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_wh_pct_v4
# 2023-12-30 17:15:23.404564
# ['{"message": "Processing stobieb.losangelesca_wh_pct_v4", "jobId": "clqsmfqyo005u08l5dsi748nz"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_wh_pct_v4 or run tilesets job stobieb.losangelesca_wh_pct_v4 clqsmfqyo005u08l5dsi748nz to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_wh_pct_v4', 'jobId': 'clqsmfqyo005u08l5dsi748nz'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:17:54.596860
# tilesets upload-source stobieb losangelesca_labels_src_v4 losangelesca_labels_v4.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/losangelesca_labels_src_v4", "files": 1, "source_size": 966348, "file_size": 966348}', '']
# tilesets create stobieb.losangelesca_labels_v4 --recipe losangelesca_labels_recipe_v4.json --name losangelesca_labels_v4
# ['{"message": "Successfully created empty tileset stobieb.losangelesca_labels_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.losangelesca_labels_v4 losangelesca_labels_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.losangelesca_labels_v4
# 2023-12-30 17:18:05.878825
# ['{"message": "Processing stobieb.losangelesca_labels_v4", "jobId": "clqsmj86e006408l599su11ru"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.losangelesca_labels_v4 or run tilesets job stobieb.losangelesca_labels_v4 clqsmj86e006408l599su11ru to view the status of your tileset.
#
# {'message': 'Processing stobieb.losangelesca_labels_v4', 'jobId': 'clqsmj86e006408l599su11ru'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:21:08.580783
# count 84
# creating tilesets for: california all
# 2023-12-30 17:21:08.580953
# tilesets upload-source stobieb california_al_cnt_src_v4 california_al_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_al_cnt_src_v4", "files": 1, "source_size": 124107991, "file_size": 124107991}', '']
# tilesets create stobieb.california_al_cnt_v4 --recipe california_al_cnt_recipe_v4.json --name california_al_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.california_al_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_al_cnt_v4 california_al_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_al_cnt_v4
# 2023-12-30 17:21:53.261426
# ['{"message": "Processing stobieb.california_al_cnt_v4", "jobId": "clqsmo3ra000208jsdy9mg1cl"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_al_cnt_v4 or run tilesets job stobieb.california_al_cnt_v4 clqsmo3ra000208jsdy9mg1cl to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_al_cnt_v4', 'jobId': 'clqsmo3ra000208jsdy9mg1cl'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:24:40.878337
# tilesets upload-source stobieb california_al_pct_src_v4 california_al_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_al_pct_src_v4", "files": 1, "source_size": 124534276, "file_size": 124534276}', '']
# tilesets create stobieb.california_al_pct_v4 --recipe california_al_pct_recipe_v4.json --name california_al_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.california_al_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_al_pct_v4 california_al_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_al_pct_v4
# 2023-12-30 17:25:26.487636
# ['{"message": "Processing stobieb.california_al_pct_v4", "jobId": "clqsmso8e000g08l55y3j68zp"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_al_pct_v4 or run tilesets job stobieb.california_al_pct_v4 clqsmso8e000g08l55y3j68zp to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_al_pct_v4', 'jobId': 'clqsmso8e000g08l55y3j68zp'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:29:01.862488
# count 85
# creating tilesets for: california asian
# 2023-12-30 17:29:01.862633
# tilesets upload-source stobieb california_as_cnt_src_v4 california_as_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_as_cnt_src_v4", "files": 1, "source_size": 124310889, "file_size": 124310889}', '']
# tilesets create stobieb.california_as_cnt_v4 --recipe california_as_cnt_recipe_v4.json --name california_as_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.california_as_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_as_cnt_v4 california_as_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_as_cnt_v4
# 2023-12-30 17:29:46.181131
# ['{"message": "Processing stobieb.california_as_cnt_v4", "jobId": "clqsmy8jy000o08l519nf4m65"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_as_cnt_v4 or run tilesets job stobieb.california_as_cnt_v4 clqsmy8jy000o08l519nf4m65 to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_as_cnt_v4', 'jobId': 'clqsmy8jy000o08l519nf4m65'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:32:17.823699
# tilesets upload-source stobieb california_as_pct_src_v4 california_as_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_as_pct_src_v4", "files": 1, "source_size": 124269776, "file_size": 124269776}', '']
# tilesets create stobieb.california_as_pct_v4 --recipe california_as_pct_recipe_v4.json --name california_as_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.california_as_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_as_pct_v4 california_as_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_as_pct_v4
# 2023-12-30 17:33:02.462383
# ['{"message": "Processing stobieb.california_as_pct_v4", "jobId": "clqsn2g1b001908l5fczd18eb"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_as_pct_v4 or run tilesets job stobieb.california_as_pct_v4 clqsn2g1b001908l5fczd18eb to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_as_pct_v4', 'jobId': 'clqsn2g1b001908l5fczd18eb'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:35:48.982186
# count 86
# creating tilesets for: california black
# 2023-12-30 17:35:48.983187
# tilesets upload-source stobieb california_bl_cnt_src_v4 california_bl_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_bl_cnt_src_v4", "files": 1, "source_size": 123676998, "file_size": 123676998}', '']
# tilesets create stobieb.california_bl_cnt_v4 --recipe california_bl_cnt_recipe_v4.json --name california_bl_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.california_bl_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_bl_cnt_v4 california_bl_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_bl_cnt_v4
# 2023-12-30 17:36:34.162051
# ['{"message": "Processing stobieb.california_bl_cnt_v4", "jobId": "clqsn6zo3003t08lketjn3kci"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_bl_cnt_v4 or run tilesets job stobieb.california_bl_cnt_v4 clqsn6zo3003t08lketjn3kci to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_bl_cnt_v4', 'jobId': 'clqsn6zo3003t08lketjn3kci'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:38:48.790957
# tilesets upload-source stobieb california_bl_pct_src_v4 california_bl_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_bl_pct_src_v4", "files": 1, "source_size": 123743047, "file_size": 123743047}', '']
# tilesets create stobieb.california_bl_pct_v4 --recipe california_bl_pct_recipe_v4.json --name california_bl_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.california_bl_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_bl_pct_v4 california_bl_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_bl_pct_v4
# 2023-12-30 17:39:34.153650
# ['{"message": "Processing stobieb.california_bl_pct_v4", "jobId": "clqsnau7c004108lk09iqgpfg"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_bl_pct_v4 or run tilesets job stobieb.california_bl_pct_v4 clqsnau7c004108lk09iqgpfg to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_bl_pct_v4', 'jobId': 'clqsnau7c004108lk09iqgpfg'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:42:04.437912
# count 87
# creating tilesets for: california hispanic
# 2023-12-30 17:42:04.438205
# tilesets upload-source stobieb california_hi_cnt_src_v4 california_hi_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_hi_cnt_src_v4", "files": 1, "source_size": 125030151, "file_size": 125030151}', '']
# tilesets create stobieb.california_hi_cnt_v4 --recipe california_hi_cnt_recipe_v4.json --name california_hi_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.california_hi_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_hi_cnt_v4 california_hi_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_hi_cnt_v4
# 2023-12-30 17:42:49.822565
# ['{"message": "Processing stobieb.california_hi_cnt_v4", "jobId": "clqsnf15o000e08l8f51u8phh"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_hi_cnt_v4 or run tilesets job stobieb.california_hi_cnt_v4 clqsnf15o000e08l8f51u8phh to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_hi_cnt_v4', 'jobId': 'clqsnf15o000e08l8f51u8phh'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:45:20.239729
# tilesets upload-source stobieb california_hi_pct_src_v4 california_hi_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_hi_pct_src_v4", "files": 1, "source_size": 124614673, "file_size": 124614673}', '']
# tilesets create stobieb.california_hi_pct_v4 --recipe california_hi_pct_recipe_v4.json --name california_hi_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.california_hi_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_hi_pct_v4 california_hi_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_hi_pct_v4
# 2023-12-30 17:46:05.730925
# ['{"message": "Processing stobieb.california_hi_pct_v4", "jobId": "clqsnj8f6000r08l8e2fa28l6"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_hi_pct_v4 or run tilesets job stobieb.california_hi_pct_v4 clqsnj8f6000r08l8e2fa28l6 to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_hi_pct_v4', 'jobId': 'clqsnj8f6000r08l8e2fa28l6'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:49:10.533877
# count 88
# creating tilesets for: california other
# 2023-12-30 17:49:10.534157
# tilesets upload-source stobieb california_ot_cnt_src_v4 california_ot_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_ot_cnt_src_v4", "files": 1, "source_size": 124426630, "file_size": 124426630}', '']
# tilesets create stobieb.california_ot_cnt_v4 --recipe california_ot_cnt_recipe_v4.json --name california_ot_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.california_ot_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_ot_cnt_v4 california_ot_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_ot_cnt_v4
# 2023-12-30 17:49:55.446577
# ['{"message": "Processing stobieb.california_ot_cnt_v4", "jobId": "clqsno5oa000y08l898z92b22"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_ot_cnt_v4 or run tilesets job stobieb.california_ot_cnt_v4 clqsno5oa000y08l898z92b22 to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_ot_cnt_v4', 'jobId': 'clqsno5oa000y08l898z92b22'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:53:32.036498
# tilesets upload-source stobieb california_ot_pct_src_v4 california_ot_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_ot_pct_src_v4", "files": 1, "source_size": 124502646, "file_size": 124502646}', '']
# tilesets create stobieb.california_ot_pct_v4 --recipe california_ot_pct_recipe_v4.json --name california_ot_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.california_ot_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_ot_pct_v4 california_ot_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_ot_pct_v4
# 2023-12-30 17:54:16.974500
# ['{"message": "Processing stobieb.california_ot_pct_v4", "jobId": "clqsntri7000808l7e42j4766"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_ot_pct_v4 or run tilesets job stobieb.california_ot_pct_v4 clqsntri7000808l7e42j4766 to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_ot_pct_v4', 'jobId': 'clqsntri7000808l7e42j4766'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 17:56:47.708282
# count 89
# creating tilesets for: california white
# 2023-12-30 17:56:47.708434
# tilesets upload-source stobieb california_wh_cnt_src_v4 california_wh_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_wh_cnt_src_v4", "files": 1, "source_size": 125261593, "file_size": 125261593}', '']
# tilesets create stobieb.california_wh_cnt_v4 --recipe california_wh_cnt_recipe_v4.json --name california_wh_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.california_wh_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_wh_cnt_v4 california_wh_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_wh_cnt_v4
# 2023-12-30 17:57:33.489685
# ['{"message": "Processing stobieb.california_wh_cnt_v4", "jobId": "clqsny18n000008l32tnj94sc"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_wh_cnt_v4 or run tilesets job stobieb.california_wh_cnt_v4 clqsny18n000008l32tnj94sc to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_wh_cnt_v4', 'jobId': 'clqsny18n000008l32tnj94sc'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:00:56.747091
# tilesets upload-source stobieb california_wh_pct_src_v4 california_wh_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_wh_pct_src_v4", "files": 1, "source_size": 124613147, "file_size": 124613147}', '']
# tilesets create stobieb.california_wh_pct_v4 --recipe california_wh_pct_recipe_v4.json --name california_wh_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.california_wh_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_wh_pct_v4 california_wh_pct_recipe_v4.json
# [''] Traceback (most recent call last):
#   File "/Users/alanmccann/opt/anaconda3/bin/tilesets", line 8, in <module>
#     sys.exit(cli())
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/mapbox_tilesets/scripts/cli.py", line 496, in update_recipe
#     raise errors.TilesetsError(r.text)
# mapbox_tilesets.errors.TilesetsError: {"message":"stobieb.california_wh_pct_v4 does not exist."}
#
# tilesets publish stobieb.california_wh_pct_v4
# 2023-12-30 18:01:40.334778
# ['{"message": "Processing stobieb.california_wh_pct_v4", "jobId": "clqso39og000708jx4b97ayw8"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_wh_pct_v4 or run tilesets job stobieb.california_wh_pct_v4 clqso39og000708jx4b97ayw8 to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_wh_pct_v4', 'jobId': 'clqso39og000708jx4b97ayw8'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:04:11.094009
# tilesets upload-source stobieb california_labels_src_v4 california_labels_v4.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/california_labels_src_v4", "files": 1, "source_size": 2688651, "file_size": 2688651}', '']
# tilesets create stobieb.california_labels_v4 --recipe california_labels_recipe_v4.json --name california_labels_v4
# ['{"message": "Successfully created empty tileset stobieb.california_labels_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.california_labels_v4 california_labels_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.california_labels_v4
# 2023-12-30 18:04:29.548685
# ['{"message": "Processing stobieb.california_labels_v4", "jobId": "clqso6w5z000u08l77jls369t"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.california_labels_v4 or run tilesets job stobieb.california_labels_v4 clqso6w5z000u08l77jls369t to view the status of your tileset.
#
# {'message': 'Processing stobieb.california_labels_v4', 'jobId': 'clqso6w5z000u08l77jls369t'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:07:33.352254
# count 90
# creating tilesets for: texas all
# 2023-12-30 18:07:33.353294
# tilesets upload-source stobieb texas_al_cnt_src_v4 texas_al_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_al_cnt_src_v4", "files": 1, "source_size": 99708075, "file_size": 99708075}', '']
# tilesets create stobieb.texas_al_cnt_v4 --recipe texas_al_cnt_recipe_v4.json --name texas_al_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_al_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_al_cnt_v4 texas_al_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_al_cnt_v4
# 2023-12-30 18:08:08.653343
# ['{"message": "Processing stobieb.texas_al_cnt_v4", "jobId": "clqsobl4s001208l7eku12lo0"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_al_cnt_v4 or run tilesets job stobieb.texas_al_cnt_v4 clqsobl4s001208l7eku12lo0 to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_al_cnt_v4', 'jobId': 'clqsobl4s001208l7eku12lo0'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:12:22.781108
# tilesets upload-source stobieb texas_al_pct_src_v4 texas_al_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_al_pct_src_v4", "files": 1, "source_size": 99925511, "file_size": 99925511}', '']
# tilesets create stobieb.texas_al_pct_v4 --recipe texas_al_pct_recipe_v4.json --name texas_al_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_al_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_al_pct_v4 texas_al_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_al_pct_v4
# 2023-12-30 18:12:58.677779
# ['{"message": "Processing stobieb.texas_al_pct_v4", "jobId": "clqsohspw000t08jx8udvbxxr"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_al_pct_v4 or run tilesets job stobieb.texas_al_pct_v4 clqsohspw000t08jx8udvbxxr to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_al_pct_v4', 'jobId': 'clqsohspw000t08jx8udvbxxr'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:17:06.817492
# count 91
# creating tilesets for: texas asian
# 2023-12-30 18:17:06.817625
# tilesets upload-source stobieb texas_as_cnt_src_v4 texas_as_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_as_cnt_src_v4", "files": 1, "source_size": 99270268, "file_size": 99270268}', '']
# tilesets create stobieb.texas_as_cnt_v4 --recipe texas_as_cnt_recipe_v4.json --name texas_as_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_as_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_as_cnt_v4 texas_as_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_as_cnt_v4
# 2023-12-30 18:17:44.697403
# ['{"message": "Processing stobieb.texas_as_cnt_v4", "jobId": "clqsonxts000708l2496c0lsy"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_as_cnt_v4 or run tilesets job stobieb.texas_as_cnt_v4 clqsonxts000708l2496c0lsy to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_as_cnt_v4', 'jobId': 'clqsonxts000708l2496c0lsy'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:21:25.230221
# tilesets upload-source stobieb texas_as_pct_src_v4 texas_as_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_as_pct_src_v4", "files": 1, "source_size": 99287336, "file_size": 99287336}', '']
# tilesets create stobieb.texas_as_pct_v4 --recipe texas_as_pct_recipe_v4.json --name texas_as_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_as_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_as_pct_v4 texas_as_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_as_pct_v4
# 2023-12-30 18:22:01.204722
# ['{"message": "Processing stobieb.texas_as_pct_v4", "jobId": "clqsotfcs002m08k02qtfa2zx"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_as_pct_v4 or run tilesets job stobieb.texas_as_pct_v4 clqsotfcs002m08k02qtfa2zx to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_as_pct_v4', 'jobId': 'clqsotfcs002m08k02qtfa2zx'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:25:22.172803
# count 92
# creating tilesets for: texas black
# 2023-12-30 18:25:22.173107
# tilesets upload-source stobieb texas_bl_cnt_src_v4 texas_bl_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_bl_cnt_src_v4", "files": 1, "source_size": 99665344, "file_size": 99665344}', '']
# tilesets create stobieb.texas_bl_cnt_v4 --recipe texas_bl_cnt_recipe_v4.json --name texas_bl_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_bl_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_bl_cnt_v4 texas_bl_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_bl_cnt_v4
# 2023-12-30 18:26:10.404416
# ['{"message": "Processing stobieb.texas_bl_cnt_v4", "jobId": "clqsoyrpt000p08lafjs51wqc"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_bl_cnt_v4 or run tilesets job stobieb.texas_bl_cnt_v4 clqsoyrpt000p08lafjs51wqc to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_bl_cnt_v4', 'jobId': 'clqsoyrpt000p08lafjs51wqc'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:29:46.436186
# tilesets upload-source stobieb texas_bl_pct_src_v4 texas_bl_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_bl_pct_src_v4", "files": 1, "source_size": 99604448, "file_size": 99604448}', '']
# tilesets create stobieb.texas_bl_pct_v4 --recipe texas_bl_pct_recipe_v4.json --name texas_bl_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_bl_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_bl_pct_v4 texas_bl_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_bl_pct_v4
# 2023-12-30 18:30:23.158169
# ['{"message": "Processing stobieb.texas_bl_pct_v4", "jobId": "clqsp46x0001j08jlbmww401q"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_bl_pct_v4 or run tilesets job stobieb.texas_bl_pct_v4 clqsp46x0001j08jlbmww401q to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_bl_pct_v4', 'jobId': 'clqsp46x0001j08jlbmww401q'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:33:42.339974
# count 93
# creating tilesets for: texas hispanic
# 2023-12-30 18:33:42.340248
# tilesets upload-source stobieb texas_hi_cnt_src_v4 texas_hi_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_hi_cnt_src_v4", "files": 1, "source_size": 100224726, "file_size": 100224726}', '']
# tilesets create stobieb.texas_hi_cnt_v4 --recipe texas_hi_cnt_recipe_v4.json --name texas_hi_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_hi_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_hi_cnt_v4 texas_hi_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_hi_cnt_v4
# 2023-12-30 18:34:17.681972
# ['{"message": "Processing stobieb.texas_hi_cnt_v4", "jobId": "clqsp97x6001s08l7fotd9nmo"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_hi_cnt_v4 or run tilesets job stobieb.texas_hi_cnt_v4 clqsp97x6001s08l7fotd9nmo to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_hi_cnt_v4', 'jobId': 'clqsp97x6001s08l7fotd9nmo'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:38:41.852694
# tilesets upload-source stobieb texas_hi_pct_src_v4 texas_hi_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_hi_pct_src_v4", "files": 1, "source_size": 99958785, "file_size": 99958785}', '']
# tilesets create stobieb.texas_hi_pct_v4 --recipe texas_hi_pct_recipe_v4.json --name texas_hi_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_hi_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_hi_pct_v4 texas_hi_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_hi_pct_v4
# 2023-12-30 18:39:19.312393
# ['{"message": "Processing stobieb.texas_hi_pct_v4", "jobId": "clqspfobu002108l7aqzw98b5"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_hi_pct_v4 or run tilesets job stobieb.texas_hi_pct_v4 clqspfobu002108l7aqzw98b5 to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_hi_pct_v4', 'jobId': 'clqspfobu002108l7aqzw98b5'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:42:54.464156
# count 94
# creating tilesets for: texas other
# 2023-12-30 18:42:54.464295
# tilesets upload-source stobieb texas_ot_cnt_src_v4 texas_ot_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_ot_cnt_src_v4", "files": 1, "source_size": 99680052, "file_size": 99680052}', '']
# tilesets create stobieb.texas_ot_cnt_v4 --recipe texas_ot_cnt_recipe_v4.json --name texas_ot_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_ot_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_ot_cnt_v4 texas_ot_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_ot_cnt_v4
# 2023-12-30 18:43:30.276062
# ['{"message": "Processing stobieb.texas_ot_cnt_v4", "jobId": "clqspl296001608la3s6y1zs7"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_ot_cnt_v4 or run tilesets job stobieb.texas_ot_cnt_v4 clqspl296001608la3s6y1zs7 to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_ot_cnt_v4', 'jobId': 'clqspl296001608la3s6y1zs7'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:47:22.121518
# tilesets upload-source stobieb texas_ot_pct_src_v4 texas_ot_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_ot_pct_src_v4", "files": 1, "source_size": 99770907, "file_size": 99770907}', '']
# tilesets create stobieb.texas_ot_pct_v4 --recipe texas_ot_pct_recipe_v4.json --name texas_ot_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_ot_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_ot_pct_v4 texas_ot_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_ot_pct_v4
# 2023-12-30 18:47:58.869060
# ['{"message": "Processing stobieb.texas_ot_pct_v4", "jobId": "clqspqti5001m08lafz7r54a0"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_ot_pct_v4 or run tilesets job stobieb.texas_ot_pct_v4 clqspqti5001m08lafz7r54a0 to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_ot_pct_v4', 'jobId': 'clqspqti5001m08lafz7r54a0'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:52:07.427128
# count 95
# creating tilesets for: texas white
# 2023-12-30 18:52:07.427290
# tilesets upload-source stobieb texas_wh_cnt_src_v4 texas_wh_cnt_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_wh_cnt_src_v4", "files": 1, "source_size": 100395524, "file_size": 100395524}', '']
# tilesets create stobieb.texas_wh_cnt_v4 --recipe texas_wh_cnt_recipe_v4.json --name texas_wh_cnt_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_wh_cnt_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_wh_cnt_v4 texas_wh_cnt_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_wh_cnt_v4
# 2023-12-30 18:52:43.810425
# ['{"message": "Processing stobieb.texas_wh_cnt_v4", "jobId": "clqspwxer002j08l79byj0utm"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_wh_cnt_v4 or run tilesets job stobieb.texas_wh_cnt_v4 clqspwxer002j08l79byj0utm to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_wh_cnt_v4', 'jobId': 'clqspwxer002j08l79byj0utm'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 18:56:51.995316
# tilesets upload-source stobieb texas_wh_pct_src_v4 texas_wh_pct_v4.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_wh_pct_src_v4", "files": 1, "source_size": 99971700, "file_size": 99971700}', '']
# tilesets create stobieb.texas_wh_pct_v4 --recipe texas_wh_pct_recipe_v4.json --name texas_wh_pct_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_wh_pct_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_wh_pct_v4 texas_wh_pct_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_wh_pct_v4
# 2023-12-30 18:57:27.614499
# ['{"message": "Processing stobieb.texas_wh_pct_v4", "jobId": "clqsq30wc000108l160w2a2bd"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_wh_pct_v4 or run tilesets job stobieb.texas_wh_pct_v4 clqsq30wc000108l160w2a2bd to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_wh_pct_v4', 'jobId': 'clqsq30wc000108l160w2a2bd'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 19:02:09.474281
# tilesets upload-source stobieb texas_labels_src_v4 texas_labels_v4.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_labels_src_v4", "files": 1, "source_size": 1531233, "file_size": 1531233}', '']
# tilesets create stobieb.texas_labels_v4 --recipe texas_labels_recipe_v4.json --name texas_labels_v4
# ['{"message": "Successfully created empty tileset stobieb.texas_labels_v4. Publish your tileset to begin processing your data into tiles."}', '']
# tilesets update-recipe stobieb.texas_labels_v4 texas_labels_recipe_v4.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_labels_v4
# 2023-12-30 19:02:23.064457
# ['{"message": "Processing stobieb.texas_labels_v4", "jobId": "clqsq9cc8000d08jw2sgx7kmr"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_labels_v4 or run tilesets job stobieb.texas_labels_v4 clqsq9cc8000d08jw2sgx7kmr to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_labels_v4', 'jobId': 'clqsq9cc8000d08jw2sgx7kmr'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-12-30 19:05:26.486931

# %%
import csv
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/US_Geospatial_2023_Run5 brian stobie"
published_data_base_path = f'/Users/alanmccann/Dropbox/bain/mtsds-data/v{MAP_VERSION}'
csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings_v{MAP_VERSION}.csv'
market_rows = []
with open(csv_file_path, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        market_rows.append(row)

# %%
for row in market_rows:
    print(row["MarketName"],len(row["MarketName"]))
# Out:
# AbileneTX 9
# AkronOH 7
# AlbanyGA 8
# AlbanyOR 8
# AlbanyNY 8
# AlbuquerqueNM 13
# AlexandriaLA 12
# AllentownPA 11
# AltoonaPA 9
# AmarilloTX 10
# AmesIA 6
# AnchorageAK 11
# AnnArborMI 10
# AnnistonAL 10
# AppletonWI 10
# AshevilleNC 11
# AthensGA 8
# AtlantaGA 9
# AtlanticCityNJ 14
# AuburnAL 8
# AugustaGA 9
# AustinTX 8
# BakersfieldCA 13
# BaltimoreMD 11
# BangorME 8
# BarnstableTownMA 16
# BatonRougeLA 12
# BattleCreekMI 13
# BayCityMI 9
# BeaumontTX 10
# BeckleyWV 9
# BellinghamWA 12
# BendOR 6
# BillingsMT 10
# BinghamtonNY 12
# BirminghamAL 12
# BismarckND 10
# BlacksburgVA 12
# BloomingtonIL 13
# BloomingtonIN 13
# BloomsburgPA 12
# BoiseCityID 11
# BostonMA 8
# BoulderCO 9
# BowlingGreenKY 14
# BremertonWA 11
# BridgeportCT 12
# BrownsvilleTX 13
# BrunswickGA 11
# BuffaloNY 9
# BurlingtonNC 12
# BurlingtonVT 12
# CaliforniaMD 12
# CantonOH 8
# CapeCoralFL 11
# CapeGirardeauMO 15
# CarbondaleIL 12
# CarsonCityNV 12
# CasperWY 8
# CedarRapidsIA 13
# ChambersburgPA 14
# ChampaignIL 11
# CharlestonWV 12
# CharlestonSC 12
# CharlotteNC 11
# CharlottesvilleVA 17
# ChattanoogaTN 13
# CheyenneWY 10
# ChicagoIL 9
# ChicoCA 7
# CincinnatiOH 12
# ClarksvilleTN 13
# ClevelandTN 11
# ClevelandOH 11
# CoeurDaleneID 13
# CollegeStationTX 16
# ColoradoSpringsCO 17
# ColumbiaMO 10
# ColumbiaSC 10
# ColumbusGA 10
# ColumbusIN 10
# ColumbusOH 10
# CorpusChristiTX 15
# CorvallisOR 11
# CrestviewFL 11
# CumberlandMD 12
# DallasFortWorthTX 17
# DaltonGA 8
# DanvilleIL 10
# DaphneAL 8
# DavenportIA 11
# DaytonOH 8
# DecaturAL 9
# DecaturIL 9
# DeltonaFL 9
# DenverCO 8
# DesMoinesIA 11
# DetroitMI 9
# DothanAL 8
# DoverDE 7
# DubuqueIA 9
# DuluthMN 8
# DurhamNC 8
# EastStroudsburgPA 17
# EauClaireWI 11
# ElCentroCA 10
# ElPasoTX 8
# ElizabethtownKY 15
# ElkhartIN 9
# ElmiraNY 8
# EriePA 6
# EugeneOR 8
# EvansvilleIN 12
# FairbanksAK 11
# FargoND 7
# FarmingtonNM 12
# FayettevilleNC 14
# FayettevilleAR 14
# FlagstaffAZ 11
# FlintMI 7
# FlorenceSC 10
# FlorenceAL 10
# FondDuLacWI 11
# FortCollinsCO 13
# FortSmithAR 11
# FortWayneIN 11
# FresnoCA 8
# GadsdenAL 9
# GainesvilleFL 13
# GainesvilleGA 13
# GettysburgPA 12
# GlensFallsNY 12
# GoldsboroNC 11
# GrandForksND 12
# GrandIslandNE 13
# GrandJunctionCO 15
# GrandRapidsMI 13
# GrantsPassOR 12
# GreatFallsMT 12
# GreeleyCO 9
# GreenBayWI 10
# GreensboroNC 12
# GreenvilleNC 12
# GreenvilleSC 12
# GulfportMS 10
# HagerstownMD 12
# HammondLA 9
# HanfordCA 9
# HarrisburgPA 12
# HarrisonburgVA 14
# HartfordCT 10
# HattiesburgMS 13
# HickoryNC 9
# HiltonHeadIslandSC 18
# HinesvilleGA 12
# HomosassaSpringsFL 18
# HotSpringsAR 12
# HoumaLA 7
# HoustonTX 9
# HuntingtonWV 12
# HuntsvilleAL 12
# IdahoFallsID 12
# IndianapolisIN 14
# IowaCityIA 10
# IthacaNY 8
# JacksonMI 9
# JacksonMS 9
# JacksonTN 9
# JacksonvilleFL 14
# JacksonvilleNC 14
# JanesvilleWI 12
# JeffersonCityMO 15
# JohnsonCityTN 13
# JohnstownPA 11
# JonesboroAR 11
# JoplinMO 8
# KahuluiHI 9
# KalamazooMI 11
# KankakeeIL 10
# KansasCityMO 12
# KennewickWA 11
# KilleenTX 9
# KingsportTN 11
# KingstonNY 10
# KnoxvilleTN 11
# KokomoIN 8
# LaCrosseWI 10
# LafayetteLA 11
# LafayetteIN 11
# LakeCharlesLA 13
# LakeHavasuCityAZ 16
# LakelandFL 10
# LancasterPA 11
# LansingMI 9
# LaredoTX 8
# LasCrucesNM 11
# LasVegasNV 10
# LawrenceKS 10
# LawtonOK 8
# LebanonPA 9
# LewistonID 10
# LewistonME 10
# LexingtonKY 11
# LimaOH 6
# LincolnNE 9
# LittleRockAR 12
# LoganUT 7
# LongviewTX 10
# LongviewWA 10
# LosAngelesCA 12
# LouisvilleKY 12
# LubbockTX 9
# LynchburgVA 11
# MaconGA 7
# MaderaCA 8
# MadisonWI 9
# ManchesterNH 12
# ManhattanKS 11
# MankatoMN 9
# MansfieldOH 11
# McAllenTX 9
# MedfordOR 9
# MemphisTN 9
# MercedCA 8
# MiamiFL 7
# MichiganCityIN 14
# MidlandMI 9
# MidlandTX 9
# MilwaukeeWI 11
# MinneapolisMN 13
# MissoulaMT 10
# MobileAL 8
# ModestoCA 9
# MonroeLA 8
# MonroeMI 8
# MontgomeryAL 12
# MorgantownWV 12
# MorristownTN 12
# MountVernonWA 13
# MuncieIN 8
# MuskegonMI 10
# MyrtleBeachSC 13
# NapaCA 6
# NaplesFL 8
# NashvilleTN 11
# NewBernNC 9
# NewHavenCT 10
# NewOrleansLA 12
# NewYorkNY 9
# NilesMI 7
# NorthPortFL 11
# NorwichCT 9
# OcalaFL 7
# OceanCityNJ 11
# OdessaTX 8
# OgdenUT 7
# OklahomaCityOK 14
# OlympiaWA 9
# OmahaNE 7
# OrlandoFL 9
# OshkoshWI 9
# OwensboroKY 11
# OxnardCA 8
# PalmBayFL 9
# PanamaCityFL 12
# ParkersburgWV 13
# PensacolaFL 11
# PeoriaIL 8
# PhiladelphiaPA 14
# PhoenixAZ 9
# PineBluffAR 11
# PittsburghPA 12
# PittsfieldMA 12
# PocatelloID 11
# PortStLucieFL 13
# PortlandME 10
# PortlandOR 10
# PrescottAZ 10
# ProvidenceRI 12
# ProvoUT 7
# PuebloCO 8
# PuntaGordaFL 12
# RacineWI 8
# RaleighNC 9
# RapidCitySD 11
# ReadingPA 9
# ReddingCA 9
# RenoNV 6
# RichmondVA 10
# RiversideCA 11
# RoanokeVA 9
# RochesterMN 11
# RochesterNY 11
# RockfordIL 10
# RockyMountNC 12
# RomeGA 6
# SacramentoCA 12
# SaginawMI 9
# SalemOR 7
# SalinasCA 9
# SalisburyMD 11
# SaltLakeCityUT 14
# SanAngeloTX 11
# SanAntonioTX 12
# SanDiegoCA 10
# SanFranciscoCA 14
# SanJoseCA 9
# SanLuisObispoCA 15
# SantaCruzCA 11
# SantaFeNM 9
# SantaMariaCA 12
# SantaRosaCA 11
# SavannahGA 10
# ScrantonPA 10
# SeattleWA 9
# SebastianFL 11
# SebringFL 9
# SheboyganWI 11
# ShermanTX 9
# ShreveportLA 12
# SierraVistaAZ 13
# SiouxCityIA 11
# SiouxFallsSD 12
# SouthBendIN 11
# SpartanburgSC 13
# SpokaneWA 9
# SpringfieldIL 13
# SpringfieldMA 13
# SpringfieldMO 13
# SpringfieldOH 13
# StCloudMN 9
# StGeorgeUT 10
# StJosephMO 10
# StLouisMO 9
# StateCollegePA 14
# StauntonVA 10
# StocktonCA 10
# SumterSC 8
# SyracuseNY 10
# TallahasseeFL 13
# TampaFL 7
# TerreHauteIN 12
# TexarkanaTX 11
# TheVillagesFL 13
# ToledoOH 8
# TopekaKS 8
# TrentonNJ 9
# TucsonAZ 8
# TulsaOK 7
# TuscaloosaAL 12
# TylerTX 7
# UrbanHonoluluHI 15
# UticaNY 7
# ValdostaGA 10
# VallejoCA 9
# VictoriaTX 10
# VinelandNJ 10
# VirginiaBeachVA 15
# VisaliaCA 9
# WacoTX 6
# WallaWallaWA 12
# WarnerRobinsGA 14
# WashingtonDC 12
# WaterlooIA 10
# WatertownNY 11
# WausauWI 8
# WeirtonWV 9
# WenatcheeWA 11
# WheelingWV 10
# WichitaFallsTX 14
# WichitaKS 9
# WilliamsportPA 14
# WilmingtonNC 12
# WinchesterVA 12
# WinstonNC 9
# WorcesterMA 11
# YakimaWA 8
# YorkPA 6
# YoungstownOH 12
# YubaCityCA 10
# YumaAZ 6
# Alabama 7
# Alaska 6
# Arizona 7
# Arkansas 8
# California 10
# Colorado 8
# Connecticut 11
# Delaware 8
# DistrictOfColumbia 18
# Florida 7
# Georgia 7
# Hawaii 6
# Idaho 5
# Illinois 8
# Indiana 7
# Iowa 4
# Kansas 6
# Kentucky 8
# Louisiana 9
# Maine 5
# Maryland 8
# Massachusetts 13
# Michigan 8
# Minnesota 9
# Mississippi 11
# Missouri 8
# Montana 7
# Nebraska 8
# Nevada 6
# NewHampshire 12
# NewJersey 9
# NewMexico 9
# NewYork 7
# NorthCarolina 13
# NorthDakota 11
# Ohio 4
# Oklahoma 8
# Oregon 6
# Pennsylvania 12
# RhodeIsland 11
# SouthCarolina 13
# SouthDakota 11
# Tennessee 9
# Texas 5
# Utah 4
# Vermont 7
# Virginia 8
# Washington 10
# WestVirginia 12
# Wisconsin 9
# Wyoming 7

# %%
market_rows[155]['MarketName']
# Out:
# 'HomosassaSprngFL'

# %%
STATS_TYPES[:2]
# Out:
# ['Count', 'Percent']

# %%
for ethnicity in ETHNICITIES.keys():
    print(ethnicity)
# Out:
# all
# asian
# black
# hispanic
# other
# white

# %%
for stats_type in STATS_TYPES[:2]:
    print(stats_type)
# Out:
# Count
# Percent

# %%
ETHNICITIES.keys()
# Out:
# dict_keys(['all', 'asian', 'black', 'hispanic', 'other', 'white'])

# %%
market_rows
# Out:
# [{'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'}]

# %%
market_rows = []
with open(csv_file_path, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        market_rows.append(row)

# %%
market_rows
# Out:
# [{'MarketName': 'AbileneTX',
#   'Market_Display_Name': 'Abilene, TX',
#   'MapboxMarketName': 'AbileneTX',
#   'StateFips': '',
#   'CenterLat': '32.453549',
#   'CenterLong': '-99.730981',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'AshevilleNC',
#   'Market_Display_Name': 'Asheville, NC',
#   'MapboxMarketName': 'AshevilleNC',
#   'StateFips': '',
#   'CenterLat': '35.595548',
#   'CenterLong': '-82.548192',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'CharlestonSC',
#   'Market_Display_Name': 'Charleston, SC',
#   'MapboxMarketName': 'CharlestonSC',
#   'StateFips': '',
#   'CenterLat': '32.77657',
#   'CenterLong': '-79.931085',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'DallasFortWorthTX',
#   'Market_Display_Name': 'Dallas Fort Worth, TX',
#   'MapboxMarketName': 'DallasFortWorthTX',
#   'StateFips': '',
#   'CenterLat': '32.775862',
#   'CenterLong': '-96.796877',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'KnoxvilleTN',
#   'Market_Display_Name': 'Knoxville, TN',
#   'MapboxMarketName': 'KnoxvilleTN',
#   'StateFips': '',
#   'CenterLat': '35.960552',
#   'CenterLong': '-83.917405',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'LosAngelesCA',
#   'Market_Display_Name': 'Los Angeles, CA',
#   'MapboxMarketName': 'LosAngelesCA',
#   'StateFips': '',
#   'CenterLat': '34.0543',
#   'CenterLong': '-118.241929',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'NewYorkNY',
#   'Market_Display_Name': 'New York, NY',
#   'MapboxMarketName': 'NewYorkNY',
#   'StateFips': '',
#   'CenterLat': '40.71311',
#   'CenterLong': '-74.006016',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'RaleighNC',
#   'Market_Display_Name': 'Raleigh, NC',
#   'MapboxMarketName': 'RaleighNC',
#   'StateFips': '',
#   'CenterLat': '35.776891',
#   'CenterLong': '-78.640465',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'WashingtonDC',
#   'Market_Display_Name': 'Washington, DC',
#   'MapboxMarketName': 'WashingtonDC',
#   'StateFips': '',
#   'CenterLat': '38.895529',
#   'CenterLong': '-77.031564',
#   'GeoTypeGroup': '1 - Designated Metro Areas',
#   'DefaultZoomLevel': '8',
#   'InterMarketMetro': '1'},
#  {'MarketName': 'California',
#   'Market_Display_Name': 'California',
#   'MapboxMarketName': 'California',
#   'StateFips': '',
#   'CenterLat': '37.1841',
#   'CenterLong': '-119.4696',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Colorado',
#   'Market_Display_Name': 'Colorado',
#   'MapboxMarketName': 'Colorado',
#   'StateFips': '',
#   'CenterLat': '38.9972',
#   'CenterLong': '-105.5478',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Tennessee',
#   'Market_Display_Name': 'Tennessee',
#   'MapboxMarketName': 'Tennessee',
#   'StateFips': '',
#   'CenterLat': '35.858',
#   'CenterLong': '-86.3505',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Texas',
#   'Market_Display_Name': 'Texas',
#   'MapboxMarketName': 'Texas',
#   'StateFips': '',
#   'CenterLat': '31.4757',
#   'CenterLong': '-99.3312',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Virginia',
#   'Market_Display_Name': 'Virginia',
#   'MapboxMarketName': 'Virginia',
#   'StateFips': '',
#   'CenterLat': '37.5215',
#   'CenterLong': '-78.8537',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'},
#  {'MarketName': 'Wisconsin',
#   'Market_Display_Name': 'Wisconsin',
#   'MapboxMarketName': 'Wisconsin',
#   'StateFips': '',
#   'CenterLat': '44.6243',
#   'CenterLong': '-89.9941',
#   'GeoTypeGroup': '2 - States',
#   'DefaultZoomLevel': '5',
#   'InterMarketMetro': '0'}]

# %%
STATS_TYPES
# Out:
# ['Count',
#  'Percent',
#  'nshft',
#  'pshft',
#  'growth',
#  'pshftna',
#  'growthna',
#  'Labels']
