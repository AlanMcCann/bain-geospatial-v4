# %%
# Mexico
# Imports

import json
import geojson
import geopandas
import pandas as pd
import pathlib
import csv
import copy
import ast
import os
import time
from collections import OrderedDict

from geojson import Feature, Point, FeatureCollection

MAP_VERSION = 3
STATS_TYPES = ['Count','Percent','nshft'] #, 'pshft','growth', 'Labels']

# %%
# Data Notes for Brian
# Market Display Name for Mexico City needed a space 
# Add MapboxMarketName  - FIXED
# Transposed files still had BG rather than GEO  - FIXED
# San Luis Potosi - had blanks in MarketName and in file names
# Mexico City longitude wrong -99.13320799999997

# %%
#  Importing notes
# Use a map files from MX GEO 2020 Brian Stobie
# RFC 7946 warning: non-WGS84 GeoJSON output. Tip: use "-proj wgs84" to convert.
# https://mapshaper.org/
# open console in mapshaper and run the following command to output lat/long
# $ -proj wgs84

# %%
STATE_FILES = ["mexico_geo_geojson_2022_07_06.json"]
CENTER_STATE_FILES = ["geo_centers_ageb_2022_07_06.json"]

# %%
#  block_group_geojson_filename(state_name, census_year=2010)
# "geo_centers_ageb_2022_07_06.json"
def block_group_geojson_filename(state_name, census_year=2010):
    return STATE_FILES[0]

def bg_geojson_files_for_market(market_data, census_year):
    # states = market_data['states']
    # Dummy calculation for now
    states = ["mexico"]
    files = []
    for state in states:
        files.append(block_group_geojson_filename(state, census_year=census_year))
    return files

def read_geo_gson_file(file_path):
    with open(file_path) as f:
        gj = geojson.load(f)
        features = gj['features']
    print(f'Loaded {len(features)} features from {file_path}')
    return  features

def read_geojson_files(file_paths, base_path = "./"):
    features = []
    for file_path in file_paths:
        features += read_geo_gson_file(os.path.join(base_path, file_path))
    return features
    

def read_market_block_group_usage(market_file_prefix, base_path="./source_data" ):
    data_type = "geo"
    csv_file_path = mapping_data_file_path(market_file_prefix, base_path=base_path, data_type=data_type)
    data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)
    block_groups = []
    for data_row in data_rows:
        block_groups.append(data_row['GEO'])
    print(f'Loaded {len(block_groups)} block groups from {csv_file_path}')
    return block_groups
        
# market_file_prefix = 'MexicoCity'
# market_prefix= 'MexicoCity'
# MexicoCity__Mapping_GEO_Data.csv
# ./source_data/{market_file_prefix}__Mapping_GEO_Data.csv - the actual geo code data
# 
# MexicoCity__Mapping_Settings_Transposed File_GEO.csv
# ./source_data/{market_file_prefix}__Mapping_Settings_Transposed_File_GEO.csv - segment definitions for Geos


def file_type_for_data_type(data_type = "geo"):
    if data_type == "geo":
        return "GEO"
    if data_type == "zip": 
        return "Zip"
    if data_type == "bg":
        return "BG"

# MexicoCity__Mapping_GEO_Data.csv
# ./source_data/{market_file_prefix}__Mapping_GEO_Data.csv - the actual geo data
# 

# 
def mapping_data_file_path(market_file_prefix, base_path="./source_data", data_type = "geo"):
    file_type = file_type_for_data_type(data_type = data_type)
    return f'{base_path}/{market_file_prefix}_Mapping_{file_type}_Data.csv'

# MexicoCity__Mapping_Settings_Transposed File_GEO.csv
# ./source_data/{market_file_prefix}__Mapping_Settings_Transposed_File_GEO.csv - segment definitions for GEOs

def map_settings_data_file_path(market_file_prefix, base_path="./source_data", data_type = "geo"):
    file_type = file_type_for_data_type(data_type = data_type)
    return f'{base_path}/{market_file_prefix}__Mapping_Settings_Transposed File_{file_type}.csv'

def published_map_data_path(market_prefix,  data_type = "geo", published_data_base_path="/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    return f'{published_data_base_path}/{market_prefix}/data/{market_prefix}_{data_type}_data_v{MAP_VERSION}.json'

def published_map_settings_path(market_prefix,  data_type = "geo", published_data_base_path="/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    return f'{published_data_base_path}/{market_prefix.lower()}_{data_type}_settings_data_v{MAP_VERSION}.json'

def published_map_labels_path(market_prefix,  data_type = "geo", published_data_base_path="/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    return f'{published_data_base_path}/{market_prefix.lower()}_labels_v{MAP_VERSION}.json'

def read_mapping_data(market_file_prefix, base_path='./source_data', data_type='geo'):
    data_rows = []
    csv_file_path = mapping_data_file_path(market_file_prefix, base_path=base_path, data_type = data_type)
    with open(csv_file_path) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)
    print(f'Loaded {len(data_rows)} data rows from {csv_file_path}')
    return data_rows


def create_bg_features(features, map_settings_data, bg_data_rows, stats_type):
    print('create_bg_features')
    new_features_to_keep = []
    for data_row in bg_data_rows:
        block_group = str(data_row['GEOID'])
        if (len(block_group) == 12) or (len(block_group) == 8):
            block_group = '0' + block_group
        # find the associated feature
        found = False
        if block_group in features:
            found = True
            feature = features[block_group]
            new_feature = copy.deepcopy(feature)
            properties = new_feature['properties']
            properties.pop("CVE_ENT",0)
            properties.pop("CVE_MUN",0)
            properties.pop("CVE_LOC",0)
            properties.pop("CVE_AGEB",0)
            new_feature['properties'] = properties
            for key in list(data_row.keys())[0:]:
                if key not in  ['GEOID','LAT','LON'] and stats_type in key: #and 'Count' in key:
                    if data_row[key] and data_row[key] != 'inf':
                        translated_key = map_settings_data[key]['mapbox_segment']
                        value = ast.literal_eval(data_row[key].replace(',',''))
                        value = int(value * 1000000) / 1000000
                        new_feature['properties'][translated_key] =  value
                if key == 'LAT':
                    new_feature['properties']['INTPTLAT10'] = data_row[key]
                if key == 'LON':
                    new_feature['properties']['INTPTLON10'] = data_row[key]
            new_features_to_keep.append(new_feature)
    #         if found == False:
    #             print(f'failed: {block_group}')
    print(f'Processed {len(new_features_to_keep)} features to use')
    return new_features_to_keep

def create_geojson(features):
    print(f'Created GeoJson with  {len(features)} features')
    return FeatureCollection(features)


def create_data_json(features):
    data = []
    for feature in features:
        #centroid = {
        #    "GEOID10": feature["properties"]["GEOID10"],
        #    "INTPTLAT10": feature["properties"]["INTPTLAT10"],
        #    "INTPTLON10": feature["properties"]["INTPTLON10"],
        #}
        datum = feature["properties"]
        data.append(datum)
    return data

def write_geojson(geojson_data, mapbox_market_file_prefix, data_type='geo', stats_type='Count',published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    geojson_string = geojson.dumps(geojson_data, sort_keys=True)
    f = open(f'{published_data_base_path}/{mapbox_market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}.json', "w")
    f.write(geojson_string)
    f.close()
    print(f'Wrote geojson data to  {published_data_base_path}/{mapbox_market_file_prefix.lower()}/data/{mapbox_market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}.json')
    
def write_data_json(json_data, mapbox_market_file_prefix, data_type='geo', stats_type='count',published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    json_string = json.dumps(json_data, sort_keys=True)
    f = open(f'{published_data_base_path}/{mapbox_market_file_prefix.lower()}_{stats_type.lower()}_data_v{MAP_VERSION}.json', "w")
    f.write(json_string)
    f.close()
    print(f'Wrote centroid json data to  {published_data_base_path}/{mapbox_market_file_prefix.lower()}/data/{mapbox_market_file_prefix}_{stats_type.lower()}_data_v{MAP_VERSION}.json')


def read_map_settings(market_file_prefix, base_path="./source_data", data_type = "geo"):
    data_rows = []
    csv_file_path = map_settings_data_file_path(market_file_prefix, base_path=base_path, data_type = data_type)
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)
    print(f'Loaded {len(data_rows)} data rows from {csv_file_path}')   
    return data_rows

def write_settings_data(settings_data, mapbox_market_file_prefix, base_path="/Users/alanmccann/Dropbox/develop/bain-geospatial/public", data_type = "geo"):
    processed_settings_data = OrderedDict()
    segment_number = 0
    for row in settings_data:
        segment_number += 1
        if row["Display_Data_Type"] == "HH_Count":
            row["Display_Data_Type"] = "HH Count"
        mapbox_segment_key = f's{segment_number}'
        row['mapbox_segment'] = mapbox_segment_key
        processed_settings_data[row['UniqueSeriesString']] = row
    json_string = json.dumps(processed_settings_data, indent = 2, sort_keys=False)
    settings_data_file_path = published_map_settings_path(mapbox_market_file_prefix.lower(),  data_type = data_type, published_data_base_path=base_path)
    f = open(settings_data_file_path, "w")
    f.write(json_string)
    f.close()
    print(f'Wrote settings data rows to {settings_data_file_path}') 
    return processed_settings_data
    

def create_bg_labels(market_file_prefix, mapbox_market_file_prefix, base_path="./source_data" , data_type = "geo" , published_data_base_path="/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    data_rows = []
    #     csv_file_path = './DFW_Mapping_data.csv'
    csv_file_path = mapping_data_file_path(market_file_prefix.lower(), base_path=base_path, data_type = "geo")
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            data_rows.append(row)

    features = []
    for data_row in data_rows:
        feature =  { 
            "type": "Feature", 
            "properties": {
                "id": data_row['GEOID']
            },
            "geometry": { 
                "type": "Point", 
                "coordinates": [ float(data_row['LON']), float(data_row['LAT']) ]
            }
        }

        features.append(feature)
    geo_json = {
        "type": "FeatureCollection",
        "features": features
    }
    json_string = json.dumps(geo_json, indent = 2, sort_keys=True)
    output_file_path = published_map_labels_path(mapbox_market_file_prefix,  data_type , published_data_base_path=published_data_base_path)
    f = open(output_file_path, "w")
    f.write(json_string)
    f.close()
    print(f'Wrote geojson labels data to  {output_file_path}')

def create_geojson_settings(csv_file_path, published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):

    geospatial_settings = OrderedDict()
    csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings.csv'
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            row['CenterLat'] = float(row['CenterLat'])
            row['CenterLong'] = float(row['CenterLong'])
            geospatial_settings[row['MarketName']] = row
    geojson_string = json.dumps(geospatial_settings, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/mexico_geospatial_settings_v{MAP_VERSION}.json', "w+")
    f.write(geojson_string)
    f.close()
    print(f'Wrote geospatials settings data to  {published_data_base_path}/mexico_geospatial_settings_v{MAP_VERSION}.json')
    
    
def create_tileset_data_recipe_file(mapbox_market_file_prefix, published_data_base_path, stats_type):
    recipe_file_contents = {
      'version': 1,
      'layers': {
        f'{mapbox_market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}': {
          'source': f'mapbox://tileset-source/stobieb/{mapbox_market_file_prefix.lower()}_{stats_type.lower()}_src_v{MAP_VERSION}',
          'minzoom': 0,
          'maxzoom': 13,
          'tiles': {
            'layer_size': 2500
          }
        }
      }
    }

    recipe_file_path = os.path.join(published_data_base_path,f'{mapbox_market_file_prefix.lower()}_{stats_type.lower()}_recipe_v{MAP_VERSION}.json' )
    with open(recipe_file_path, 'w') as recipe_file:
        recipe_file.write(json.dumps(recipe_file_contents, indent=4))
    print(recipe_file_path)

def create_tileset_labels_recipe_file(mapbox_market_file_prefix, published_data_base_path):
    recipe_file_contents = {
      'version': 1,
      'layers': {
        f'{mapbox_market_file_prefix.lower()}_labels_v{MAP_VERSION}': {
          'source': f'mapbox://tileset-source/stobieb/{mapbox_market_file_prefix.lower()}_labels_src_v{MAP_VERSION}',
          'minzoom': 0,
          'maxzoom': 13,
            
        }
      }
    }

    recipe_file_path = os.path.join(published_data_base_path,f'{mapbox_market_file_prefix.lower()}_labels_recipe_v{MAP_VERSION}.json' )
    with open(recipe_file_path, 'w') as recipe_file:
        recipe_file.write(json.dumps(recipe_file_contents, indent=4))
    print(recipe_file_path)
# def mstds_convert_file(market_file_prefix, published_data_base_path, filetype='data'):
#     recipe_file_path = os.path.join(published_data_base_path, market_file_prefix,'labels','mts-recipe.json' )
#     market_file_prefix, published_data_base_path

# %%
# Geojson file path
geojson_files_base_path = '/Users/alanmccann/Dropbox/bain/mexico_map_source_data'
def create_nation_bg_features_json(geojson_files_base_path='/Users/alanmccann/Dropbox/bain/mexico_map_source_data'):
    nationwide_features = {}
    for file in STATE_FILES:
        print(f'processing: {file}')
        geosjon_path = os.path.join(geojson_files_base_path,file)
        features = read_geo_gson_file(geosjon_path)
        for feature in features:
            key = feature['properties']["CVEGEO"]
            nationwide_features[key] = feature
    json_string = json.dumps(nationwide_features, sort_keys=True)
    f = open(f'{geojson_files_base_path}/nationwide_bg.json', "w")
    f.write(json_string)
    f.close()
    print(f'Wrote geojson data to  {geojson_files_base_path}/nationwide_bg.json')

def read_nation_bg_features_json(geojson_files_base_path='/Users/alanmccann/Dropbox/bain/mexico_map_source_data'):
    geosjon_path = os.path.join(geojson_files_base_path,"nationwide_bg.json")
    # Opening JSON file
    f = open(geosjon_path)
    # returns JSON object as 
    # a dictionary
    features = json.load(f)
    # Closing file
    f.close()
    return features
# Different file for this?
def write_nation_bg_centroids_json(geojson_files_base_path='/Users/alanmccann/Dropbox/bain/mexico_map_source_data'):
    geosjon_path = os.path.join(geojson_files_base_path,"geo_centers_ageb_2022_07_06.json")
    features = read_nation_bg_features_json(geojson_files_base_path)
    centroids = []
    for feature in features:
        centroid = {
            "CVEGEO": feature["properties"]["CVEGEO"],
            "INTPTLAT10": feature["geometry"]["coordinates"][1],
            "INTPTLON10": feature["properties"]["coordinates"][0],
        }
        centroids.append(centroid)
    json_string = json.dumps(centroids, sort_keys=True)
    f = open(f'{geojson_files_base_path}/nationwide_bg_centroids.json', "w")
    f.write(json_string)
    f.close()
    print(f'Wrote bg centroids data to  {geojson_files_base_path}/nationwide_bg_centroids.json')

# %%
def create_chart_json(published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    csv_file_path = f'{source_data_base_path}/Chart_Data_File.csv'
    chart_data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            chart_data_rows.append(row)
    data_json = {}
    for row in chart_data_rows:
        region = row['Region']
        # segment = row['Segment']
        year = row['Year']
        urban = row['Urban']
        suburban = row['SubUrban']
        exurban = row['ExUrban']
        print(region,year)
        print(urban, suburban, exurban)
        urban = '%.10f' % float(row['Urban'])
        suburban = '%.10f' % float(row['SubUrban'])
        exurban = '%.10f' % float(row['ExUrban'])
        display_region = row['DisplayRegion']
        if region not in data_json.keys():
            data_json[region] = {'displayRegion': display_region, 'data': {}}
        if year not in data_json[region]['data'].keys():
            data_json[region]['data'][year] = {}
        if 'Urban' not in data_json[region]['data'][year].keys():
            data_json[region]['data'][year]['Urban'] = {}
            data_json[region]['data'][year]['SubUrban'] = {}
            data_json[region]['data'][year]['ExUrban'] = {}
        data_json[region]['data'][year]['Urban'] = urban
        data_json[region]['data'][year]['SubUrban'] = suburban
        data_json[region]['data'][year]['ExUrban'] = exurban
    chart_data_string = json.dumps(data_json, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/market_summary_charts_v{MAP_VERSION}.json', "w")
    f.write(chart_data_string)
    f.close()
    print(f'Wrote market summary charts data to  {published_data_base_path}/market_summary_charts_v{MAP_VERSION}.json')

# %%
def create_comparison_chart_json(published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    csv_file_path = f'{source_data_base_path}/Chart_Data_File.csv'
    chart_data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            chart_data_rows.append(row)
    data_json = {}
    for row in chart_data_rows:
        region = row['Region']
        display_region = row['DisplayRegion']
        year = row['Year']
        age_segment=row['Display_Age_Segment']
        income_segment=row['Display_Income_Segment']
        key = f'{region}-{year}-{age_segment}-{income_segment}'
        urban = row['Urban']
        suburban = row['SubUrban']
        exurban = row['ExUrban']
        print(key)
        urban = '%.10f' % float(row['Urban'])
        suburban = '%.10f' % float(row['SubUrban'])
        exurban = '%.10f' % float(row['ExUrban'])
        display_region = row['DisplayRegion']
        isMetro = row['IsMetro']
        data_json[key] = {
            "year": year,
            "ageSegment": age_segment,
            "incomeSegment": income_segment,
            "urban": urban,
            "suburban": suburban,
            "exurban": exurban,
            "isMetro": isMetro,
        }
    chart_data_string = json.dumps(data_json, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/market_comparison_charts_v{MAP_VERSION}.json', "w")
    f.write(chart_data_string)
    f.close()
    print(f'Wrote market summary charts data to  {published_data_base_path}/market_comparison_charts_v{MAP_VERSION}.json')

# %%
def create_data_options_json(published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"):
    csv_file_path = f'{source_data_base_path}/Chart_Data_File.csv'
    chart_data_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            chart_data_rows.append(row)
    year_options_set = set()
    age_segment_options_set = set()
    income_segment_options_set = set()
    region_options_list = []
    for row in chart_data_rows:
        year_options_set.add(row["Year"])
        age_segment_options_set.add(row["Display_Age_Segment"])
        income_segment_options_set.add(row["Display_Income_Segment"])
        region = {
            "region": row["Region"],
            "displayRegion": row["DisplayRegion"],
            "isMetro": row["IsMetro"],
        }
        region_options_list.append(region)
    year_options_list = list(year_options_set)
    year_options_list.sort()
    age_segment_options_list = list(age_segment_options_set)
    age_segment_options_list.sort()
    income_segment_options_list = list(income_segment_options_set)
    income_segment_options_list.sort()
    region_options = pd.DataFrame(region_options_list).drop_duplicates().to_dict('r')
    dataOptions = {
        "yearOptions": year_options_list,
        'ageSegmentOptions': age_segment_options_list,
        'incomeSegmentOptions': income_segment_options_list,
        "regionOptions": region_options
    }
    data_options_string = json.dumps(dataOptions, indent=4, sort_keys=True)
    f = open(f'{published_data_base_path}/data_options_v{MAP_VERSION}.json', "w")
    f.write(data_options_string)
    f.close()
    print(f'Wrote data options data to  {published_data_base_path}/data_options_v{MAP_VERSION}.json')

# %%
create_nation_bg_features_json()
# Out:
# processing: mexico_geo_geojson_2022_07_06.json
# Loaded 81451 features from /Users/alanmccann/Dropbox/bain/mexico_map_source_data/mexico_geo_geojson_2022_07_06.json
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mexico_map_source_data/nationwide_bg.json

# %%
def process_main_geo_data(source_data_base_path, geojson_files_base_path, published_data_base_path, census_year):
    nationwide_bg_features = read_nation_bg_features_json(geojson_files_base_path)
    csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings.csv'
    market_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            market_rows.append(row)
    market_count = 0
    completed_markets = []
    for market_data in market_rows[:1]:
        #         if market_data['MarketName'] in ['HiltonHeadIslandSC','HomosassaSpringsFL', 'DistrictOfColumbia','CharlottesvilleVA','ColoradoSpringsCO','DallasFortWorthTX','EastStroudsburgPA']:
        #             #if True:
        #             #print(market_data['MarketName'])
        if market_data['MarketName']: # in ['HiltonHeadIslandSC','HomosassaSpringsFL', 'DistrictOfColumbia','CharlottesvilleVA','ColoradoSpringsCO','DallasFortWorthTX','EastStroudsburgPA']:
            print("")
            print(f'Market Data: {market_count + 1}')
            market_file_prefix = market_data['MarketName']
            mapbox_market_file_prefix =  market_data['MapboxMarketName']
            market_prefix = market_file_prefix

            for stats_type in STATS_TYPES:
                create_tileset_data_recipe_file(mapbox_market_file_prefix.lower(), published_data_base_path,stats_type)
                create_tileset_labels_recipe_file(mapbox_market_file_prefix.lower(), published_data_base_path)
            # Block Group Processing
            data_type = 'geo'
            map_settings_data = read_map_settings(market_file_prefix, base_path=source_data_base_path, data_type = "geo")
            map_settings = write_settings_data(map_settings_data, mapbox_market_file_prefix.lower(), base_path=published_data_base_path, data_type = "geo")
            block_group_rows = read_mapping_data(market_file_prefix, source_data_base_path, data_type)
            for stats_type in STATS_TYPES:
                features_to_use = create_bg_features(nationwide_bg_features, map_settings, block_group_rows, stats_type)

                new_geojson = create_geojson(features_to_use)
                write_geojson(new_geojson, mapbox_market_file_prefix, data_type, stats_type,published_data_base_path=published_data_base_path)
                if stats_type.lower() != 'labels':
                    new_data_json = create_data_json(features_to_use)
                    write_data_json(new_data_json, mapbox_market_file_prefix.lower(),data_type, stats_type.lower(),published_data_base_path)
            create_bg_labels(market_file_prefix, mapbox_market_file_prefix, base_path=source_data_base_path , data_type = "geo" , published_data_base_path=published_data_base_path)
            market_count += 1
    # Finished states - create overall settings file    
    create_geojson_settings(csv_file_path, published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public")
    print(f'*** COMPLETED {market_count} markets')
                          
        
# source_data_base_path = "./source_data"
# source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/v5_9th_run Brian Stobie/"
# published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"
# geojson_files_base_path = '/Users/alanmccann/Dropbox/bain/map_source_data'
# census_year = 2010

# %%
# Set up input and output locations
# Geojson file path
geojson_files_base_path = '/Users/alanmccann/Dropbox/bain/mexico_map_source_data'
# Source csv data path
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/runJun14_6 Brian Stobie"
# Output data path - all of the files in this folder should be uploaded to the cms GeoSpatialTool/v1 folder
published_data_base_path = "/Users/alanmccann/Dropbox/develop/bain-geospatial/public"
published_data_base_path = '/Users/alanmccann/Dropbox/bain/mtsds-data'
# Census year for geojson
census_year = 2010


# Process the data
process_main_geo_data(source_data_base_path, geojson_files_base_path, published_data_base_path, census_year)
# create_chart_json(published_data_base_path)
# create_comparison_chart_json(published_data_base_path)
# create_data_options_json(published_data_base_path)
# Out:
# Market Data: 1
# /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_count_recipe_v3.json
# /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_labels_recipe_v3.json
# /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_percent_recipe_v3.json
# /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_labels_recipe_v3.json
# /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_nshft_recipe_v3.json
# /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_labels_recipe_v3.json
# Loaded 138 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/runJun14_6 Brian Stobie/MexicoCity__Mapping_Settings_Transposed File_GEO.csv
# Wrote settings data rows to /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_geo_settings_data_v3.json
# Loaded 5112 data rows from /Users/alanmccann/Dropbox/bain/bain-uploads/runJun14_6 Brian Stobie/MexicoCity_Mapping_GEO_Data.csv
# create_bg_features
# Processed 5112 features to use
# Created GeoJson with  5112 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity/data/mexicocity_count_v3.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity/data/mexicocity_count_data_v3.json
# create_bg_features
# Processed 5112 features to use
# Created GeoJson with  5112 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity/data/mexicocity_percent_v3.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity/data/mexicocity_percent_data_v3.json
# create_bg_features
# Processed 5112 features to use
# Created GeoJson with  5112 features
# Wrote geojson data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity/data/mexicocity_nshft_v3.json
# Wrote centroid json data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity/data/mexicocity_nshft_data_v3.json
# Wrote geojson labels data to  /Users/alanmccann/Dropbox/bain/mtsds-data/mexicocity_labels_v3.json
# Wrote geospatials settings data to  /Users/alanmccann/Dropbox/develop/bain-geospatial/public/mexico_geospatial_settings_v3.json
# *** COMPLETED 1 markets

# %%
def upload_to_mapbox(source_data_base_path,published_data_base_path):
    csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings.csv'
    market_rows = []
    with open(csv_file_path, encoding='utf-8-sig') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            market_rows.append(row)
    market_count = 0
    completed_markets = []
    for market_data in market_rows: #[0:10]:
        # if market_data['MarketName'] in ['Texas','DallasFortWorth']:
        if True:
            print("")
            print(f'Market Data: {market_count + 1}')
            market_file_prefix = market_data['MapboxMarketName'].lower()
            os.system(f'cd {published_data_base_path}; tilesets upload-source stobieb {market_file_prefix}_bg_data-src_v{MAP_VERSION} {market_file_prefix}_bg_data_v{MAP_VERSION}.json')
            os.system(f'cd {published_data_base_path};  tilesets create stobieb.{market_file_prefix}_bg_data_v{MAP_VERSION} --recipe {market_file_prefix}-bg-recipe_v{MAP_VERSION}.json --name "{market_file_prefix}_bg_data"')
            os.system(f'cd {published_data_base_path};  tilesets publish stobieb.{market_file_prefix}_bg_data_v{MAP_VERSION}')
            os.system(f'cd {published_data_base_path};  tilesets upload-source stobieb {market_file_prefix}_bg_labels-src {market_file_prefix}_bg_labels_v{MAP_VERSION}.json')
            os.system(f'cd {published_data_base_path};  tilesets create stobieb.{market_file_prefix}_bg_labels --recipe {market_file_prefix}-labels-recipe.json --name "{market_file_prefix}_bg_labels_v{MAP_VERSION}"')
            os.system(f'cd {published_data_base_path};  tilesets publish stobieb.{market_file_prefix}_bg_labels')

# %%
import os
import subprocess
import json
MAPBOX_ACCESS_TOKEN='sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'
my_env = {**os.environ, 'MAPBOX_ACCESS_TOKEN':'sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'}
published_data_base_path = '/Users/alanmccann/Dropbox/bain/mtsds-data'
import subprocess

cwd = os.getcwd()
os.chdir(published_data_base_path)

market_file_prefix = 'austin'
stats_type = 'Count'

def upload_source(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    upload_source_command = [
        'tilesets',
        'upload-source',
        'stobieb',
        f'{market_file_prefix}_{stats_type.lower()}_src_v{MAP_VERSION}',
        f'{market_file_prefix}_{stats_type.lower()}_v{MAP_VERSION}.json',
        '--replace'
    ]
    print(' '.join(upload_source_command))
    process = subprocess.Popen(upload_source_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output)

def upload_label_source(market_file_prefix, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    upload_source_command = [
        'tilesets',
        'upload-source',
        'stobieb',
        f'{market_file_prefix}_labels_src_v{MAP_VERSION}',
        f'{market_file_prefix}_labels_v{MAP_VERSION}.json',
        #'--replace'
    ]
    print(' '.join(upload_source_command))
    process = subprocess.Popen(upload_source_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output)
    
# upload_source(market_file_prefix, stats_type, published_data_base_path)

# %%
def update_recipe(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    update_recipe_command = [
        'tilesets',
        'update-recipe',
        f'stobieb.{market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}',
        f'{market_file_prefix.lower()}_{stats_type.lower()}_recipe_v{MAP_VERSION}.json',
        
    ]

    print(' '.join(update_recipe_command))
    process = subprocess.Popen(update_recipe_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    
def update_label_recipe(market_file_prefix, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    update_recipe_command = [
        'tilesets',
        'update-recipe',
        f'stobieb.{market_file_prefix.lower()}_labels_v{MAP_VERSION}',
        f'{market_file_prefix.lower()}_labels_recipe_v{MAP_VERSION}.json',
        
    ]

    print(' '.join(update_recipe_command))
    process = subprocess.Popen(update_recipe_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    
def upload_tileset(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    create_tileset_command = [
        'tilesets',
        'create',
        f'stobieb.{market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}',
        '--recipe', 
        f'{market_file_prefix.lower()}_{stats_type.lower()}_recipe_v{MAP_VERSION}.json',
        '--name',
        f'{market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}'
        
    ]

    print(' '.join(create_tileset_command))
    process = subprocess.Popen(create_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)

def upload_label_tileset(market_file_prefix, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    create_tileset_command = [
        'tilesets',
        'create',
        f'stobieb.{market_file_prefix.lower()}_labels_v{MAP_VERSION}',
        '--recipe', f'{market_file_prefix.lower()}_labels_recipe_v{MAP_VERSION}.json',
        '--name',
        f'{market_file_prefix.lower()}_labels_v{MAP_VERSION}'
        
    ]

    print(' '.join(create_tileset_command))
    process = subprocess.Popen(create_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)

# %%
import time
def publish_tileset(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    publish_tileset_command = [
        'tilesets',
        'publish',
        f'stobieb.{market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}'
    ]

    print(' '.join(publish_tileset_command))
    print(datetime.datetime.now())
    process = subprocess.Popen(publish_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    result = json.loads(output[0])
    print(result)
    get_job_status_command = [
        'tilesets',
        'job',
        f'stobieb.{market_file_prefix.lower()}_{stats_type.lower()}_v{MAP_VERSION}',
        result['jobId']
    ]
    state = 'processing'
    while state == 'processing':
        process = subprocess.Popen(get_job_status_command,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE,
                     env=my_env)

        stdout, stderr = process.communicate()
        output = stdout.decode('utf-8').split('\n')
        try:
            result = json.loads(output[0])
        except:
            result = {}
        if 'stage' in result.keys():
            state = result['stage']
        if state != 'success':
            print(f'{state}: sleeping')
            time.sleep(15)
    print('finished')
    print(datetime.datetime.now())

# %%
import time
def publish_label_tileset(market_file_prefix,working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    publish_tileset_command = [
        'tilesets',
        'publish',
        f'stobieb.{market_file_prefix.lower()}_labels_v{MAP_VERSION}'
    ]

    print(' '.join(publish_tileset_command))
    print(datetime.datetime.now())
    process = subprocess.Popen(publish_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    result = json.loads(output[0])
    print(result)
    get_job_status_command = [
        'tilesets',
        'job',
        f'stobieb.{market_file_prefix.lower()}_labels_v{MAP_VERSION}',
        result['jobId']
    ]
    state = 'processing'
    while state == 'processing':
        process = subprocess.Popen(get_job_status_command,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE,
                     env=my_env)

        stdout, stderr = process.communicate()
        output = stdout.decode('utf-8').split('\n')
        try:
            result = json.loads(output[0])
        except:
            result = {}
        if 'stage' in result.keys():
            state = result['stage']
        if state != 'success':
            print(f'{state}: sleeping')
            time.sleep(15)
    print('finished')
    print(datetime.datetime.now())

# %%
import csv
import datetime
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/runJun14_6 Brian Stobie"
published_data_base_path = '/Users/alanmccann/Dropbox/bain/mtsds-data'
csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings.csv'
market_rows = []
with open(csv_file_path, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        market_rows.append(row)
market_count = 0
completed_markets = []
STATS_TYPES = ['count','percent','nshft'] #'growth'] #['count','percent','nshft','labels','pshft']
# STATS_TYPES = ['nshft']
for market_data in market_rows[1:]: #[339:]:
    #market_data['MarketName'] in ['HiltonHeadIslandSC','HomosassaSpringsFL', 'DistrictOfColumbia','CharlottesvilleVA','ColoradoSpringsCO','DallasFortWorthTX','EastStroudsburgPA']:
    #market_file_prefix = market_data['MapboxMarketName'].lower()
    #if True: #market_data['MarketName'] in ['Texas','DallasFortWorthTX']:
    if True: #market_data['MarketName'] in ['HiltonHeadIslandSC', 'HomosassaSpringsFL', 'DistrictOfColumbia','CharlottesvilleVA','ColoradoSpringsCO','DallasFortWorthTX','EastStroudsburgPA']:
        market_file_prefix = market_data['MapboxMarketName'].lower()
        print('creating tilesets for:', market_file_prefix)
        print(datetime.datetime.now())
        for stats_type in STATS_TYPES:
            upload_source(market_file_prefix, stats_type, published_data_base_path)
            upload_tileset(market_file_prefix, stats_type, published_data_base_path)
            update_recipe(market_file_prefix, stats_type, published_data_base_path)
            publish_tileset(market_file_prefix, stats_type, published_data_base_path)
        upload_label_source(market_file_prefix, published_data_base_path)
        upload_label_tileset(market_file_prefix, published_data_base_path)
        update_label_recipe(market_file_prefix, published_data_base_path)
        publish_label_tileset(market_file_prefix, published_data_base_path)
# Out:
# creating tilesets for: monterrey
# 2023-06-15 11:56:09.529497
# tilesets upload-source stobieb monterrey_count_src_v3 monterrey_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monterrey_count_src_v3", "files": 1, "source_size": 5507202, "file_size": 5507202}', '']
# tilesets create stobieb.monterrey_count_v3 --recipe monterrey_count_recipe_v3.json --name monterrey_count_v3
# ['{"message": "stobieb.monterrey_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.monterrey_count_v3 monterrey_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monterrey_count_v3
# 2023-06-15 11:56:19.654529
# ['{"message": "Processing stobieb.monterrey_count_v3", "jobId": "clixbpltt000908mt1ynhggfc"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monterrey_count_v3 or run tilesets job stobieb.monterrey_count_v3 clixbpltt000908mt1ynhggfc to view the status of your tileset.
#
# {'message': 'Processing stobieb.monterrey_count_v3', 'jobId': 'clixbpltt000908mt1ynhggfc'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 11:57:47.012908
# tilesets upload-source stobieb monterrey_percent_src_v3 monterrey_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monterrey_percent_src_v3", "files": 1, "source_size": 5390763, "file_size": 5390763}', '']
# tilesets create stobieb.monterrey_percent_v3 --recipe monterrey_percent_recipe_v3.json --name monterrey_percent_v3
# ['{"message": "stobieb.monterrey_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.monterrey_percent_v3 monterrey_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monterrey_percent_v3
# 2023-06-15 11:57:56.242627
# ['{"message": "Processing stobieb.monterrey_percent_v3", "jobId": "clixbro4b002308l4bsq92ruq"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monterrey_percent_v3 or run tilesets job stobieb.monterrey_percent_v3 clixbro4b002308l4bsq92ruq to view the status of your tileset.
#
# {'message': 'Processing stobieb.monterrey_percent_v3', 'jobId': 'clixbro4b002308l4bsq92ruq'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:01:18.163398
# tilesets upload-source stobieb monterrey_nshft_src_v3 monterrey_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monterrey_nshft_src_v3", "files": 1, "source_size": 4945920, "file_size": 4945920}', '']
# tilesets create stobieb.monterrey_nshft_v3 --recipe monterrey_nshft_recipe_v3.json --name monterrey_nshft_v3
# ['{"message": "stobieb.monterrey_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.monterrey_nshft_v3 monterrey_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monterrey_nshft_v3
# 2023-06-15 12:01:27.483191
# ['{"message": "Processing stobieb.monterrey_nshft_v3", "jobId": "clixbw7fi000l08ms5qxm9oex"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monterrey_nshft_v3 or run tilesets job stobieb.monterrey_nshft_v3 clixbw7fi000l08ms5qxm9oex to view the status of your tileset.
#
# {'message': 'Processing stobieb.monterrey_nshft_v3', 'jobId': 'clixbw7fi000l08ms5qxm9oex'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:05:56.058325
# tilesets upload-source stobieb monterrey_labels_src_v3 monterrey_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monterrey_labels_src_v3", "files": 2, "source_size": 559774, "file_size": 282648}', '']
# tilesets create stobieb.monterrey_labels_v3 --recipe monterrey_labels_recipe_v3.json --name monterrey_labels_v3
# ['{"message": "stobieb.monterrey_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.monterrey_labels_v3 monterrey_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monterrey_labels_v3
# 2023-06-15 12:06:02.405594
# ['{"message": "Processing stobieb.monterrey_labels_v3", "jobId": "clixc236w001308msehm9gna5"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monterrey_labels_v3 or run tilesets job stobieb.monterrey_labels_v3 clixc236w001308msehm9gna5 to view the status of your tileset.
#
# {'message': 'Processing stobieb.monterrey_labels_v3', 'jobId': 'clixc236w001308msehm9gna5'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:07:28.886475
# creating tilesets for: guadalajara
# 2023-06-15 12:07:28.886711
# tilesets upload-source stobieb guadalajara_count_src_v3 guadalajara_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/guadalajara_count_src_v3", "files": 1, "source_size": 5185223, "file_size": 5185223}', '']
# tilesets create stobieb.guadalajara_count_v3 --recipe guadalajara_count_recipe_v3.json --name guadalajara_count_v3
# ['{"message": "stobieb.guadalajara_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.guadalajara_count_v3 guadalajara_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.guadalajara_count_v3
# 2023-06-15 12:07:37.584708
# ['{"message": "Processing stobieb.guadalajara_count_v3", "jobId": "clixc44xz001508ms8i6rbyrg"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.guadalajara_count_v3 or run tilesets job stobieb.guadalajara_count_v3 clixc44xz001508ms8i6rbyrg to view the status of your tileset.
#
# {'message': 'Processing stobieb.guadalajara_count_v3', 'jobId': 'clixc44xz001508ms8i6rbyrg'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:11:01.274839
# tilesets upload-source stobieb guadalajara_percent_src_v3 guadalajara_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/guadalajara_percent_src_v3", "files": 1, "source_size": 5057603, "file_size": 5057603}', '']
# tilesets create stobieb.guadalajara_percent_v3 --recipe guadalajara_percent_recipe_v3.json --name guadalajara_percent_v3
# ['{"message": "stobieb.guadalajara_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.guadalajara_percent_v3 guadalajara_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.guadalajara_percent_v3
# 2023-06-15 12:11:09.816709
# ['{"message": "Processing stobieb.guadalajara_percent_v3", "jobId": "clixc8og6001m08mse8tf3v36"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.guadalajara_percent_v3 or run tilesets job stobieb.guadalajara_percent_v3 clixc8og6001m08mse8tf3v36 to view the status of your tileset.
#
# {'message': 'Processing stobieb.guadalajara_percent_v3', 'jobId': 'clixc8og6001m08mse8tf3v36'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:14:31.233657
# tilesets upload-source stobieb guadalajara_nshft_src_v3 guadalajara_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/guadalajara_nshft_src_v3", "files": 1, "source_size": 4626308, "file_size": 4626308}', '']
# tilesets create stobieb.guadalajara_nshft_v3 --recipe guadalajara_nshft_recipe_v3.json --name guadalajara_nshft_v3
# ['{"message": "stobieb.guadalajara_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.guadalajara_nshft_v3 guadalajara_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.guadalajara_nshft_v3
# 2023-06-15 12:14:39.337723
# ['{"message": "Processing stobieb.guadalajara_nshft_v3", "jobId": "clixcd6ap000a08lcg4lafa85"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.guadalajara_nshft_v3 or run tilesets job stobieb.guadalajara_nshft_v3 clixcd6ap000a08lcg4lafa85 to view the status of your tileset.
#
# {'message': 'Processing stobieb.guadalajara_nshft_v3', 'jobId': 'clixcd6ap000a08lcg4lafa85'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:16:07.183679
# tilesets upload-source stobieb guadalajara_labels_src_v3 guadalajara_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/guadalajara_labels_src_v3", "files": 2, "source_size": 559998, "file_size": 279864}', '']
# tilesets create stobieb.guadalajara_labels_v3 --recipe guadalajara_labels_recipe_v3.json --name guadalajara_labels_v3
# ['{"message": "stobieb.guadalajara_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.guadalajara_labels_v3 guadalajara_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.guadalajara_labels_v3
# 2023-06-15 12:16:13.830894
# ['{"message": "Processing stobieb.guadalajara_labels_v3", "jobId": "clixcf7ky000k08lc893e0euq"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.guadalajara_labels_v3 or run tilesets job stobieb.guadalajara_labels_v3 clixcf7ky000k08lc893e0euq to view the status of your tileset.
#
# {'message': 'Processing stobieb.guadalajara_labels_v3', 'jobId': 'clixcf7ky000k08lc893e0euq'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:17:26.249922
# creating tilesets for: puebla-tlaxcala
# 2023-06-15 12:17:26.250052
# tilesets upload-source stobieb puebla-tlaxcala_count_src_v3 puebla-tlaxcala_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/puebla-tlaxcala_count_src_v3", "files": 1, "source_size": 5961414, "file_size": 5961414}', '']
# tilesets create stobieb.puebla-tlaxcala_count_v3 --recipe puebla-tlaxcala_count_recipe_v3.json --name puebla-tlaxcala_count_v3
# ['{"message": "Successfully created empty tileset stobieb.puebla-tlaxcala_count_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.puebla-tlaxcala_count_v3 puebla-tlaxcala_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.puebla-tlaxcala_count_v3
# 2023-06-15 12:17:36.230402
# ['{"message": "Processing stobieb.puebla-tlaxcala_count_v3", "jobId": "clixcgz5x003308l4166r2t35"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.puebla-tlaxcala_count_v3 or run tilesets job stobieb.puebla-tlaxcala_count_v3 clixcgz5x003308l4166r2t35 to view the status of your tileset.
#
# {'message': 'Processing stobieb.puebla-tlaxcala_count_v3', 'jobId': 'clixcgz5x003308l4166r2t35'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:20:59.009584
# tilesets upload-source stobieb puebla-tlaxcala_percent_src_v3 puebla-tlaxcala_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/puebla-tlaxcala_percent_src_v3", "files": 1, "source_size": 5900947, "file_size": 5900947}', '']
# tilesets create stobieb.puebla-tlaxcala_percent_v3 --recipe puebla-tlaxcala_percent_recipe_v3.json --name puebla-tlaxcala_percent_v3
# ['{"message": "Successfully created empty tileset stobieb.puebla-tlaxcala_percent_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.puebla-tlaxcala_percent_v3 puebla-tlaxcala_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.puebla-tlaxcala_percent_v3
# 2023-06-15 12:21:09.000508
# ['{"message": "Processing stobieb.puebla-tlaxcala_percent_v3", "jobId": "clixcliwe001b08lc37oldtzz"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.puebla-tlaxcala_percent_v3 or run tilesets job stobieb.puebla-tlaxcala_percent_v3 clixcliwe001b08lc37oldtzz to view the status of your tileset.
#
# {'message': 'Processing stobieb.puebla-tlaxcala_percent_v3', 'jobId': 'clixcliwe001b08lc37oldtzz'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:24:33.174416
# tilesets upload-source stobieb puebla-tlaxcala_nshft_src_v3 puebla-tlaxcala_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/puebla-tlaxcala_nshft_src_v3", "files": 1, "source_size": 5609349, "file_size": 5609349}', '']
# tilesets create stobieb.puebla-tlaxcala_nshft_v3 --recipe puebla-tlaxcala_nshft_recipe_v3.json --name puebla-tlaxcala_nshft_v3
# ['{"message": "Successfully created empty tileset stobieb.puebla-tlaxcala_nshft_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.puebla-tlaxcala_nshft_v3 puebla-tlaxcala_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.puebla-tlaxcala_nshft_v3
# 2023-06-15 12:24:43.576743
# ['{"message": "Processing stobieb.puebla-tlaxcala_nshft_v3", "jobId": "clixcq4n4003e08l47bqld53w"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.puebla-tlaxcala_nshft_v3 or run tilesets job stobieb.puebla-tlaxcala_nshft_v3 clixcq4n4003e08l47bqld53w to view the status of your tileset.
#
# {'message': 'Processing stobieb.puebla-tlaxcala_nshft_v3', 'jobId': 'clixcq4n4003e08l47bqld53w'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:28:07.241081
# tilesets upload-source stobieb puebla-tlaxcala_labels_src_v3 puebla-tlaxcala_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/puebla-tlaxcala_labels_src_v3", "files": 1, "source_size": 171843, "file_size": 171843}', '']
# tilesets create stobieb.puebla-tlaxcala_labels_v3 --recipe puebla-tlaxcala_labels_recipe_v3.json --name puebla-tlaxcala_labels_v3
# ['{"message": "Successfully created empty tileset stobieb.puebla-tlaxcala_labels_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.puebla-tlaxcala_labels_v3 puebla-tlaxcala_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.puebla-tlaxcala_labels_v3
# 2023-06-15 12:28:14.778369
# ['{"message": "Processing stobieb.puebla-tlaxcala_labels_v3", "jobId": "clixcunce001y08lceui32p2a"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.puebla-tlaxcala_labels_v3 or run tilesets job stobieb.puebla-tlaxcala_labels_v3 clixcunce001y08lceui32p2a to view the status of your tileset.
#
# {'message': 'Processing stobieb.puebla-tlaxcala_labels_v3', 'jobId': 'clixcunce001y08lceui32p2a'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:29:57.970876
# creating tilesets for: toluca
# 2023-06-15 12:29:57.971039
# tilesets upload-source stobieb toluca_count_src_v3 toluca_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/toluca_count_src_v3", "files": 1, "source_size": 3779939, "file_size": 3779939}', '']
# tilesets create stobieb.toluca_count_v3 --recipe toluca_count_recipe_v3.json --name toluca_count_v3
# ['{"message": "stobieb.toluca_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.toluca_count_v3 toluca_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.toluca_count_v3
# 2023-06-15 12:30:05.638986
# ['{"message": "Processing stobieb.toluca_count_v3", "jobId": "clixcx0qx003m08l4hbgr9oqj"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.toluca_count_v3 or run tilesets job stobieb.toluca_count_v3 clixcx0qx003m08l4hbgr9oqj to view the status of your tileset.
#
# {'message': 'Processing stobieb.toluca_count_v3', 'jobId': 'clixcx0qx003m08l4hbgr9oqj'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:33:27.582653
# tilesets upload-source stobieb toluca_percent_src_v3 toluca_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/toluca_percent_src_v3", "files": 1, "source_size": 3734777, "file_size": 3734777}', '']
# tilesets create stobieb.toluca_percent_v3 --recipe toluca_percent_recipe_v3.json --name toluca_percent_v3
# ['{"message": "stobieb.toluca_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.toluca_percent_v3 toluca_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.toluca_percent_v3
# 2023-06-15 12:33:35.501177
# ['{"message": "Processing stobieb.toluca_percent_v3", "jobId": "clixd1ioh002208l0cd7kgzzs"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.toluca_percent_v3 or run tilesets job stobieb.toluca_percent_v3 clixd1ioh002208l0cd7kgzzs to view the status of your tileset.
#
# {'message': 'Processing stobieb.toluca_percent_v3', 'jobId': 'clixd1ioh002208l0cd7kgzzs'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:35:18.544142
# tilesets upload-source stobieb toluca_nshft_src_v3 toluca_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/toluca_nshft_src_v3", "files": 1, "source_size": 3573751, "file_size": 3573751}', '']
# tilesets create stobieb.toluca_nshft_v3 --recipe toluca_nshft_recipe_v3.json --name toluca_nshft_v3
# ['{"message": "stobieb.toluca_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.toluca_nshft_v3 toluca_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.toluca_nshft_v3
# 2023-06-15 12:35:26.205575
# ['{"message": "Processing stobieb.toluca_nshft_v3", "jobId": "clixd3whw003t08l44xsy0q6r"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.toluca_nshft_v3 or run tilesets job stobieb.toluca_nshft_v3 clixd3whw003t08l44xsy0q6r to view the status of your tileset.
#
# {'message': 'Processing stobieb.toluca_nshft_v3', 'jobId': 'clixd3whw003t08l44xsy0q6r'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:36:53.920712
# tilesets upload-source stobieb toluca_labels_src_v3 toluca_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/toluca_labels_src_v3", "files": 2, "source_size": 199962, "file_size": 99981}', '']
# tilesets create stobieb.toluca_labels_v3 --recipe toluca_labels_recipe_v3.json --name toluca_labels_v3
# ['{"message": "stobieb.toluca_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.toluca_labels_v3 toluca_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.toluca_labels_v3
# 2023-06-15 12:36:59.685909
# ['{"message": "Processing stobieb.toluca_labels_v3", "jobId": "clixd5wku002v08lcdq70c24o"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.toluca_labels_v3 or run tilesets job stobieb.toluca_labels_v3 clixd5wku002v08lcdq70c24o to view the status of your tileset.
#
# {'message': 'Processing stobieb.toluca_labels_v3', 'jobId': 'clixd5wku002v08lcdq70c24o'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:40:23.122705
# creating tilesets for: tijuana
# 2023-06-15 12:40:23.122853
# tilesets upload-source stobieb tijuana_count_src_v3 tijuana_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/tijuana_count_src_v3", "files": 1, "source_size": 2660499, "file_size": 2660499}', '']
# tilesets create stobieb.tijuana_count_v3 --recipe tijuana_count_recipe_v3.json --name tijuana_count_v3
# ['{"message": "stobieb.tijuana_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.tijuana_count_v3 tijuana_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.tijuana_count_v3
# 2023-06-15 12:40:30.460241
# ['{"message": "Processing stobieb.tijuana_count_v3", "jobId": "clixdaf1b002k08l0htok6g4t"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.tijuana_count_v3 or run tilesets job stobieb.tijuana_count_v3 clixdaf1b002k08l0htok6g4t to view the status of your tileset.
#
# {'message': 'Processing stobieb.tijuana_count_v3', 'jobId': 'clixdaf1b002k08l0htok6g4t'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:44:10.108056
# tilesets upload-source stobieb tijuana_percent_src_v3 tijuana_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/tijuana_percent_src_v3", "files": 1, "source_size": 2617742, "file_size": 2617742}', '']
# tilesets create stobieb.tijuana_percent_v3 --recipe tijuana_percent_recipe_v3.json --name tijuana_percent_v3
# ['{"message": "stobieb.tijuana_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.tijuana_percent_v3 tijuana_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.tijuana_percent_v3
# 2023-06-15 12:44:17.319876
# ['{"message": "Processing stobieb.tijuana_percent_v3", "jobId": "clixdfa3i003e08lc2jyad303"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.tijuana_percent_v3 or run tilesets job stobieb.tijuana_percent_v3 clixdfa3i003e08lc2jyad303 to view the status of your tileset.
#
# {'message': 'Processing stobieb.tijuana_percent_v3', 'jobId': 'clixdfa3i003e08lc2jyad303'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:47:39.853390
# tilesets upload-source stobieb tijuana_nshft_src_v3 tijuana_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/tijuana_nshft_src_v3", "files": 1, "source_size": 2447334, "file_size": 2447334}', '']
# tilesets create stobieb.tijuana_nshft_v3 --recipe tijuana_nshft_recipe_v3.json --name tijuana_nshft_v3
# ['{"message": "stobieb.tijuana_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.tijuana_nshft_v3 tijuana_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.tijuana_nshft_v3
# 2023-06-15 12:47:47.625176
# ['{"message": "Processing stobieb.tijuana_nshft_v3", "jobId": "clixdjsl0003k08lc1seh9he5"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.tijuana_nshft_v3 or run tilesets job stobieb.tijuana_nshft_v3 clixdjsl0003k08lc1seh9he5 to view the status of your tileset.
#
# {'message': 'Processing stobieb.tijuana_nshft_v3', 'jobId': 'clixdjsl0003k08lc1seh9he5'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:49:15.863604
# tilesets upload-source stobieb tijuana_labels_src_v3 tijuana_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/tijuana_labels_src_v3", "files": 3, "source_size": 315888, "file_size": 105296}', '']
# tilesets create stobieb.tijuana_labels_v3 --recipe tijuana_labels_recipe_v3.json --name tijuana_labels_v3
# ['{"message": "stobieb.tijuana_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.tijuana_labels_v3 tijuana_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.tijuana_labels_v3
# 2023-06-15 12:49:21.851978
# ['{"message": "Processing stobieb.tijuana_labels_v3", "jobId": "clixdlvr2000008mh7xcldwpg"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.tijuana_labels_v3 or run tilesets job stobieb.tijuana_labels_v3 clixdlvr2000008mh7xcldwpg to view the status of your tileset.
#
# {'message': 'Processing stobieb.tijuana_labels_v3', 'jobId': 'clixdlvr2000008mh7xcldwpg'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:50:53.745134
# creating tilesets for: leon
# 2023-06-15 12:50:53.745364
# tilesets upload-source stobieb leon_count_src_v3 leon_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/leon_count_src_v3", "files": 1, "source_size": 2832773, "file_size": 2832773}', '']
# tilesets create stobieb.leon_count_v3 --recipe leon_count_recipe_v3.json --name leon_count_v3
# ['{"message": "stobieb.leon_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.leon_count_v3 leon_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.leon_count_v3
# 2023-06-15 12:51:01.838862
# ['{"message": "Processing stobieb.leon_count_v3", "jobId": "clixdnyaf000a08mh746o1o0v"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.leon_count_v3 or run tilesets job stobieb.leon_count_v3 clixdnyaf000a08mh746o1o0v to view the status of your tileset.
#
# {'message': 'Processing stobieb.leon_count_v3', 'jobId': 'clixdnyaf000a08mh746o1o0v'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:54:24.810969
# tilesets upload-source stobieb leon_percent_src_v3 leon_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/leon_percent_src_v3", "files": 1, "source_size": 2761589, "file_size": 2761589}', '']
# tilesets create stobieb.leon_percent_v3 --recipe leon_percent_recipe_v3.json --name leon_percent_v3
# ['{"message": "stobieb.leon_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.leon_percent_v3 leon_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.leon_percent_v3
# 2023-06-15 12:54:32.322453
# ['{"message": "Processing stobieb.leon_percent_v3", "jobId": "clixdsgmg003b08l050j0hfd3"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.leon_percent_v3 or run tilesets job stobieb.leon_percent_v3 clixdsgmg003b08l050j0hfd3 to view the status of your tileset.
#
# {'message': 'Processing stobieb.leon_percent_v3', 'jobId': 'clixdsgmg003b08l050j0hfd3'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:55:58.881271
# tilesets upload-source stobieb leon_nshft_src_v3 leon_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/leon_nshft_src_v3", "files": 1, "source_size": 2593152, "file_size": 2593152}', '']
# tilesets create stobieb.leon_nshft_v3 --recipe leon_nshft_recipe_v3.json --name leon_nshft_v3
# ['{"message": "stobieb.leon_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.leon_nshft_v3 leon_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.leon_nshft_v3
# 2023-06-15 12:56:05.990837
# ['{"message": "Processing stobieb.leon_nshft_v3", "jobId": "clixdugw3003l08l0cgey709l"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.leon_nshft_v3 or run tilesets job stobieb.leon_nshft_v3 clixdugw3003l08l0cgey709l to view the status of your tileset.
#
# {'message': 'Processing stobieb.leon_nshft_v3', 'jobId': 'clixdugw3003l08l0cgey709l'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 12:57:33.197352
# tilesets upload-source stobieb leon_labels_src_v3 leon_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/leon_labels_src_v3", "files": 3, "source_size": 364836, "file_size": 121612}', '']
# tilesets create stobieb.leon_labels_v3 --recipe leon_labels_recipe_v3.json --name leon_labels_v3
# ['{"message": "stobieb.leon_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.leon_labels_v3 leon_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.leon_labels_v3
# 2023-06-15 12:57:39.119272
# ['{"message": "Processing stobieb.leon_labels_v3", "jobId": "clixdwgs0000108jh9mgv9rwm"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.leon_labels_v3 or run tilesets job stobieb.leon_labels_v3 clixdwgs0000108jh9mgv9rwm to view the status of your tileset.
#
# {'message': 'Processing stobieb.leon_labels_v3', 'jobId': 'clixdwgs0000108jh9mgv9rwm'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:01:02.473551
# creating tilesets for: queretaro
# 2023-06-15 13:01:02.473694
# tilesets upload-source stobieb queretaro_count_src_v3 queretaro_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/queretaro_count_src_v3", "files": 1, "source_size": 2584481, "file_size": 2584481}', '']
# tilesets create stobieb.queretaro_count_v3 --recipe queretaro_count_recipe_v3.json --name queretaro_count_v3
# ['{"message": "stobieb.queretaro_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.queretaro_count_v3 queretaro_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.queretaro_count_v3
# 2023-06-15 13:01:10.246831
# ['{"message": "Processing stobieb.queretaro_count_v3", "jobId": "clixe0zqe000b08mp1gcw9dbh"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.queretaro_count_v3 or run tilesets job stobieb.queretaro_count_v3 clixe0zqe000b08mp1gcw9dbh to view the status of your tileset.
#
# {'message': 'Processing stobieb.queretaro_count_v3', 'jobId': 'clixe0zqe000b08mp1gcw9dbh'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:03:11.232380
# tilesets upload-source stobieb queretaro_percent_src_v3 queretaro_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/queretaro_percent_src_v3", "files": 1, "source_size": 2531287, "file_size": 2531287}', '']
# tilesets create stobieb.queretaro_percent_v3 --recipe queretaro_percent_recipe_v3.json --name queretaro_percent_v3
# ['{"message": "stobieb.queretaro_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.queretaro_percent_v3 queretaro_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.queretaro_percent_v3
# 2023-06-15 13:03:18.804801
# ['{"message": "Processing stobieb.queretaro_percent_v3", "jobId": "clixe3qty000t08jhdqg0asi9"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.queretaro_percent_v3 or run tilesets job stobieb.queretaro_percent_v3 clixe3qty000t08jhdqg0asi9 to view the status of your tileset.
#
# {'message': 'Processing stobieb.queretaro_percent_v3', 'jobId': 'clixe3qty000t08jhdqg0asi9'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:05:52.532198
# tilesets upload-source stobieb queretaro_nshft_src_v3 queretaro_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/queretaro_nshft_src_v3", "files": 1, "source_size": 2356505, "file_size": 2356505}', '']
# tilesets create stobieb.queretaro_nshft_v3 --recipe queretaro_nshft_recipe_v3.json --name queretaro_nshft_v3
# ['{"message": "stobieb.queretaro_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.queretaro_nshft_v3 queretaro_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.queretaro_nshft_v3
# 2023-06-15 13:05:59.778161
# ['{"message": "Processing stobieb.queretaro_nshft_v3", "jobId": "clixe790q001608jhgqvjarsw"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.queretaro_nshft_v3 or run tilesets job stobieb.queretaro_nshft_v3 clixe790q001608jhgqvjarsw to view the status of your tileset.
#
# {'message': 'Processing stobieb.queretaro_nshft_v3', 'jobId': 'clixe790q001608jhgqvjarsw'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:09:25.499007
# tilesets upload-source stobieb queretaro_labels_src_v3 queretaro_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/queretaro_labels_src_v3", "files": 2, "source_size": 230994, "file_size": 115497}', '']
# tilesets create stobieb.queretaro_labels_v3 --recipe queretaro_labels_recipe_v3.json --name queretaro_labels_v3
# ['{"message": "stobieb.queretaro_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.queretaro_labels_v3 queretaro_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.queretaro_labels_v3
# 2023-06-15 13:09:31.532058
# ['{"message": "Processing stobieb.queretaro_labels_v3", "jobId": "clixebqc4000d08me10dr3ues"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.queretaro_labels_v3 or run tilesets job stobieb.queretaro_labels_v3 clixebqc4000d08me10dr3ues to view the status of your tileset.
#
# {'message': 'Processing stobieb.queretaro_labels_v3', 'jobId': 'clixebqc4000d08me10dr3ues'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:10:41.788381
# creating tilesets for: juarez
# 2023-06-15 13:10:41.788567
# tilesets upload-source stobieb juarez_count_src_v3 juarez_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/juarez_count_src_v3", "files": 1, "source_size": 1374150, "file_size": 1374150}', '']
# tilesets create stobieb.juarez_count_v3 --recipe juarez_count_recipe_v3.json --name juarez_count_v3
# ['{"message": "Successfully created empty tileset stobieb.juarez_count_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.juarez_count_v3 juarez_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.juarez_count_v3
# 2023-06-15 13:10:50.868290
# ['{"message": "Processing stobieb.juarez_count_v3", "jobId": "clixedfk9000a09mm8lawfb52"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.juarez_count_v3 or run tilesets job stobieb.juarez_count_v3 clixedfk9000a09mm8lawfb52 to view the status of your tileset.
#
# {'message': 'Processing stobieb.juarez_count_v3', 'jobId': 'clixedfk9000a09mm8lawfb52'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:12:33.906050
# tilesets upload-source stobieb juarez_percent_src_v3 juarez_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/juarez_percent_src_v3", "files": 1, "source_size": 1309984, "file_size": 1309984}', '']
# tilesets create stobieb.juarez_percent_v3 --recipe juarez_percent_recipe_v3.json --name juarez_percent_v3
# ['{"message": "Successfully created empty tileset stobieb.juarez_percent_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.juarez_percent_v3 juarez_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.juarez_percent_v3
# 2023-06-15 13:12:41.560266
# ['{"message": "Processing stobieb.juarez_percent_v3", "jobId": "clixeft1q004208lcadci4hwa"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.juarez_percent_v3 or run tilesets job stobieb.juarez_percent_v3 clixeft1q004208lcadci4hwa to view the status of your tileset.
#
# {'message': 'Processing stobieb.juarez_percent_v3', 'jobId': 'clixeft1q004208lcadci4hwa'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:16:03.622169
# tilesets upload-source stobieb juarez_nshft_src_v3 juarez_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/juarez_nshft_src_v3", "files": 1, "source_size": 1190243, "file_size": 1190243}', '']
# tilesets create stobieb.juarez_nshft_v3 --recipe juarez_nshft_recipe_v3.json --name juarez_nshft_v3
# ['{"message": "Successfully created empty tileset stobieb.juarez_nshft_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.juarez_nshft_v3 juarez_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.juarez_nshft_v3
# 2023-06-15 13:16:11.115083
# ['{"message": "Processing stobieb.juarez_nshft_v3", "jobId": "clixekau8004o08lc9frw5tzn"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.juarez_nshft_v3 or run tilesets job stobieb.juarez_nshft_v3 clixekau8004o08lc9frw5tzn to view the status of your tileset.
#
# {'message': 'Processing stobieb.juarez_nshft_v3', 'jobId': 'clixekau8004o08lc9frw5tzn'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:19:33.891969
# tilesets upload-source stobieb juarez_labels_src_v3 juarez_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/juarez_labels_src_v3", "files": 1, "source_size": 91535, "file_size": 91535}', '']
# tilesets create stobieb.juarez_labels_v3 --recipe juarez_labels_recipe_v3.json --name juarez_labels_v3
# ['{"message": "Successfully created empty tileset stobieb.juarez_labels_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.juarez_labels_v3 juarez_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.juarez_labels_v3
# 2023-06-15 13:19:40.728883
# ['{"message": "Processing stobieb.juarez_labels_v3", "jobId": "clixeosi7001q08jh5j952fwh"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.juarez_labels_v3 or run tilesets job stobieb.juarez_labels_v3 clixeosi7001q08jh5j952fwh to view the status of your tileset.
#
# {'message': 'Processing stobieb.juarez_labels_v3', 'jobId': 'clixeosi7001q08jh5j952fwh'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:21:07.590880
# creating tilesets for: lalaguna
# 2023-06-15 13:21:07.591039
# tilesets upload-source stobieb lalaguna_count_src_v3 lalaguna_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/lalaguna_count_src_v3", "files": 1, "source_size": 1830964, "file_size": 1830964}', '']
# tilesets create stobieb.lalaguna_count_v3 --recipe lalaguna_count_recipe_v3.json --name lalaguna_count_v3
# ['{"message": "Successfully created empty tileset stobieb.lalaguna_count_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.lalaguna_count_v3 lalaguna_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.lalaguna_count_v3
# 2023-06-15 13:21:15.254409
# ['{"message": "Processing stobieb.lalaguna_count_v3", "jobId": "clixeqtns000n08me3kih3gzo"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.lalaguna_count_v3 or run tilesets job stobieb.lalaguna_count_v3 clixeqtns000n08me3kih3gzo to view the status of your tileset.
#
# {'message': 'Processing stobieb.lalaguna_count_v3', 'jobId': 'clixeqtns000n08me3kih3gzo'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:25:27.150523
# tilesets upload-source stobieb lalaguna_percent_src_v3 lalaguna_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/lalaguna_percent_src_v3", "files": 1, "source_size": 1746083, "file_size": 1746083}', '']
# tilesets create stobieb.lalaguna_percent_v3 --recipe lalaguna_percent_recipe_v3.json --name lalaguna_percent_v3
# ['{"message": "Successfully created empty tileset stobieb.lalaguna_percent_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.lalaguna_percent_v3 lalaguna_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.lalaguna_percent_v3
# 2023-06-15 13:25:35.993306
# ['{"message": "Processing stobieb.lalaguna_percent_v3", "jobId": "clixewern002f08jh600ab78t"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.lalaguna_percent_v3 or run tilesets job stobieb.lalaguna_percent_v3 clixewern002f08jh600ab78t to view the status of your tileset.
#
# {'message': 'Processing stobieb.lalaguna_percent_v3', 'jobId': 'clixewern002f08jh600ab78t'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:31:29.630283
# tilesets upload-source stobieb lalaguna_nshft_src_v3 lalaguna_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/lalaguna_nshft_src_v3", "files": 1, "source_size": 1618569, "file_size": 1618569}', '']
# tilesets create stobieb.lalaguna_nshft_v3 --recipe lalaguna_nshft_recipe_v3.json --name lalaguna_nshft_v3
# ['{"message": "Successfully created empty tileset stobieb.lalaguna_nshft_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.lalaguna_nshft_v3 lalaguna_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.lalaguna_nshft_v3
# 2023-06-15 13:31:39.066522
# ['{"message": "Processing stobieb.lalaguna_nshft_v3", "jobId": "clixf47md000108l38c7o75u0"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.lalaguna_nshft_v3 or run tilesets job stobieb.lalaguna_nshft_v3 clixf47md000108l38c7o75u0 to view the status of your tileset.
#
# {'message': 'Processing stobieb.lalaguna_nshft_v3', 'jobId': 'clixf47md000108l38c7o75u0'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:35:52.022788
# tilesets upload-source stobieb lalaguna_labels_src_v3 lalaguna_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/lalaguna_labels_src_v3", "files": 1, "source_size": 107934, "file_size": 107934}', '']
# tilesets create stobieb.lalaguna_labels_v3 --recipe lalaguna_labels_recipe_v3.json --name lalaguna_labels_v3
# ['{"message": "Successfully created empty tileset stobieb.lalaguna_labels_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.lalaguna_labels_v3 lalaguna_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.lalaguna_labels_v3
# 2023-06-15 13:35:58.988058
# ['{"message": "Processing stobieb.lalaguna_labels_v3", "jobId": "clixf9rhf005k08lc95i63585"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.lalaguna_labels_v3 or run tilesets job stobieb.lalaguna_labels_v3 clixf9rhf005k08lc95i63585 to view the status of your tileset.
#
# {'message': 'Processing stobieb.lalaguna_labels_v3', 'jobId': 'clixf9rhf005k08lc95i63585'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:39:22.422830
# creating tilesets for: merida
# 2023-06-15 13:39:22.423005
# tilesets upload-source stobieb merida_count_src_v3 merida_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/merida_count_src_v3", "files": 1, "source_size": 1981829, "file_size": 1981829}', '']
# tilesets create stobieb.merida_count_v3 --recipe merida_count_recipe_v3.json --name merida_count_v3
# ['{"message": "stobieb.merida_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.merida_count_v3 merida_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.merida_count_v3
# 2023-06-15 13:39:29.083846
# ['{"message": "Processing stobieb.merida_count_v3", "jobId": "clixfe9lw001c08me5jwggc55"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.merida_count_v3 or run tilesets job stobieb.merida_count_v3 clixfe9lw001c08me5jwggc55 to view the status of your tileset.
#
# {'message': 'Processing stobieb.merida_count_v3', 'jobId': 'clixfe9lw001c08me5jwggc55'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:43:08.589797
# tilesets upload-source stobieb merida_percent_src_v3 merida_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/merida_percent_src_v3", "files": 1, "source_size": 1917698, "file_size": 1917698}', '']
# tilesets create stobieb.merida_percent_v3 --recipe merida_percent_recipe_v3.json --name merida_percent_v3
# ['{"message": "stobieb.merida_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.merida_percent_v3 merida_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.merida_percent_v3
# 2023-06-15 13:43:15.311644
# ['{"message": "Processing stobieb.merida_percent_v3", "jobId": "clixfj3xj001j08me73jd501x"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.merida_percent_v3 or run tilesets job stobieb.merida_percent_v3 clixfj3xj001j08me73jd501x to view the status of your tileset.
#
# {'message': 'Processing stobieb.merida_percent_v3', 'jobId': 'clixfj3xj001j08me73jd501x'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 13:44:58.307726
# tilesets upload-source stobieb merida_nshft_src_v3 merida_nshft_v3.json --replace
# ...
# [''] Updated recipe.
#
# tilesets publish stobieb.nogales_count_v3
# 2023-06-15 16:42:28.056366
# ['{"message": "Processing stobieb.nogales_count_v3", "jobId": "clixlxl0n001r08l65fnc3oo5"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.nogales_count_v3 or run tilesets job stobieb.nogales_count_v3 clixlxl0n001r08l65fnc3oo5 to view the status of your tileset.
#
# {'message': 'Processing stobieb.nogales_count_v3', 'jobId': 'clixlxl0n001r08l65fnc3oo5'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 16:43:55.852707
# tilesets upload-source stobieb nogales_percent_src_v3 nogales_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/nogales_percent_src_v3", "files": 1, "source_size": 517348, "file_size": 517348}', '']
# tilesets create stobieb.nogales_percent_v3 --recipe nogales_percent_recipe_v3.json --name nogales_percent_v3
# ['{"message": "Successfully created empty tileset stobieb.nogales_percent_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.nogales_percent_v3 nogales_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.nogales_percent_v3
# 2023-06-15 16:44:02.957482
# ['{"message": "Processing stobieb.nogales_percent_v3", "jobId": "clixlzm2q004o08l496j25qg3"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.nogales_percent_v3 or run tilesets job stobieb.nogales_percent_v3 clixlzm2q004o08l496j25qg3 to view the status of your tileset.
#
# {'message': 'Processing stobieb.nogales_percent_v3', 'jobId': 'clixlzm2q004o08l496j25qg3'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 16:47:44.277732
# tilesets upload-source stobieb nogales_nshft_src_v3 nogales_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/nogales_nshft_src_v3", "files": 1, "source_size": 474118, "file_size": 474118}', '']
# tilesets create stobieb.nogales_nshft_v3 --recipe nogales_nshft_recipe_v3.json --name nogales_nshft_v3
# ['{"message": "Successfully created empty tileset stobieb.nogales_nshft_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.nogales_nshft_v3 nogales_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.nogales_nshft_v3
# 2023-06-15 16:47:51.441905
# ['{"message": "Processing stobieb.nogales_nshft_v3", "jobId": "clixm4ihq001v08l656ic053t"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.nogales_nshft_v3 or run tilesets job stobieb.nogales_nshft_v3 clixm4ihq001v08l656ic053t to view the status of your tileset.
#
# {'message': 'Processing stobieb.nogales_nshft_v3', 'jobId': 'clixm4ihq001v08l656ic053t'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 16:51:16.044799
# tilesets upload-source stobieb nogales_labels_src_v3 nogales_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/nogales_labels_src_v3", "files": 1, "source_size": 31598, "file_size": 31598}', '']
# tilesets create stobieb.nogales_labels_v3 --recipe nogales_labels_recipe_v3.json --name nogales_labels_v3
# ['{"message": "Successfully created empty tileset stobieb.nogales_labels_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.nogales_labels_v3 nogales_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.nogales_labels_v3
# 2023-06-15 16:51:22.545413
# ['{"message": "Processing stobieb.nogales_labels_v3", "jobId": "clixm91kn000708lgd1y9g0xz"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.nogales_labels_v3 or run tilesets job stobieb.nogales_labels_v3 clixm91kn000708lgd1y9g0xz to view the status of your tileset.
#
# {'message': 'Processing stobieb.nogales_labels_v3', 'jobId': 'clixm91kn000708lgd1y9g0xz'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 16:55:18.446442
# creating tilesets for: monclova
# 2023-06-15 16:55:18.446601
# tilesets upload-source stobieb monclova_count_src_v3 monclova_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monclova_count_src_v3", "files": 1, "source_size": 703116, "file_size": 703116}', '']
# tilesets create stobieb.monclova_count_v3 --recipe monclova_count_recipe_v3.json --name monclova_count_v3
# ['{"message": "Successfully created empty tileset stobieb.monclova_count_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.monclova_count_v3 monclova_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monclova_count_v3
# 2023-06-15 16:55:25.889565
# ['{"message": "Processing stobieb.monclova_count_v3", "jobId": "clixme908002j08l6fkv7356v"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monclova_count_v3 or run tilesets job stobieb.monclova_count_v3 clixme908002j08l6fkv7356v to view the status of your tileset.
#
# {'message': 'Processing stobieb.monclova_count_v3', 'jobId': 'clixme908002j08l6fkv7356v'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 16:58:47.670956
# tilesets upload-source stobieb monclova_percent_src_v3 monclova_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monclova_percent_src_v3", "files": 1, "source_size": 681833, "file_size": 681833}', '']
# tilesets create stobieb.monclova_percent_v3 --recipe monclova_percent_recipe_v3.json --name monclova_percent_v3
# ['{"message": "Successfully created empty tileset stobieb.monclova_percent_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.monclova_percent_v3 monclova_percent_recipe_v3.json
# [''] Traceback (most recent call last):
#   File "/Users/alanmccann/opt/anaconda3/bin/tilesets", line 8, in <module>
#     sys.exit(cli())
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/mapbox_tilesets/scripts/cli.py", line 496, in update_recipe
#     raise errors.TilesetsError(r.text)
# mapbox_tilesets.errors.TilesetsError: {"message":"stobieb.monclova_percent_v3 does not exist."}
#
# tilesets publish stobieb.monclova_percent_v3
# 2023-06-15 16:58:54.366670
# ['{"message": "Processing stobieb.monclova_percent_v3", "jobId": "clixmipwp001408l8ata89xyb"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monclova_percent_v3 or run tilesets job stobieb.monclova_percent_v3 clixmipwp001408l8ata89xyb to view the status of your tileset.
#
# {'message': 'Processing stobieb.monclova_percent_v3', 'jobId': 'clixmipwp001408l8ata89xyb'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:00:37.387309
# tilesets upload-source stobieb monclova_nshft_src_v3 monclova_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monclova_nshft_src_v3", "files": 1, "source_size": 627426, "file_size": 627426}', '']
# tilesets create stobieb.monclova_nshft_v3 --recipe monclova_nshft_recipe_v3.json --name monclova_nshft_v3
# ['{"message": "Successfully created empty tileset stobieb.monclova_nshft_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.monclova_nshft_v3 monclova_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monclova_nshft_v3
# 2023-06-15 17:00:44.761272
# ['{"message": "Processing stobieb.monclova_nshft_v3", "jobId": "clixml31i003108l6dexlc2kr"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monclova_nshft_v3 or run tilesets job stobieb.monclova_nshft_v3 clixml31i003108l6dexlc2kr to view the status of your tileset.
#
# {'message': 'Processing stobieb.monclova_nshft_v3', 'jobId': 'clixml31i003108l6dexlc2kr'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:04:24.978516
# tilesets upload-source stobieb monclova_labels_src_v3 monclova_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/monclova_labels_src_v3", "files": 1, "source_size": 38305, "file_size": 38305}', '']
# tilesets create stobieb.monclova_labels_v3 --recipe monclova_labels_recipe_v3.json --name monclova_labels_v3
# ['{"message": "Successfully created empty tileset stobieb.monclova_labels_v3. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.monclova_labels_v3 monclova_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.monclova_labels_v3
# 2023-06-15 17:04:32.392793
# ['{"message": "Processing stobieb.monclova_labels_v3", "jobId": "clixmpytv003e08l6142w5od9"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.monclova_labels_v3 or run tilesets job stobieb.monclova_labels_v3 clixmpytv003e08l6142w5od9 to view the status of your tileset.
#
# {'message': 'Processing stobieb.monclova_labels_v3', 'jobId': 'clixmpytv003e08l6142w5od9'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:07:57.678165
# creating tilesets for: mexico
# 2023-06-15 17:07:57.678315
# tilesets upload-source stobieb mexico_count_src_v3 mexico_count_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/mexico_count_src_v3", "files": 1, "source_size": 353028199, "file_size": 353028199}', '']
# tilesets create stobieb.mexico_count_v3 --recipe mexico_count_recipe_v3.json --name mexico_count_v3
# ['{"message": "stobieb.mexico_count_v3 already exists"}', '']
# tilesets update-recipe stobieb.mexico_count_v3 mexico_count_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.mexico_count_v3
# 2023-06-15 17:10:11.703680
# ['{"message": "Processing stobieb.mexico_count_v3", "jobId": "clixmx8tm000308jle3t34de7"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.mexico_count_v3 or run tilesets job stobieb.mexico_count_v3 clixmx8tm000308jle3t34de7 to view the status of your tileset.
#
# {'message': 'Processing stobieb.mexico_count_v3', 'jobId': 'clixmx8tm000308jle3t34de7'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:11:56.008972
# tilesets upload-source stobieb mexico_percent_src_v3 mexico_percent_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/mexico_percent_src_v3", "files": 1, "source_size": 346077230, "file_size": 346077230}', '']
# tilesets create stobieb.mexico_percent_v3 --recipe mexico_percent_recipe_v3.json --name mexico_percent_v3
# ['{"message": "stobieb.mexico_percent_v3 already exists"}', '']
# tilesets update-recipe stobieb.mexico_percent_v3 mexico_percent_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.mexico_percent_v3
# 2023-06-15 17:14:07.273920
# ['{"message": "Processing stobieb.mexico_percent_v3", "jobId": "clixn2ak2000c08mr6lu36s6h"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.mexico_percent_v3 or run tilesets job stobieb.mexico_percent_v3 clixn2ak2000c08mr6lu36s6h to view the status of your tileset.
#
# {'message': 'Processing stobieb.mexico_percent_v3', 'jobId': 'clixn2ak2000c08mr6lu36s6h'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:15:51.070720
# tilesets upload-source stobieb mexico_nshft_src_v3 mexico_nshft_v3.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/mexico_nshft_src_v3", "files": 1, "source_size": 331446900, "file_size": 331446900}', '']
# tilesets create stobieb.mexico_nshft_v3 --recipe mexico_nshft_recipe_v3.json --name mexico_nshft_v3
# ['{"message": "stobieb.mexico_nshft_v3 already exists"}', '']
# tilesets update-recipe stobieb.mexico_nshft_v3 mexico_nshft_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.mexico_nshft_v3
# 2023-06-15 17:18:06.505453
# ['{"message": "Processing stobieb.mexico_nshft_v3", "jobId": "clixn7eyi000808i92jcjbhj4"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.mexico_nshft_v3 or run tilesets job stobieb.mexico_nshft_v3 clixn7eyi000808i92jcjbhj4 to view the status of your tileset.
#
# {'message': 'Processing stobieb.mexico_nshft_v3', 'jobId': 'clixn7eyi000808i92jcjbhj4'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:20:06.872995
# tilesets upload-source stobieb mexico_labels_src_v3 mexico_labels_v3.json
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/mexico_labels_src_v3", "files": 2, "source_size": 21860216, "file_size": 10930108}', '']
# tilesets create stobieb.mexico_labels_v3 --recipe mexico_labels_recipe_v3.json --name mexico_labels_v3
# ['{"message": "stobieb.mexico_labels_v3 already exists"}', '']
# tilesets update-recipe stobieb.mexico_labels_v3 mexico_labels_recipe_v3.json
# [''] Updated recipe.
#
# tilesets publish stobieb.mexico_labels_v3
# 2023-06-15 17:20:56.849559
# ['{"message": "Processing stobieb.mexico_labels_v3", "jobId": "clixnb2b5000o08jl926p926h"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.mexico_labels_v3 or run tilesets job stobieb.mexico_labels_v3 clixnb2b5000o08jl926p926h to view the status of your tileset.
#
# {'message': 'Processing stobieb.mexico_labels_v3', 'jobId': 'clixnb2b5000o08jl926p926h'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2023-06-15 17:26:32.561827
