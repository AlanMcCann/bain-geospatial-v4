# %%
# Imports

import json
import geojson
import geopandas
import pandas as pd
import pathlib
import csv
import copy
import ast
import os
import time
from collections import OrderedDict

from geojson import Feature, Point, FeatureCollection

MAP_VERSION = 3
STATS_TYPES = ['Count','Percent','nshft', 'pshft', 'growth',"Labels"]

import os
import subprocess
import json
MAPBOX_ACCESS_TOKEN='sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'
my_env = {**os.environ, 'MAPBOX_ACCESS_TOKEN':'sk.eyJ1Ijoic3RvYmllYiIsImEiOiJjbDR2dDlibHkwODhjM2lub3EwOXJld2dzIn0.Ur59yGDIvj60ELA7QOCnqQ'}
published_data_base_path = '/Users/alanmccann/Dropbox/bain/mtsds-data'
import subprocess

cwd = os.getcwd()
os.chdir(published_data_base_path)

market_file_prefix = 'austin'
stats_type = 'Count'

def upload_source(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    upload_source_command = [
        'tilesets',
        'upload-source',
        'stobieb',
        f'{market_file_prefix}_{stats_type.lower()}_src',
        f'{market_file_prefix}_{stats_type.lower()}.json',
        '--replace'
    ]
    print(' '.join(upload_source_command))
    process = subprocess.Popen(upload_source_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output)

def upload_label_source(market_file_prefix, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
    upload_source_command = [
        'tilesets',
        'upload-source',
        'stobieb',
        f'{market_file_prefix}_labels_src',
        f'{market_file_prefix}_labels.json',
        #'--replace'
    ]
    print(' '.join(upload_source_command))
    process = subprocess.Popen(upload_source_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output)
    
# upload_source(market_file_prefix, stats_type, published_data_base_path)

def update_recipe(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    update_recipe_command = [
        'tilesets',
        'update-recipe',
        f'stobieb.{market_file_prefix}_{stats_type.lower()}',
        f'{market_file_prefix}_{stats_type.lower()}_recipe.json',
        
    ]

    print(' '.join(update_recipe_command))
    process = subprocess.Popen(update_recipe_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    
def upload_tileset(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    create_tileset_command = [
        'tilesets',
        'create',
        f'stobieb.{market_file_prefix}_{stats_type.lower()}',
        '--recipe', 
        f'{market_file_prefix}_{stats_type.lower()}_recipe.json',
        '--name',
        f'{market_file_prefix}_{stats_type.lower()}'
        
    ]

    print(' '.join(create_tileset_command))
    process = subprocess.Popen(create_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)

def upload_label_tileset(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    create_tileset_command = [
        'tilesets',
        'create',
        f'stobieb.{market_file_prefix}_{stats_type.lower()}',
        '--recipe', f'{market_file_prefix}_{stats_type.lower()}_recipe.json',
        '--name',
        f'{market_file_prefix}_{stats_type.lower()}'
        
    ]

    print(' '.join(create_tileset_command))
    process = subprocess.Popen(create_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)

import time
def publish_tileset(market_file_prefix, stats_type, working_directory):
    cwd = os.getcwd()
    os.chdir(working_directory)
                # print(f'tilesets create stobieb.{market_file_prefix}_bg_{stats_type.lower()}_data --recipe {market_file_prefix}_bg_{stats_type.lower()}_recipe.json --name "{market_file_prefix}_bg_{stats_type.lower()}_data"')
    publish_tileset_command = [
        'tilesets',
        'publish',
        f'stobieb.{market_file_prefix}_{stats_type.lower()}'
    ]

    print(' '.join(publish_tileset_command))
    print(datetime.datetime.now())
    process = subprocess.Popen(publish_tileset_command,
                         stdout=subprocess.PIPE, 
                         stderr=subprocess.PIPE,
                         env=my_env)

    stdout, stderr = process.communicate()
    output = stdout.decode('utf-8').split('\n')
    error = stderr.decode('utf-8')
    print(output, error)
    result = json.loads(output[0])
    print(result)
    get_job_status_command = [
        'tilesets',
        'job',
        f'stobieb.{market_file_prefix}_{stats_type.lower()}',
        result['jobId']
    ]
    state = 'processing'
    while state == 'processing':
        process = subprocess.Popen(get_job_status_command,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE,
                     env=my_env)

        stdout, stderr = process.communicate()
        output = stdout.decode('utf-8').split('\n')
        try:
            result = json.loads(output[0])
        except:
            result = {}
        if 'stage' in result.keys():
            state = result['stage']
        if state != 'success':
            print(f'{state}: sleeping')
            time.sleep(15)
    print('finished')
    print(datetime.datetime.now())

# %%
import csv
import datetime
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/v6_4th_run Brian Stobie"
published_data_base_path = '/Users/alanmccann/Dropbox/bain/mtsds-data'
csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings.csv'
market_rows = []
with open(csv_file_path, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        market_rows.append(row)
market_count = 0
completed_markets = []
# STATS_TYPES = ['Count','Percent','nshft','Labels', 'pshft','growth']
# STATS_TYPES = [ 'pshft','growth']
STATS_TYPES = [ 'growth']
# Dallas market_rows[86:87]
# Texas market_rows[424:425]
for market_data in market_rows: # [424:425]:
    market_file_prefix = market_data['MarketName'].lower()
    # if market_data['MarketName'] in ['Texas','DallasFortWorth']:
    print('creating tilesets for:', market_file_prefix)
    print(datetime.datetime.now())
    for stats_type in STATS_TYPES:
        upload_source(market_file_prefix, stats_type, published_data_base_path)
        upload_tileset(market_file_prefix, stats_type, published_data_base_path)
        update_recipe(market_file_prefix, stats_type, published_data_base_path)
        publish_tileset(market_file_prefix, stats_type, published_data_base_path)
# Out:
# creating tilesets for: abilenetx
# 2022-12-07 08:51:12.496561
# tilesets upload-source stobieb abilenetx_growth_src abilenetx_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/abilenetx_growth_src", "files": 1, "source_size": 1134844, "file_size": 1134844}', '']
# tilesets create stobieb.abilenetx_growth --recipe abilenetx_growth_recipe.json --name abilenetx_growth
# ['{"message": "stobieb.abilenetx_growth already exists"}', '']
# tilesets update-recipe stobieb.abilenetx_growth abilenetx_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.abilenetx_growth
# 2022-12-07 08:51:19.567078
# ['{"message": "Processing stobieb.abilenetx_growth", "jobId": "clbdpl01o000608l9d7hrfsxa"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.abilenetx_growth or run tilesets job stobieb.abilenetx_growth clbdpl01o000608l9d7hrfsxa to view the status of your tileset.
#
# {'message': 'Processing stobieb.abilenetx_growth', 'jobId': 'clbdpl01o000608l9d7hrfsxa'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 08:52:46.556121
# creating tilesets for: akronoh
# 2022-12-07 08:52:46.556339
# tilesets upload-source stobieb akronoh_growth_src akronoh_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/akronoh_growth_src", "files": 1, "source_size": 1916832, "file_size": 1916832}', '']
# tilesets create stobieb.akronoh_growth --recipe akronoh_growth_recipe.json --name akronoh_growth
# ['{"message": "stobieb.akronoh_growth already exists"}', '']
# tilesets update-recipe stobieb.akronoh_growth akronoh_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.akronoh_growth
# 2022-12-07 08:52:53.667329
# ['{"message": "Processing stobieb.akronoh_growth", "jobId": "clbdpn0gh002p08mj6w6vbbw3"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.akronoh_growth or run tilesets job stobieb.akronoh_growth clbdpn0gh002p08mj6w6vbbw3 to view the status of your tileset.
#
# {'message': 'Processing stobieb.akronoh_growth', 'jobId': 'clbdpn0gh002p08mj6w6vbbw3'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 08:54:20.091645
# creating tilesets for: albanyga
# 2022-12-07 08:54:20.091787
# tilesets upload-source stobieb albanyga_growth_src albanyga_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/albanyga_growth_src", "files": 1, "source_size": 1283982, "file_size": 1283982}', '']
# tilesets create stobieb.albanyga_growth --recipe albanyga_growth_recipe.json --name albanyga_growth
# ['{"message": "stobieb.albanyga_growth already exists"}', '']
# tilesets update-recipe stobieb.albanyga_growth albanyga_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.albanyga_growth
# 2022-12-07 08:54:26.991339
# ['{"message": "Processing stobieb.albanyga_growth", "jobId": "clbdpp0g4000z08mra4vt4580"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.albanyga_growth or run tilesets job stobieb.albanyga_growth clbdpp0g4000z08mra4vt4580 to view the status of your tileset.
#
# {'message': 'Processing stobieb.albanyga_growth', 'jobId': 'clbdpp0g4000z08mra4vt4580'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 08:56:10.066473
# creating tilesets for: albanyor
# 2022-12-07 08:56:10.066592
# tilesets upload-source stobieb albanyor_growth_src albanyor_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/albanyor_growth_src", "files": 1, "source_size": 1417013, "file_size": 1417013}', '']
# tilesets create stobieb.albanyor_growth --recipe albanyor_growth_recipe.json --name albanyor_growth
# ['{"message": "stobieb.albanyor_growth already exists"}', '']
# tilesets update-recipe stobieb.albanyor_growth albanyor_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.albanyor_growth
# 2022-12-07 08:56:16.777216
# ['{"message": "Processing stobieb.albanyor_growth", "jobId": "clbdprdln000308mg78rx7unl"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.albanyor_growth or run tilesets job stobieb.albanyor_growth clbdprdln000308mg78rx7unl to view the status of your tileset.
#
# {'message': 'Processing stobieb.albanyor_growth', 'jobId': 'clbdprdln000308mg78rx7unl'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 08:57:44.826329
# creating tilesets for: albanyny
# 2022-12-07 08:57:44.826460
# tilesets upload-source stobieb albanyny_growth_src albanyny_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/albanyny_growth_src", "files": 1, "source_size": 2867671, "file_size": 2867671}', '']
# tilesets create stobieb.albanyny_growth --recipe albanyny_growth_recipe.json --name albanyny_growth
# ['{"message": "stobieb.albanyny_growth already exists"}', '']
# tilesets update-recipe stobieb.albanyny_growth albanyny_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.albanyny_growth
# 2022-12-07 08:57:52.443358
# ['{"message": "Processing stobieb.albanyny_growth", "jobId": "clbdptf6o002z08mjbt3wcrc4"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.albanyny_growth or run tilesets job stobieb.albanyny_growth clbdptf6o002z08mjbt3wcrc4 to view the status of your tileset.
#
# {'message': 'Processing stobieb.albanyny_growth', 'jobId': 'clbdptf6o002z08mjbt3wcrc4'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 08:59:35.315075
# creating tilesets for: albuquerquenm
# 2022-12-07 08:59:35.315215
# tilesets upload-source stobieb albuquerquenm_growth_src albuquerquenm_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/albuquerquenm_growth_src", "files": 1, "source_size": 3026347, "file_size": 3026347}', '']
# tilesets create stobieb.albuquerquenm_growth --recipe albuquerquenm_growth_recipe.json --name albuquerquenm_growth
# ['{"message": "stobieb.albuquerquenm_growth already exists"}', '']
# tilesets update-recipe stobieb.albuquerquenm_growth albuquerquenm_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.albuquerquenm_growth
# 2022-12-07 08:59:42.969498
# ['{"message": "Processing stobieb.albuquerquenm_growth", "jobId": "clbdpvsbc001w08mg9i3x8hbm"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.albuquerquenm_growth or run tilesets job stobieb.albuquerquenm_growth clbdpvsbc001w08mg9i3x8hbm to view the status of your tileset.
#
# {'message': 'Processing stobieb.albuquerquenm_growth', 'jobId': 'clbdpvsbc001w08mg9i3x8hbm'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:01:25.932188
# creating tilesets for: alexandriala
# 2022-12-07 09:01:25.932320
# tilesets upload-source stobieb alexandriala_growth_src alexandriala_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/alexandriala_growth_src", "files": 1, "source_size": 1831323, "file_size": 1831323}', '']
# tilesets create stobieb.alexandriala_growth --recipe alexandriala_growth_recipe.json --name alexandriala_growth
# ['{"message": "stobieb.alexandriala_growth already exists"}', '']
# tilesets update-recipe stobieb.alexandriala_growth alexandriala_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.alexandriala_growth
# 2022-12-07 09:01:32.351618
# ['{"message": "Processing stobieb.alexandriala_growth", "jobId": "clbdpy4qy000809mgfpuda0gr"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.alexandriala_growth or run tilesets job stobieb.alexandriala_growth clbdpy4qy000809mgfpuda0gr to view the status of your tileset.
#
# {'message': 'Processing stobieb.alexandriala_growth', 'jobId': 'clbdpy4qy000809mgfpuda0gr'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:02:59.554038
# creating tilesets for: allentownpa
# 2022-12-07 09:02:59.554158
# tilesets upload-source stobieb allentownpa_growth_src allentownpa_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/allentownpa_growth_src", "files": 1, "source_size": 3016001, "file_size": 3016001}', '']
# tilesets create stobieb.allentownpa_growth --recipe allentownpa_growth_recipe.json --name allentownpa_growth
# ['{"message": "stobieb.allentownpa_growth already exists"}', '']
# tilesets update-recipe stobieb.allentownpa_growth allentownpa_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.allentownpa_growth
# 2022-12-07 09:03:06.751431
# ['{"message": "Processing stobieb.allentownpa_growth", "jobId": "clbdq064v003908mkbfgtg2uu"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.allentownpa_growth or run tilesets job stobieb.allentownpa_growth clbdq064v003908mkbfgtg2uu to view the status of your tileset.
#
# {'message': 'Processing stobieb.allentownpa_growth', 'jobId': 'clbdq064v003908mkbfgtg2uu'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:05:07.454348
# creating tilesets for: altoonapa
# 2022-12-07 09:05:07.454467
# tilesets upload-source stobieb altoonapa_growth_src altoonapa_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/altoonapa_growth_src", "files": 1, "source_size": 889209, "file_size": 889209}', '']
# tilesets create stobieb.altoonapa_growth --recipe altoonapa_growth_recipe.json --name altoonapa_growth
# ['{"message": "stobieb.altoonapa_growth already exists"}', '']
# tilesets update-recipe stobieb.altoonapa_growth altoonapa_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.altoonapa_growth
# 2022-12-07 09:05:13.755210
# ['{"message": "Processing stobieb.altoonapa_growth", "jobId": "clbdq2xb5000i09mga9bxfpx8"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.altoonapa_growth or run tilesets job stobieb.altoonapa_growth clbdq2xb5000i09mga9bxfpx8 to view the status of your tileset.
#
# {'message': 'Processing stobieb.altoonapa_growth', 'jobId': 'clbdq2xb5000i09mga9bxfpx8'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:06:59.340328
# creating tilesets for: amarillotx
# 2022-12-07 09:06:59.340448
# tilesets upload-source stobieb amarillotx_growth_src amarillotx_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/amarillotx_growth_src", "files": 1, "source_size": 890159, "file_size": 890159}', '']
# tilesets create stobieb.amarillotx_growth --recipe amarillotx_growth_recipe.json --name amarillotx_growth
# ['{"message": "stobieb.amarillotx_growth already exists"}', '']
# tilesets update-recipe stobieb.amarillotx_growth amarillotx_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.amarillotx_growth
# 2022-12-07 09:07:05.989796
# ['{"message": "Processing stobieb.amarillotx_growth", "jobId": "clbdq5a87003a08mj3ith3tq6"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.amarillotx_growth or run tilesets job stobieb.amarillotx_growth clbdq5a87003a08mj3ith3tq6 to view the status of your tileset.
#
# {'message': 'Processing stobieb.amarillotx_growth', 'jobId': 'clbdq5a87003a08mj3ith3tq6'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:08:32.518117
# creating tilesets for: amesia
# 2022-12-07 09:08:32.518242
# tilesets upload-source stobieb amesia_growth_src amesia_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/amesia_growth_src", "files": 1, "source_size": 247698, "file_size": 247698}', '']
# tilesets create stobieb.amesia_growth --recipe amesia_growth_recipe.json --name amesia_growth
# ['{"message": "stobieb.amesia_growth already exists"}', '']
# tilesets update-recipe stobieb.amesia_growth amesia_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.amesia_growth
# 2022-12-07 09:08:38.736324
# ['{"message": "Processing stobieb.amesia_growth", "jobId": "clbdq79tb003p08mk0ebdaszo"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.amesia_growth or run tilesets job stobieb.amesia_growth clbdq79tb003p08mk0ebdaszo to view the status of your tileset.
#
# {'message': 'Processing stobieb.amesia_growth', 'jobId': 'clbdq79tb003p08mk0ebdaszo'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:10:21.289559
# creating tilesets for: anchorageak
# 2022-12-07 09:10:21.290083
# tilesets upload-source stobieb anchorageak_growth_src anchorageak_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/anchorageak_growth_src", "files": 1, "source_size": 2076464, "file_size": 2076464}', '']
# tilesets create stobieb.anchorageak_growth --recipe anchorageak_growth_recipe.json --name anchorageak_growth
# ['{"message": "stobieb.anchorageak_growth already exists"}', '']
# tilesets update-recipe stobieb.anchorageak_growth anchorageak_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.anchorageak_growth
# 2022-12-07 09:10:28.812665
# ['{"message": "Processing stobieb.anchorageak_growth", "jobId": "clbdq9mmt000908mg737d327t"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.anchorageak_growth or run tilesets job stobieb.anchorageak_growth clbdq9mmt000908mg737d327t to view the status of your tileset.
#
# {'message': 'Processing stobieb.anchorageak_growth', 'jobId': 'clbdq9mmt000908mg737d327t'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:12:27.354026
# creating tilesets for: annarbormi
# 2022-12-07 09:12:27.354159
# tilesets upload-source stobieb annarbormi_growth_src annarbormi_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/annarbormi_growth_src", "files": 1, "source_size": 669988, "file_size": 669988}', '']
# tilesets create stobieb.annarbormi_growth --recipe annarbormi_growth_recipe.json --name annarbormi_growth
# ['{"message": "stobieb.annarbormi_growth already exists"}', '']
# tilesets update-recipe stobieb.annarbormi_growth annarbormi_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.annarbormi_growth
# 2022-12-07 09:12:33.932579
# ['{"message": "Processing stobieb.annarbormi_growth", "jobId": "clbdqcb5f001g08lbhr1q4uav"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.annarbormi_growth or run tilesets job stobieb.annarbormi_growth clbdqcb5f001g08lbhr1q4uav to view the status of your tileset.
#
# {'message': 'Processing stobieb.annarbormi_growth', 'jobId': 'clbdqcb5f001g08lbhr1q4uav'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:14:33.194946
# creating tilesets for: annistonal
# 2022-12-07 09:14:33.195079
# tilesets upload-source stobieb annistonal_growth_src annistonal_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/annistonal_growth_src", "files": 1, "source_size": 712128, "file_size": 712128}', '']
# tilesets create stobieb.annistonal_growth --recipe annistonal_growth_recipe.json --name annistonal_growth
# ['{"message": "stobieb.annistonal_growth already exists"}', '']
# tilesets update-recipe stobieb.annistonal_growth annistonal_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.annistonal_growth
# 2022-12-07 09:14:39.603075
# ['{"message": "Processing stobieb.annistonal_growth", "jobId": "clbdqf02t000a08mg3c8ffno4"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.annistonal_growth or run tilesets job stobieb.annistonal_growth clbdqf02t000a08mg3c8ffno4 to view the status of your tileset.
#
# {'message': 'Processing stobieb.annistonal_growth', 'jobId': 'clbdqf02t000a08mg3c8ffno4'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:16:22.661471
# creating tilesets for: appletonwi
# 2022-12-07 09:16:22.661608
# tilesets upload-source stobieb appletonwi_growth_src appletonwi_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/appletonwi_growth_src", "files": 1, "source_size": 606072, "file_size": 606072}', '']
# tilesets create stobieb.appletonwi_growth --recipe appletonwi_growth_recipe.json --name appletonwi_growth
# ['{"message": "Successfully created empty tileset stobieb.appletonwi_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.appletonwi_growth appletonwi_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.appletonwi_growth
# 2022-12-07 09:16:29.795177
# ['{"message": "Processing stobieb.appletonwi_growth", "jobId": "clbdqhd1y001r08lbfxpmg7fh"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.appletonwi_growth or run tilesets job stobieb.appletonwi_growth clbdqhd1y001r08lbfxpmg7fh to view the status of your tileset.
#
# {'message': 'Processing stobieb.appletonwi_growth', 'jobId': 'clbdqhd1y001r08lbfxpmg7fh'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:17:55.599879
# creating tilesets for: ashevillenc
# 2022-12-07 09:17:55.599999
# tilesets upload-source stobieb ashevillenc_growth_src ashevillenc_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/ashevillenc_growth_src", "files": 1, "source_size": 4611562, "file_size": 4611562}', '']
# tilesets create stobieb.ashevillenc_growth --recipe ashevillenc_growth_recipe.json --name ashevillenc_growth
# ['{"message": "Successfully created empty tileset stobieb.ashevillenc_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.ashevillenc_growth ashevillenc_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.ashevillenc_growth
# 2022-12-07 09:18:03.816874
# ['{"message": "Processing stobieb.ashevillenc_growth", "jobId": "clbdqjdpl001t08lbfkgw8p0a"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.ashevillenc_growth or run tilesets job stobieb.ashevillenc_growth clbdqjdpl001t08lbfkgw8p0a to view the status of your tileset.
#
# {'message': 'Processing stobieb.ashevillenc_growth', 'jobId': 'clbdqjdpl001t08lbfkgw8p0a'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:19:30.402580
# creating tilesets for: athensga
# 2022-12-07 09:19:30.402730
# tilesets upload-source stobieb athensga_growth_src athensga_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/athensga_growth_src", "files": 1, "source_size": 1111270, "file_size": 1111270}', '']
# tilesets create stobieb.athensga_growth --recipe athensga_growth_recipe.json --name athensga_growth
# ['{"message": "Successfully created empty tileset stobieb.athensga_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.athensga_growth athensga_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.athensga_growth
# 2022-12-07 09:19:39.646546
# ['{"message": "Processing stobieb.athensga_growth", "jobId": "clbdqlfk8003t08mj1knx5mgm"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.athensga_growth or run tilesets job stobieb.athensga_growth clbdqlfk8003t08mj1knx5mgm to view the status of your tileset.
#
# {'message': 'Processing stobieb.athensga_growth', 'jobId': 'clbdqlfk8003t08mj1knx5mgm'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:21:06.071456
# creating tilesets for: atlantaga
# 2022-12-07 09:21:06.071574
# tilesets upload-source stobieb atlantaga_growth_src atlantaga_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/atlantaga_growth_src", "files": 1, "source_size": 16333604, "file_size": 16333604}', '']
# tilesets create stobieb.atlantaga_growth --recipe atlantaga_growth_recipe.json --name atlantaga_growth
# ['{"message": "Successfully created empty tileset stobieb.atlantaga_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.atlantaga_growth atlantaga_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.atlantaga_growth
# 2022-12-07 09:21:18.523118
# ['{"message": "Processing stobieb.atlantaga_growth", "jobId": "clbdqnjwk003z08mj56a1a38y"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.atlantaga_growth or run tilesets job stobieb.atlantaga_growth clbdqnjwk003z08mj56a1a38y to view the status of your tileset.
#
# {'message': 'Processing stobieb.atlantaga_growth', 'jobId': 'clbdqnjwk003z08mj56a1a38y'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:22:45.925491
# creating tilesets for: atlanticcitynj
# 2022-12-07 09:22:45.925601
# tilesets upload-source stobieb atlanticcitynj_growth_src atlanticcitynj_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/atlanticcitynj_growth_src", "files": 1, "source_size": 886397, "file_size": 886397}', '']
# tilesets create stobieb.atlanticcitynj_growth --recipe atlanticcitynj_growth_recipe.json --name atlanticcitynj_growth
# ['{"message": "Successfully created empty tileset stobieb.atlanticcitynj_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.atlanticcitynj_growth atlanticcitynj_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.atlanticcitynj_growth
# 2022-12-07 09:22:56.147438
# ['{"message": "Processing stobieb.atlanticcitynj_growth", "jobId": "clbdqpn7j000108mmfyy8bwmm"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.atlanticcitynj_growth or run tilesets job stobieb.atlanticcitynj_growth clbdqpn7j000108mmfyy8bwmm to view the status of your tileset.
#
# {'message': 'Processing stobieb.atlanticcitynj_growth', 'jobId': 'clbdqpn7j000108mmfyy8bwmm'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:24:23.918973
# creating tilesets for: auburnal
# 2022-12-07 09:24:23.919085
# tilesets upload-source stobieb auburnal_growth_src auburnal_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/auburnal_growth_src", "files": 1, "source_size": 590612, "file_size": 590612}', '']
# tilesets create stobieb.auburnal_growth --recipe auburnal_growth_recipe.json --name auburnal_growth
# ['{"message": "Successfully created empty tileset stobieb.auburnal_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.auburnal_growth auburnal_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.auburnal_growth
# 2022-12-07 09:24:30.870166
# ['{"message": "Processing stobieb.auburnal_growth", "jobId": "clbdqroa5000a08mm7m2i2yk4"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.auburnal_growth or run tilesets job stobieb.auburnal_growth clbdqroa5000a08mm7m2i2yk4 to view the status of your tileset.
#
# {'message': 'Processing stobieb.auburnal_growth', 'jobId': 'clbdqroa5000a08mm7m2i2yk4'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:26:45.441779
# creating tilesets for: augustaga
# 2022-12-07 09:26:45.442586
# tilesets upload-source stobieb augustaga_growth_src augustaga_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/augustaga_growth_src", "files": 1, "source_size": 4069522, "file_size": 4069522}', '']
# tilesets create stobieb.augustaga_growth --recipe augustaga_growth_recipe.json --name augustaga_growth
# ['{"message": "Successfully created empty tileset stobieb.augustaga_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.augustaga_growth augustaga_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.augustaga_growth
# 2022-12-07 09:26:54.629303
# ['{"message": "Processing stobieb.augustaga_growth", "jobId": "clbdqure4000c08mmb4me976n"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.augustaga_growth or run tilesets job stobieb.augustaga_growth clbdqure4000c08mmb4me976n to view the status of your tileset.
#
# {'message': 'Processing stobieb.augustaga_growth', 'jobId': 'clbdqure4000c08mmb4me976n'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:28:38.285471
# creating tilesets for: austintx
# 2022-12-07 09:28:38.285611
# tilesets upload-source stobieb austintx_growth_src austintx_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/austintx_growth_src", "files": 1, "source_size": 5824037, "file_size": 5824037}', '']
# tilesets create stobieb.austintx_growth --recipe austintx_growth_recipe.json --name austintx_growth
# ['{"message": "Successfully created empty tileset stobieb.austintx_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.austintx_growth austintx_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.austintx_growth
# 2022-12-07 09:28:48.510471
# ['{"message": "Processing stobieb.austintx_growth", "jobId": "clbdqx787000208ky8g6h5935"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.austintx_growth or run tilesets job stobieb.austintx_growth clbdqx787000208ky8g6h5935 to view the status of your tileset.
#
# {'message': 'Processing stobieb.austintx_growth', 'jobId': 'clbdqx787000208ky8g6h5935'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:30:15.716930
# creating tilesets for: bakersfieldca
# 2022-12-07 09:30:15.717123
# tilesets upload-source stobieb bakersfieldca_growth_src bakersfieldca_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/bakersfieldca_growth_src", "files": 1, "source_size": 2791306, "file_size": 2791306}', '']
# tilesets create stobieb.bakersfieldca_growth --recipe bakersfieldca_growth_recipe.json --name bakersfieldca_growth
# ['{"message": "Successfully created empty tileset stobieb.bakersfieldca_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.bakersfieldca_growth bakersfieldca_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.bakersfieldca_growth
# 2022-12-07 09:30:24.243633
# ['{"message": "Processing stobieb.bakersfieldca_growth", "jobId": "clbdqz9pw000308mi719saekw"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.bakersfieldca_growth or run tilesets job stobieb.bakersfieldca_growth clbdqz9pw000308mi719saekw to view the status of your tileset.
#
# {'message': 'Processing stobieb.bakersfieldca_growth', 'jobId': 'clbdqz9pw000308mi719saekw'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:32:26.834852
# creating tilesets for: baltimoremd
# 2022-12-07 09:32:26.834967
# tilesets upload-source stobieb baltimoremd_growth_src baltimoremd_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/baltimoremd_growth_src", "files": 1, "source_size": 9650912, "file_size": 9650912}', '']
# tilesets create stobieb.baltimoremd_growth --recipe baltimoremd_growth_recipe.json --name baltimoremd_growth
# ['{"message": "Successfully created empty tileset stobieb.baltimoremd_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.baltimoremd_growth baltimoremd_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.baltimoremd_growth
# 2022-12-07 09:32:39.471882
# ['{"message": "Processing stobieb.baltimoremd_growth", "jobId": "clbdr25en000a08miasdtfdcc"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.baltimoremd_growth or run tilesets job stobieb.baltimoremd_growth clbdr25en000a08miasdtfdcc to view the status of your tileset.
#
# {'message': 'Processing stobieb.baltimoremd_growth', 'jobId': 'clbdr25en000a08miasdtfdcc'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:34:05.701226
# creating tilesets for: bangorme
# 2022-12-07 09:34:05.701377
# tilesets upload-source stobieb bangorme_growth_src bangorme_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/bangorme_growth_src", "files": 1, "source_size": 1314642, "file_size": 1314642}', '']
# tilesets create stobieb.bangorme_growth --recipe bangorme_growth_recipe.json --name bangorme_growth
# ['{"message": "Successfully created empty tileset stobieb.bangorme_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.bangorme_growth bangorme_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.bangorme_growth
# 2022-12-07 09:34:13.456521
# ['{"message": "Processing stobieb.bangorme_growth", "jobId": "clbdr45mn000h08mi3qw46iln"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.bangorme_growth or run tilesets job stobieb.bangorme_growth clbdr45mn000h08mi3qw46iln to view the status of your tileset.
#
# {'message': 'Processing stobieb.bangorme_growth', 'jobId': 'clbdr45mn000h08mi3qw46iln'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:35:57.018015
# creating tilesets for: barnstabletownma
# 2022-12-07 09:35:57.018144
# tilesets upload-source stobieb barnstabletownma_growth_src barnstabletownma_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/barnstabletownma_growth_src", "files": 1, "source_size": 1355435, "file_size": 1355435}', '']
# tilesets create stobieb.barnstabletownma_growth --recipe barnstabletownma_growth_recipe.json --name barnstabletownma_growth
# ['{"message": "Successfully created empty tileset stobieb.barnstabletownma_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.barnstabletownma_growth barnstabletownma_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.barnstabletownma_growth
# 2022-12-07 09:36:05.671164
# ['{"message": "Processing stobieb.barnstabletownma_growth", "jobId": "clbdr6kbi000808jv1lpl84uk"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.barnstabletownma_growth or run tilesets job stobieb.barnstabletownma_growth clbdr6kbi000808jv1lpl84uk to view the status of your tileset.
#
# {'message': 'Processing stobieb.barnstabletownma_growth', 'jobId': 'clbdr6kbi000808jv1lpl84uk'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:37:32.184392
# creating tilesets for: batonrougela
# 2022-12-07 09:37:32.184520
# tilesets upload-source stobieb batonrougela_growth_src batonrougela_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/batonrougela_growth_src", "files": 1, "source_size": 3989704, "file_size": 3989704}', '']
# tilesets create stobieb.batonrougela_growth --recipe batonrougela_growth_recipe.json --name batonrougela_growth
# ['{"message": "Successfully created empty tileset stobieb.batonrougela_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.batonrougela_growth batonrougela_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.batonrougela_growth
# 2022-12-07 09:37:40.684856
# ['{"message": "Processing stobieb.batonrougela_growth", "jobId": "clbdr8lsi000a08jvag677eat"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.batonrougela_growth or run tilesets job stobieb.batonrougela_growth clbdr8lsi000a08jvag677eat to view the status of your tileset.
#
# {'message': 'Processing stobieb.batonrougela_growth', 'jobId': 'clbdr8lsi000a08jvag677eat'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 09:39:25.082768
# creating tilesets for: battlecreekmi
# 2022-12-07 09:39:25.082887
# tilesets upload-source stobieb battlecreekmi_growth_src battlecreekmi_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/battlecreekmi_growth_src", "files": 1, "source_size": 423510, "file_size": 423510}', '']
# tilesets create stobieb.battlecreekmi_growth --recipe battlecreekmi_growth_recipe.json --name battlecreekmi_growth
# ['{"message": "Successfully created empty tileset stobieb.battlecreekmi_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.battlecreekmi_growth battlecreekmi_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.battlecreekmi_growth
# 2022-12-07 09:44:31.065817
# ['{"message": "Processing stobieb.battlecreekmi_growth", "jobId": "clbdrhefz000x08jvccaf9dm9"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.battlecreekmi_growth or run tilesets job stobieb.battlecreekmi_growth clbdrhefz000x08jvccaf9dm9 to view the status of your tileset.
#
# {'message': 'Processing stobieb.battlecreekmi_growth', 'jobId': 'clbdrhefz000x08jvccaf9dm9'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:00:42.748911
# creating tilesets for: baycitymi
# 2022-12-07 10:00:42.749090
# tilesets upload-source stobieb baycitymi_growth_src baycitymi_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/baycitymi_growth_src", "files": 1, "source_size": 236166, "file_size": 236166}', '']
# tilesets create stobieb.baycitymi_growth --recipe baycitymi_growth_recipe.json --name baycitymi_growth
# ['{"message": "Successfully created empty tileset stobieb.baycitymi_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.baycitymi_growth baycitymi_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.baycitymi_growth
# 2022-12-07 10:00:49.746852
# ['{"message": "Processing stobieb.baycitymi_growth", "jobId": "clbds2dc0000i08ldce673s03"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.baycitymi_growth or run tilesets job stobieb.baycitymi_growth clbds2dc0000i08ldce673s03 to view the status of your tileset.
#
# {'message': 'Processing stobieb.baycitymi_growth', 'jobId': 'clbds2dc0000i08ldce673s03'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:02:32.747653
# creating tilesets for: beaumonttx
# 2022-12-07 10:02:32.747800
# tilesets upload-source stobieb beaumonttx_growth_src beaumonttx_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/beaumonttx_growth_src", "files": 1, "source_size": 2281749, "file_size": 2281749}', '']
# tilesets create stobieb.beaumonttx_growth --recipe beaumonttx_growth_recipe.json --name beaumonttx_growth
# ['{"message": "Successfully created empty tileset stobieb.beaumonttx_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.beaumonttx_growth beaumonttx_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.beaumonttx_growth
# 2022-12-07 10:02:40.226514
# ['{"message": "Processing stobieb.beaumonttx_growth", "jobId": "clbds4r3s000n08ld0mr8663o"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.beaumonttx_growth or run tilesets job stobieb.beaumonttx_growth clbds4r3s000n08ld0mr8663o to view the status of your tileset.
#
# {'message': 'Processing stobieb.beaumonttx_growth', 'jobId': 'clbds4r3s000n08ld0mr8663o'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:04:24.060464
# creating tilesets for: beckleywv
# 2022-12-07 10:04:24.060638
# tilesets upload-source stobieb beckleywv_growth_src beckleywv_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/beckleywv_growth_src", "files": 1, "source_size": 2117620, "file_size": 2117620}', '']
# tilesets create stobieb.beckleywv_growth --recipe beckleywv_growth_recipe.json --name beckleywv_growth
# ['{"message": "Successfully created empty tileset stobieb.beckleywv_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.beckleywv_growth beckleywv_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.beckleywv_growth
# 2022-12-07 10:04:31.548674
# ['{"message": "Processing stobieb.beckleywv_growth", "jobId": "clbds74pr002h08l92hhfg7d4"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.beckleywv_growth or run tilesets job stobieb.beckleywv_growth clbds74pr002h08l92hhfg7d4 to view the status of your tileset.
#
# {'message': 'Processing stobieb.beckleywv_growth', 'jobId': 'clbds74pr002h08l92hhfg7d4'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:05:58.528692
# creating tilesets for: bellinghamwa
# 2022-12-07 10:05:58.528896
# tilesets upload-source stobieb bellinghamwa_growth_src bellinghamwa_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/bellinghamwa_growth_src", "files": 1, "source_size": 742357, "file_size": 742357}', '']
# tilesets create stobieb.bellinghamwa_growth --recipe bellinghamwa_growth_recipe.json --name bellinghamwa_growth
# ['{"message": "Successfully created empty tileset stobieb.bellinghamwa_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.bellinghamwa_growth bellinghamwa_growth_recipe.json
# [''] Traceback (most recent call last):
#   File "/Users/alanmccann/opt/anaconda3/bin/tilesets", line 8, in <module>
#     sys.exit(cli())
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/mapbox_tilesets/scripts/cli.py", line 496, in update_recipe
#     raise errors.TilesetsError(r.text)
# mapbox_tilesets.errors.TilesetsError: {"message":"stobieb.bellinghamwa_growth does not exist."}
#
# tilesets publish stobieb.bellinghamwa_growth
# 2022-12-07 10:06:06.664973
# ['{"message": "Processing stobieb.bellinghamwa_growth", "jobId": "clbds96bj001108lddka2595e"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.bellinghamwa_growth or run tilesets job stobieb.bellinghamwa_growth clbds96bj001108lddka2595e to view the status of your tileset.
#
# {'message': 'Processing stobieb.bellinghamwa_growth', 'jobId': 'clbds96bj001108lddka2595e'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:08:56.729281
# creating tilesets for: bendor
# 2022-12-07 10:08:56.729439
# tilesets upload-source stobieb bendor_growth_src bendor_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/bendor_growth_src", "files": 1, "source_size": 1444637, "file_size": 1444637}', '']
# tilesets create stobieb.bendor_growth --recipe bendor_growth_recipe.json --name bendor_growth
# ['{"message": "Successfully created empty tileset stobieb.bendor_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.bendor_growth bendor_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.bendor_growth
# 2022-12-07 10:09:05.158950
# ['{"message": "Processing stobieb.bendor_growth", "jobId": "clbdsd01s000508la2lal514h"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.bendor_growth or run tilesets job stobieb.bendor_growth clbdsd01s000508la2lal514h to view the status of your tileset.
#
# {'message': 'Processing stobieb.bendor_growth', 'jobId': 'clbdsd01s000508la2lal514h'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:11:06.446209
# creating tilesets for: billingsmt
# 2022-12-07 10:11:06.446378
# tilesets upload-source stobieb billingsmt_growth_src billingsmt_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/billingsmt_growth_src", "files": 1, "source_size": 1648448, "file_size": 1648448}', '']
# tilesets create stobieb.billingsmt_growth --recipe billingsmt_growth_recipe.json --name billingsmt_growth
# ['{"message": "Successfully created empty tileset stobieb.billingsmt_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.billingsmt_growth billingsmt_growth_recipe.json
# [''] Traceback (most recent call last):
#   File "/Users/alanmccann/opt/anaconda3/bin/tilesets", line 8, in <module>
#     sys.exit(cli())
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1128, in __call__
#     return self.main(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1053, in main
#     rv = self.invoke(ctx)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1659, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 1395, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/click/core.py", line 754, in invoke
#     return __callback(*args, **kwargs)
#   File "/Users/alanmccann/opt/anaconda3/lib/python3.9/site-packages/mapbox_tilesets/scripts/cli.py", line 496, in update_recipe
#     raise errors.TilesetsError(r.text)
# mapbox_tilesets.errors.TilesetsError: {"message":"stobieb.billingsmt_growth does not exist."}
#
# tilesets publish stobieb.billingsmt_growth
# 2022-12-07 10:11:13.262587
# ['{"message": "Processing stobieb.billingsmt_growth", "jobId": "clbdsfqi6002a08jvf089h34c"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.billingsmt_growth or run tilesets job stobieb.billingsmt_growth clbdsfqi6002a08jvf089h34c to view the status of your tileset.
#
# {'message': 'Processing stobieb.billingsmt_growth', 'jobId': 'clbdsfqi6002a08jvf089h34c'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:12:58.114910
# creating tilesets for: binghamtonny
# 2022-12-07 10:12:58.115076
# tilesets upload-source stobieb binghamtonny_growth_src binghamtonny_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/binghamtonny_growth_src", "files": 1, "source_size": 1341228, "file_size": 1341228}', '']
# tilesets create stobieb.binghamtonny_growth --recipe binghamtonny_growth_recipe.json --name binghamtonny_growth
# ['{"message": "Successfully created empty tileset stobieb.binghamtonny_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.binghamtonny_growth binghamtonny_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.binghamtonny_growth
# 2022-12-07 10:13:09.205806
# ['{"message": "Processing stobieb.binghamtonny_growth", "jobId": "clbdsi84c000908mdgv8fgxps"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.binghamtonny_growth or run tilesets job stobieb.binghamtonny_growth clbdsi84c000908mdgv8fgxps to view the status of your tileset.
#
# {'message': 'Processing stobieb.binghamtonny_growth', 'jobId': 'clbdsi84c000908mdgv8fgxps'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:14:36.393828
# creating tilesets for: birminghamal
# 2022-12-07 10:14:36.393990
# tilesets upload-source stobieb birminghamal_growth_src birminghamal_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/birminghamal_growth_src", "files": 1, "source_size": 7328372, "file_size": 7328372}', '']
# tilesets create stobieb.birminghamal_growth --recipe birminghamal_growth_recipe.json --name birminghamal_growth
# ['{"message": "Successfully created empty tileset stobieb.birminghamal_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.birminghamal_growth birminghamal_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.birminghamal_growth
# 2022-12-07 10:14:48.423444
# ['{"message": "Processing stobieb.birminghamal_growth", "jobId": "clbdskd0o002n08jvgx3167at"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.birminghamal_growth or run tilesets job stobieb.birminghamal_growth clbdskd0o002n08jvgx3167at to view the status of your tileset.
#
# {'message': 'Processing stobieb.birminghamal_growth', 'jobId': 'clbdskd0o002n08jvgx3167at'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 10:16:31.616482
# creating tilesets for: bismarcknd
# 2022-12-07 10:16:31.616639
# tilesets upload-source stobieb bismarcknd_growth_src bismarcknd_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/bismarcknd_growth_src", "files": 1, "source_size": 816046, "file_size": 816046}', '']
# tilesets create stobieb.bismarcknd_growth --recipe bismarcknd_growth_recipe.json --name bismarcknd_growth
# ['{"message": "Successfully created empty tileset stobieb.bismarcknd_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.bismarcknd_growth bismarcknd_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.bismarcknd_growth
# 2022-12-07 10:16:39.091286
# ['{"message": "Processing stobieb.bismarcknd_growth", "jobId": "clbdsmq7x000f08mda8wqd4gt"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.bismarcknd_growth or run tilesets job stobieb.bismarcknd_growth clbdsmq7x000f08mda8wqd4gt to view the status of your tileset.
#
# {'message': 'Processing stobieb.bismarcknd_growth', 'jobId': 'clbdsmq7x000f08mda8wqd4gt'}
# ...
# ['{"message": "Successfully created empty tileset stobieb.pennsylvania_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.pennsylvania_growth pennsylvania_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.pennsylvania_growth
# 2022-12-07 23:34:59.349785
# ['{"message": "Processing stobieb.pennsylvania_growth", "jobId": "clbel5g8o000008mb9wv6f5li"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.pennsylvania_growth or run tilesets job stobieb.pennsylvania_growth clbel5g8o000008mb9wv6f5li to view the status of your tileset.
#
# {'message': 'Processing stobieb.pennsylvania_growth', 'jobId': 'clbel5g8o000008mb9wv6f5li'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:36:28.703803
# creating tilesets for: rhodeisland
# 2022-12-07 23:36:28.703962
# tilesets upload-source stobieb rhodeisland_growth_src rhodeisland_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/rhodeisland_growth_src", "files": 1, "source_size": 3982793, "file_size": 3982793}', '']
# tilesets create stobieb.rhodeisland_growth --recipe rhodeisland_growth_recipe.json --name rhodeisland_growth
# ['{"message": "Successfully created empty tileset stobieb.rhodeisland_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.rhodeisland_growth rhodeisland_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.rhodeisland_growth
# 2022-12-07 23:36:37.095827
# ['{"message": "Processing stobieb.rhodeisland_growth", "jobId": "clbel7hpg000s08kyeiwwfxas"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.rhodeisland_growth or run tilesets job stobieb.rhodeisland_growth clbel7hpg000s08kyeiwwfxas to view the status of your tileset.
#
# {'message': 'Processing stobieb.rhodeisland_growth', 'jobId': 'clbel7hpg000s08kyeiwwfxas'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:38:36.685550
# creating tilesets for: southcarolina
# 2022-12-07 23:38:36.685678
# tilesets upload-source stobieb southcarolina_growth_src southcarolina_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/southcarolina_growth_src", "files": 1, "source_size": 35357786, "file_size": 35357786}', '']
# tilesets create stobieb.southcarolina_growth --recipe southcarolina_growth_recipe.json --name southcarolina_growth
# ['{"message": "Successfully created empty tileset stobieb.southcarolina_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.southcarolina_growth southcarolina_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.southcarolina_growth
# 2022-12-07 23:38:52.941438
# ['{"message": "Processing stobieb.southcarolina_growth", "jobId": "clbelaefa000108la2x993zpm"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.southcarolina_growth or run tilesets job stobieb.southcarolina_growth clbelaefa000108la2x993zpm to view the status of your tileset.
#
# {'message': 'Processing stobieb.southcarolina_growth', 'jobId': 'clbelaefa000108la2x993zpm'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:40:37.125714
# creating tilesets for: southdakota
# 2022-12-07 23:40:37.125933
# tilesets upload-source stobieb southdakota_growth_src southdakota_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/southdakota_growth_src", "files": 1, "source_size": 13279092, "file_size": 13279092}', '']
# tilesets create stobieb.southdakota_growth --recipe southdakota_growth_recipe.json --name southdakota_growth
# ['{"message": "Successfully created empty tileset stobieb.southdakota_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.southdakota_growth southdakota_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.southdakota_growth
# 2022-12-07 23:40:47.681724
# ['{"message": "Processing stobieb.southdakota_growth", "jobId": "clbelcuxz000608lab0sqfix1"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.southdakota_growth or run tilesets job stobieb.southdakota_growth clbelcuxz000608lab0sqfix1 to view the status of your tileset.
#
# {'message': 'Processing stobieb.southdakota_growth', 'jobId': 'clbelcuxz000608lab0sqfix1'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:42:46.980385
# creating tilesets for: tennessee
# 2022-12-07 23:42:46.980914
# tilesets upload-source stobieb tennessee_growth_src tennessee_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/tennessee_growth_src", "files": 1, "source_size": 57402268, "file_size": 57402268}', '']
# tilesets create stobieb.tennessee_growth --recipe tennessee_growth_recipe.json --name tennessee_growth
# ['{"message": "Successfully created empty tileset stobieb.tennessee_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.tennessee_growth tennessee_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.tennessee_growth
# 2022-12-07 23:43:08.882209
# ['{"message": "Processing stobieb.tennessee_growth", "jobId": "clbelfvv9001f08ky8qs345nr"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.tennessee_growth or run tilesets job stobieb.tennessee_growth clbelfvv9001f08ky8qs345nr to view the status of your tileset.
#
# {'message': 'Processing stobieb.tennessee_growth', 'jobId': 'clbelfvv9001f08ky8qs345nr'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:44:51.964638
# creating tilesets for: texas
# 2022-12-07 23:44:51.965247
# tilesets upload-source stobieb texas_growth_src texas_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_growth_src", "files": 1, "source_size": 117051344, "file_size": 117051344}', '']
# tilesets create stobieb.texas_growth --recipe texas_growth_recipe.json --name texas_growth
# ['{"message": "stobieb.texas_growth already exists"}', '']
# tilesets update-recipe stobieb.texas_growth texas_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_growth
# 2022-12-07 23:45:31.724008
# ['{"message": "Processing stobieb.texas_growth", "jobId": "clbeliy1e001u08kyf9dodvtt"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_growth or run tilesets job stobieb.texas_growth clbeliy1e001u08kyf9dodvtt to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_growth', 'jobId': 'clbeliy1e001u08kyf9dodvtt'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:47:14.129734
# creating tilesets for: utah
# 2022-12-07 23:47:14.129879
# tilesets upload-source stobieb utah_growth_src utah_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/utah_growth_src", "files": 1, "source_size": 19924518, "file_size": 19924518}', '']
# tilesets create stobieb.utah_growth --recipe utah_growth_recipe.json --name utah_growth
# ['{"message": "Successfully created empty tileset stobieb.utah_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.utah_growth utah_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.utah_growth
# 2022-12-07 23:47:26.810669
# ['{"message": "Processing stobieb.utah_growth", "jobId": "clbellewb001w08kydyel3isb"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.utah_growth or run tilesets job stobieb.utah_growth clbellewb001w08kydyel3isb to view the status of your tileset.
#
# {'message': 'Processing stobieb.utah_growth', 'jobId': 'clbellewb001w08kydyel3isb'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:49:58.820945
# creating tilesets for: vermont
# 2022-12-07 23:49:58.821163
# tilesets upload-source stobieb vermont_growth_src vermont_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/vermont_growth_src", "files": 1, "source_size": 4126650, "file_size": 4126650}', '']
# tilesets create stobieb.vermont_growth --recipe vermont_growth_recipe.json --name vermont_growth
# ['{"message": "Successfully created empty tileset stobieb.vermont_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.vermont_growth vermont_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.vermont_growth
# 2022-12-07 23:50:07.236940
# ['{"message": "Processing stobieb.vermont_growth", "jobId": "clbelouqc000608jxhgb4bfea"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.vermont_growth or run tilesets job stobieb.vermont_growth clbelouqc000608jxhgb4bfea to view the status of your tileset.
#
# {'message': 'Processing stobieb.vermont_growth', 'jobId': 'clbelouqc000608jxhgb4bfea'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:51:33.676125
# creating tilesets for: virginia
# 2022-12-07 23:51:33.676282
# tilesets upload-source stobieb virginia_growth_src virginia_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/virginia_growth_src", "files": 1, "source_size": 58212756, "file_size": 58212756}', '']
# tilesets create stobieb.virginia_growth --recipe virginia_growth_recipe.json --name virginia_growth
# ['{"message": "Successfully created empty tileset stobieb.virginia_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.virginia_growth virginia_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.virginia_growth
# 2022-12-07 23:52:03.232410
# ['{"message": "Processing stobieb.virginia_growth", "jobId": "clbelrcfu000b08jxdrqpehah"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.virginia_growth or run tilesets job stobieb.virginia_growth clbelrcfu000b08jxdrqpehah to view the status of your tileset.
#
# {'message': 'Processing stobieb.virginia_growth', 'jobId': 'clbelrcfu000b08jxdrqpehah'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:53:46.191233
# creating tilesets for: washington
# 2022-12-07 23:53:46.191365
# tilesets upload-source stobieb washington_growth_src washington_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/washington_growth_src", "files": 1, "source_size": 40098088, "file_size": 40098088}', '']
# tilesets create stobieb.washington_growth --recipe washington_growth_recipe.json --name washington_growth
# ['{"message": "Successfully created empty tileset stobieb.washington_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.washington_growth washington_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.washington_growth
# 2022-12-07 23:54:06.798878
# ['{"message": "Processing stobieb.washington_growth", "jobId": "clbeltzj8000m08jx9qtd0skf"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.washington_growth or run tilesets job stobieb.washington_growth clbeltzj8000m08jx9qtd0skf to view the status of your tileset.
#
# {'message': 'Processing stobieb.washington_growth', 'jobId': 'clbeltzj8000m08jx9qtd0skf'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:55:33.756157
# creating tilesets for: westvirginia
# 2022-12-07 23:55:33.756340
# tilesets upload-source stobieb westvirginia_growth_src westvirginia_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/westvirginia_growth_src", "files": 1, "source_size": 35345826, "file_size": 35345826}', '']
# tilesets create stobieb.westvirginia_growth --recipe westvirginia_growth_recipe.json --name westvirginia_growth
# ['{"message": "Successfully created empty tileset stobieb.westvirginia_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.westvirginia_growth westvirginia_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.westvirginia_growth
# 2022-12-07 23:55:49.728664
# ['{"message": "Processing stobieb.westvirginia_growth", "jobId": "clbelw6rh000u08jx69ho6f63"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.westvirginia_growth or run tilesets job stobieb.westvirginia_growth clbelw6rh000u08jx69ho6f63 to view the status of your tileset.
#
# {'message': 'Processing stobieb.westvirginia_growth', 'jobId': 'clbelw6rh000u08jx69ho6f63'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:56:59.668240
# creating tilesets for: wisconsin
# 2022-12-07 23:56:59.668420
# tilesets upload-source stobieb wisconsin_growth_src wisconsin_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/wisconsin_growth_src", "files": 1, "source_size": 34906275, "file_size": 34906275}', '']
# tilesets create stobieb.wisconsin_growth --recipe wisconsin_growth_recipe.json --name wisconsin_growth
# ['{"message": "Successfully created empty tileset stobieb.wisconsin_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.wisconsin_growth wisconsin_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.wisconsin_growth
# 2022-12-07 23:57:17.446062
# ['{"message": "Processing stobieb.wisconsin_growth", "jobId": "clbely30p000w08jx3j9ldoq3"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.wisconsin_growth or run tilesets job stobieb.wisconsin_growth clbely30p000w08jx3j9ldoq3 to view the status of your tileset.
#
# {'message': 'Processing stobieb.wisconsin_growth', 'jobId': 'clbely30p000w08jx3j9ldoq3'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-07 23:59:33.774845
# creating tilesets for: wyoming
# 2022-12-07 23:59:33.774992
# tilesets upload-source stobieb wyoming_growth_src wyoming_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/wyoming_growth_src", "files": 1, "source_size": 9947484, "file_size": 9947484}', '']
# tilesets create stobieb.wyoming_growth --recipe wyoming_growth_recipe.json --name wyoming_growth
# ['{"message": "Successfully created empty tileset stobieb.wyoming_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.wyoming_growth wyoming_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.wyoming_growth
# 2022-12-07 23:59:44.511092
# ['{"message": "Processing stobieb.wyoming_growth", "jobId": "clbem185k001408jxbquq86mn"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.wyoming_growth or run tilesets job stobieb.wyoming_growth clbem185k001408jxbquq86mn to view the status of your tileset.
#
# {'message': 'Processing stobieb.wyoming_growth', 'jobId': 'clbem185k001408jxbquq86mn'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-08 00:01:11.037755

# %%
import csv
import datetime
source_data_base_path = "/Users/alanmccann/Dropbox/bain/bain-uploads/v6_4th_run Brian Stobie"
published_data_base_path = '/Users/alanmccann/Dropbox/bain/mtsds-data'
csv_file_path = f'{source_data_base_path}/Market_Mapping_Settings.csv'
market_rows = []
with open(csv_file_path, encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        market_rows.append(row)
market_count = 0
completed_markets = []
# STATS_TYPES = ['Count','Percent','nshft','Labels', 'pshft','growth']
STATS_TYPES = [ 'pshft','growth']
for market_data in market_rows[424:425]:
    market_file_prefix = market_data['MarketName'].lower()
    # if market_data['MarketName'] in ['Texas','DallasFortWorth']:
    print('creating tilesets for:', market_file_prefix)
    print(datetime.datetime.now())
    for stats_type in STATS_TYPES:
        upload_source(market_file_prefix, stats_type, published_data_base_path)
        upload_tileset(market_file_prefix, stats_type, published_data_base_path)
        update_recipe(market_file_prefix, stats_type, published_data_base_path)
        publish_tileset(market_file_prefix, stats_type, published_data_base_path)
# Out:
# creating tilesets for: texas
# 2022-12-04 13:23:54.469124
# tilesets upload-source stobieb texas_pshft_src texas_pshft.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_pshft_src", "files": 1, "source_size": 118291505, "file_size": 118291505}', '']
# tilesets create stobieb.texas_pshft --recipe texas_pshft_recipe.json --name texas_pshft
# ['{"message": "Successfully created empty tileset stobieb.texas_pshft. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.texas_pshft texas_pshft_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_pshft
# 2022-12-04 13:25:09.420618
# ['{"message": "Processing stobieb.texas_pshft", "jobId": "clb9p1l4h000d08l21wh77bqz"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_pshft or run tilesets job stobieb.texas_pshft clb9p1l4h000d08l21wh77bqz to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_pshft', 'jobId': 'clb9p1l4h000d08l21wh77bqz'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-04 13:26:36.713757
# tilesets upload-source stobieb texas_growth_src texas_growth.json --replace
# ['upload progress', '{"id": "mapbox://tileset-source/stobieb/texas_growth_src", "files": 1, "source_size": 117582823, "file_size": 117582823}', '']
# tilesets create stobieb.texas_growth --recipe texas_growth_recipe.json --name texas_growth
# ['{"message": "Successfully created empty tileset stobieb.texas_growth. Publish your tileset to begin processing your data into vector tiles."}', '']
# tilesets update-recipe stobieb.texas_growth texas_growth_recipe.json
# [''] Updated recipe.
#
# tilesets publish stobieb.texas_growth
# 2022-12-04 13:27:31.152814
# ['{"message": "Processing stobieb.texas_growth", "jobId": "clb9p4mn6000j08k1ffri3el0"}', '']
# ✔ Tileset job received. Visit https://studio.mapbox.com/tilesets/stobieb.texas_growth or run tilesets job stobieb.texas_growth clb9p4mn6000j08k1ffri3el0 to view the status of your tileset.
#
# {'message': 'Processing stobieb.texas_growth', 'jobId': 'clb9p4mn6000j08k1ffri3el0'}
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# processing: sleeping
# finished
# 2022-12-04 13:28:57.500871

# %%
# market_rows[86] # Dallas
# market_rows[424] # Texas
# Out:
# {'MarketName': 'DallasFortWorthTX',
#  'Market_Display_Name': 'Dallas Fort Worth, TX',
#  'StateFips': '',
#  'CenterLat': '32.775862',
#  'CenterLong': '-96.796877',
#  'GeoTypeGroup': '1 - Designated Metro Areas',
#  'DefaultZoomLevel': '8'}

# %%
market_rows[424]
# Out:
# {'MarketName': 'Texas',
#  'Market_Display_Name': 'Texas',
#  'StateFips': '',
#  'CenterLat': '31.4757',
#  'CenterLong': '-99.3312',
#  'GeoTypeGroup': '2 - States',
#  'DefaultZoomLevel': '5'}
